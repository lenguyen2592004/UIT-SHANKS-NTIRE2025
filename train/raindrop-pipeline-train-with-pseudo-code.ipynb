# %%
import sys
import os

# Thêm đường dẫn vào sys.path
sys.path.append('/kaggle/input/raindrop_removal/pytorch/default/1/Raindrop-Removal')

# %% [markdown]
# https://github.com/Hyukju/Raindrop-Removal
#
# https://www.mdpi.com/2227-7390/11/15/3318

# %%
# %cd /kaggle/input/raindrop_removal/pytorch/default/1/Raindrop-Removal
# Out:
# /kaggle/input/raindrop_removal/pytorch/default/1/Raindrop-Removal

# %%
import sys
sys.argv = sys.argv[:1]  # Loại bỏ đối số '-f' của Jupyter

# %% [markdown]
# ## import libaries

# %%
import os
import cv2 
import numpy as np 
import torch
from torch.utils.data import Dataset
from torchvision.transforms import transforms

# %% [markdown]
# ## intialize dataset

# %%
import numpy as np
import torch
import cv2

class ToTensor():
    def __call__(self, data):
        for k, v in data.items():
            if v.ndim == 2:
                v = v[:, :, np.newaxis]
            data[k] = torch.from_numpy(v.transpose((2, 0, 1)).astype('float32'))
        return data

class Normalization():
    def __init__(self, mean=0.5, std=0.5):
        self.mean = mean
        self.std = std 

    def __call__(self, data):
        for k, v in data.items():
            data[k] = (v - self.mean) / self.std
        return data

class RandomFlip():
    def __call__(self, data):
        flag_lr = np.random.rand() > 0.5
        flag_ud = np.random.rand() > 0.5

        for k, v in data.items():
            if flag_lr: v = np.fliplr(v)
            if flag_ud: v = np.flipud(v)
            data[k] = v
        return data

class RandomCrop():
    def __init__(self, shape):
        self.shape = shape

    def __call__(self, data):
        input = data['input']
        h, w = input.shape[:2]
        new_h, new_w = self.shape

        top = np.random.randint(0, h - new_h)
        left = np.random.randint(0, w - new_w)

        id_y = np.arange(top, top + new_h, 1)[:, np.newaxis]
        id_x = np.arange(left, left + new_w, 1)

        for k, v in data.items():
            data[k] = v[id_y, id_x]
        return data

class RandomBrightness():
    def __init__(self, delta=0.2):
        self.delta = delta  # Brightness range (-delta, +delta)

    def __call__(self, data):
        factor = 1.0 + np.random.uniform(-self.delta, self.delta)
        for k, v in data.items():
            data[k] = np.clip(v * factor, 0, 1)  # Ensuring values remain in [0,1]
        return data

class RandomBlur():
    def __init__(self, max_kernel=3):
        self.max_kernel = max_kernel  # Maximum kernel size

    def __call__(self, data):
        ksize = np.random.choice(range(1, self.max_kernel + 1, 2))  # Odd kernel size
        if ksize > 1:  # Apply blur only if kernel size > 1
            for k, v in data.items():
                data[k] = cv2.GaussianBlur(v, (ksize, ksize), 0)
        return data

# %%
# class ModelDataset(Dataset):
#     def __init__(self, data_dir, dataA_dir = 'Drop', dataB_dir='Clear', use_transform=False):
#         self.data_dir = data_dir
#         self.use_transform = use_transform
#         self.transform =  transforms.Compose([
#                                             RandomCrop(shape=(256, 256)),
#                                             RandomFlip(),
#                                             Normalization(mean=0.5, std=0.5),
#                                             ToTensor(),
#                                             ])
#         self.dataA_dir = dataA_dir
#         self.dataB_dir = dataB_dir

#         lst_dataA = []
#         for folder in os.listdir(os.path.join(self.data_dir, self.dataA_dir)):
#             folder_path = os.path.join(self.data_dir, self.dataA_dir, folder)
#             if os.path.isdir(folder_path):  # Check if it's a folder
#                 images = sorted([img for img in os.listdir(folder_path) if img.lower().endswith(('jpg', 'png'))])
#                 if images:  # Ensure there is at least one image
#                     lst_dataA.append(os.path.join(folder_path, images[1]))  # Take the first image
#         lst_dataA.sort()

        
#         lst_dataB = []
#         for folder in os.listdir(os.path.join(self.data_dir, self.dataB_dir)):
#             folder_path = os.path.join(self.data_dir, self.dataB_dir, folder)
#             if os.path.isdir(folder_path):  # Check if it's a folder
#                 images = ([img for img in os.listdir(folder_path) if img.lower().endswith(('jpg', 'png'))])
#                 if images:  # Ensure there is at least one image
#                     lst_dataB.append(os.path.join(folder_path, images[1]))  # Take the first image
#         lst_dataB.sort()

#         self.lst_dataA = lst_dataA
#         self.lst_dataB = lst_dataB

#     def __len__(self):
#         return len(self.lst_dataA)

#     def __getitem__(self, index):

#         imgA = cv2.imread(os.path.join(self.data_dir, self.dataA_dir, self.lst_dataA[index]))
#         imgB = cv2.imread(os.path.join(self.data_dir, self.dataB_dir, self.lst_dataB[index]))
#         imgA = cv2.cvtColor(imgA, cv2.COLOR_BGR2RGB)
#         imgB = cv2.cvtColor(imgB, cv2.COLOR_BGR2RGB)

#         if imgA.dtype == np.uint8:
#             imgA = imgA / 255.0  
#         if imgB.dtype == np.uint8:
#             imgB = imgB / 255.0      

#         grayA = cv2.cvtColor(imgA.astype('float32'), cv2.COLOR_RGB2GRAY)
#         grayB = cv2.cvtColor(imgB.astype('float32'), cv2.COLOR_RGB2GRAY)

#         mask = (grayA - grayB) * 0.5 + 0.5
     
#         data = {'input':imgA, 'label':imgB, 'mask':mask}

#         if self.use_transform:
#             data = self.transform(data)

#         return data

# %%
# import os
# import cv2
# import torch
# import random
# import numpy as np
# from torch.utils.data import Dataset

# class ModelDataset(Dataset):
#     def __init__(self, root_dir='/kaggle/input/ntire2025', subset_day="DayRainDrop_Train_img/DayRainDrop_Train", 
#                  subset_night="NightRainDrop_Train_img/NightRainDrop_Train", use_transform=False):
#         """
#         Initialize the dataset with the same path structure as RaindropDataset.
#         :param root_dir: Root directory of the dataset
#         :param subset_day: Path to the daytime dataset
#         :param subset_night: Path to the nighttime dataset
#         :param use_transform: Whether to apply transformations
#         """
#         self.root_dir = root_dir
#         self.use_transform = use_transform

#         self.transform = transforms.Compose([
#             RandomCrop(shape=(256, 256)),
#             RandomFlip(),
#             Normalization(mean=0.5, std=0.5),
#             ToTensor(),
#         ])

#         # Daytime paths
#         subset_path_day = os.path.join(root_dir, subset_day)
#         self.drop_path_day = os.path.join(subset_path_day, "Drop")
#         self.clear_path_day = os.path.join(subset_path_day, "Clear")

#         # Nighttime paths
#         subset_path_night = os.path.join(root_dir, subset_night)
#         self.drop_path_night = os.path.join(subset_path_night, "Drop")
#         self.clear_path_night = os.path.join(subset_path_night, "Clear")

#         # Load image lists
#         self.lst_dataA_all = []  # Drop images
#         self.lst_dataB_all = []  # Clear images

#         # Add day images if they exist
#         if os.path.exists(self.drop_path_day) and os.path.exists(self.clear_path_day):
#             drop_images_day = sorted([os.path.join(self.drop_path_day, img) 
#                                    for img in os.listdir(self.drop_path_day)
#                                    if img.lower().endswith(('.png', '.jpg', '.jpeg'))])
#             clear_images_day = sorted([os.path.join(self.clear_path_day, img) 
#                                     for img in os.listdir(self.clear_path_day)
#                                     if img.lower().endswith(('.png', '.jpg', '.jpeg'))])
#             self.lst_dataA_all.extend(drop_images_day)
#             self.lst_dataB_all.extend(clear_images_day)

#         # Add night images if they exist
#         if os.path.exists(self.drop_path_night) and os.path.exists(self.clear_path_night):
#             drop_images_night = sorted([os.path.join(self.drop_path_night, img) 
#                                      for img in os.listdir(self.drop_path_night)
#                                      if img.lower().endswith(('.png', '.jpg', '.jpeg'))])
#             clear_images_night = sorted([os.path.join(self.clear_path_night, img) 
#                                       for img in os.listdir(self.clear_path_night)
#                                       if img.lower().endswith(('.png', '.jpg', '.jpeg'))])
#             self.lst_dataA_all.extend(drop_images_night)
#             self.lst_dataB_all.extend(clear_images_night)

#         # Ensure the lists have the same length and corresponding pairs
#         assert len(self.lst_dataA_all) == len(self.lst_dataB_all), "Mismatch in number of input and label images"

#     def __len__(self):
#         return len(self.lst_dataA_all)

#     def __getitem__(self, index):
#         imgA_path = self.lst_dataA_all[index]
#         imgB_path = self.lst_dataB_all[index]

#         imgA = cv2.imread(imgA_path)
#         imgB = cv2.imread(imgB_path)

#         if imgA is None or imgB is None:
#             raise ValueError(f"Error loading images: {imgA_path} or {imgB_path}")

#         imgA = cv2.cvtColor(imgA, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
#         imgB = cv2.cvtColor(imgB, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0

#         grayA = cv2.cvtColor(imgA, cv2.COLOR_RGB2GRAY)
#         grayB = cv2.cvtColor(imgB, cv2.COLOR_RGB2GRAY)
#         mask = (grayA - grayB) * 0.5 + 0.5

#         data = {'input': imgA, 'label': imgB, 'mask': mask}

#         if self.use_transform:
#             data = self.transform(data)

#         return data

# %%
class ModelDataset(Dataset):
    def __init__(self, input_folder="/kaggle/input/ntire2025/RainDrop/RainDrop", target_folder="/kaggle/input/resfusion-inference/submission", use_transform=False):
        """
        Initialize dataset using only two folders: input (rainy images) and target (clean images).
        :param root_dir: Root directory containing both folders
        :param input_folder: Folder containing rainy images
        :param target_folder: Folder containing clean images
        :param use_transform: Whether to apply transformations
        """
        #self.root_dir = root_dir
        self.use_transform = use_transform
        self.input_path =  input_folder
        self.target_path = target_folder
        
        self.transform = transforms.Compose([
            RandomCrop(shape=(256, 256)),
            RandomFlip(),
            Normalization(mean=0.5, std=0.5),
            ToTensor(),
        ])

        # Get sorted lists of images
        self.input_images = sorted([os.path.join(self.input_path, img) 
                                    for img in os.listdir(self.input_path) 
                                    if img.lower().endswith(('.png', '.jpg', '.jpeg'))])

        self.target_images = sorted([os.path.join(self.target_path, img) 
                                     for img in os.listdir(self.target_path) 
                                     if img.lower().endswith(('.png', '.jpg', '.jpeg'))])

        # Ensure corresponding pairs exist
        assert len(self.input_images) == len(self.target_images), "Mismatch in number of input and target images"

    def __len__(self):
        return len(self.input_images)

    def __getitem__(self, index):
        imgA_path = self.input_images[index]
        imgB_path = self.target_images[index]

        imgA = cv2.imread(imgA_path)
        imgB = cv2.imread(imgB_path)

        if imgA is None or imgB is None:
            raise ValueError(f"Error loading images: {imgA_path} or {imgB_path}")

        imgA = cv2.cvtColor(imgA, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
        imgB = cv2.cvtColor(imgB, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0

        # Create mask from grayscale difference
        grayA = cv2.cvtColor(imgA, cv2.COLOR_RGB2GRAY)
        grayB = cv2.cvtColor(imgB, cv2.COLOR_RGB2GRAY)
        mask = (grayA - grayB) * 0.5 + 0.5  # Normalize to [0,1]

        data = {'input': imgA, 'label': imgB, 'mask': mask}

        if self.use_transform:
            data = self.transform(data)

        return data

# %%
import importlib

def find_model(model_name, phase='train', learning_rate=0.002):
    """
    Searches for the specified model inside the 'model' directory.
    Imports the corresponding <model_name>_model.py and instantiates the 'Model' class.
    
    Parameters:
        model_name (str): Name of the model.
        phase (str): Either 'train' or 'test'.
        learning_rate (float): Learning rate for the model.

    Returns:
        model: Instantiated model class or None if not found.
    """
    
    model = None
    model_module_name = f'model.{model_name.lower()}_model'

    print(f'Searching for model: {model_module_name}')
    
    try:
        # Import the model module dynamically
        model_module = importlib.import_module(model_module_name)
    except ModuleNotFoundError:
        print(f'Error: {model_module_name} module not found.')
        return None
    
    target_model_name = 'Model'

    # Search for the class inside the module
    for name, cls in model_module.__dict__.items():
        if name.lower() == target_model_name.lower() and isinstance(cls, type):
            model = cls  # Store the class

    if model is None:
        print(f'Error: {target_model_name} class not found in {model_module_name}.')
        return None

    print(f'{model_module_name}.{target_model_name} successfully created.')
    
    # Instantiate the model with provided parameters
    return model(phase=phase, in_channels=3, out_channels=3, nker=64, lr=learning_rate)

# %% [markdown]
# ## Train

# %%
import os
import argparse
import utils
import torch
import gc
from torch.utils.data import DataLoader
from datetime import datetime
from time import time

def train(args):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    #ckpt_dir = os.path.join(args.ckpt_dir, args.model)
    ckpt_dir=args.ckpt_dir
    os.makedirs(ckpt_dir, exist_ok=True)
    save_dir= args.save_dir
    utils.print_args(args)
    utils.save_log(save_dir, 'train', args)
    
    model = find_model(model_name=args.model, phase='train', learning_rate=args.learning_rate)

    dataset = ModelDataset(
        use_transform=True
    )
    print(f"Length of dataset:{len(dataset)}")
    data_loader = DataLoader(
        dataset=dataset,
        batch_size=args.batch_size,
        shuffle=True,
        num_workers=args.num_workers,
        pin_memory=True  # ✅ Optimizes GPU memory transfer
    )

    max_batches = len(data_loader)
    start_epoch = 1

    # Check for continued training
    if args.train_continue:
        last_epoch = model.load(ckpt_dir,epoch=args.ckpt_epoch)
        if last_epoch > 1:
            start_epoch = last_epoch + 1
            print(f'Continued Training from EPOCH {last_epoch}!!')

    for epoch in range(start_epoch, args.ckpt_epoch+args.max_epochs + 1):
        start_t = time()
        losses_list = []
        for batch, data in enumerate(data_loader, 1):
            # Move data to GPU
            for key in data.keys():
                data[key] = data[key].to(device, non_blocking=True)

            # Forward pass
            model.set_inputs(data)
            model.train_on_batch()  # 🚨 Ensure this function returns loss tensor

            # Backward pass
            #loss.backward()
            #model.optimizer.step()
            #model.optimizer.zero_grad(set_to_none=True)  # ✅ Free memory

            # Print loss for each batch
            if batch == 1 or batch % 10 == 0 or batch == max_batches:
                losses_list.append(model.get_losses())
                utils.print_losses(epoch, args.ckpt_epoch+args.max_epochs, batch, max_batches, losses_list, title=f'[{args.model}] TRAIN', mode='last')

            # ✅ Free memory after every batch
            del data  # Delete unnecessary variables
            torch.cuda.empty_cache()  # Free GPU cache
            gc.collect()  # Run garbage collection

        # Print loss for each epoch (average of batch losses)
        delay_t = time() - start_t
        utils.print_losses(epoch, args.max_epochs, batch, max_batches, losses_list, title=f'[{args.model}: {delay_t:.3f}s] TRAIN MEAN LOSS', mode='mean')
        utils.save_losses(save_dir, epoch, losses_list, mode='mean')

        # Save images
        utils.save_outputs(
           save_dir=os.path.join(args.save_dir, args.model, 'train'),
           filename=f'{epoch:04d}.png',
           outputs=model.get_outputs(),
           max_display=3
        )

        # Save model every 200 epochs
        if epoch % 20 == 0:
            model.save(save_dir, epoch)

    print(f'Training Finished!!: {datetime.now()}')

if __name__ == '__main__':
    parser = argparse.ArgumentParser(prog='DeRainDrop')             
    
    parser.add_argument('--train_continue', action='store_true', dest='train_continue', default=True)
    parser.add_argument('--model', default='proposed', type=str, dest='model')
    parser.add_argument('--ckpt_epoch', default=700, type=int, dest='ckpt_epoch')
    parser.add_argument('--max_epochs', default=100, type=int, dest='max_epochs')
    parser.add_argument('--batch_size', default=8, type=int, dest='batch_size')
    parser.add_argument('--num_workers', default=8, type=int, dest='num_workers')
    parser.add_argument('--lr', default=0.0001, type=float, dest='learning_rate')
    parser.add_argument('--ckpt_dir', default='/kaggle/input/raindrop-pipeline-train-pseudo-code', type=str, dest='ckpt_dir')    
    parser.add_argument('--input_folder', default='/kaggle/input/ntire2025/RainDrop/RainDrop', type=str, dest='dataset_dir_day')
    parser.add_argument('--target_folder', default='/kaggle/input/resfusion-inference/submission', type=str, dest='dataset_dir_night')    

    parser.add_argument('--save_dir', default='/kaggle/working/', type=str, dest='save_dir')
    
    args = parser.parse_args()
    train(args)
# Out:
# -------------------------------------------
# train_continue: True
# model: proposed
# ckpt_epoch: 700
# max_epochs: 100
# batch_size: 8
# num_workers: 8
# learning_rate: 0.0001
# ckpt_dir: /kaggle/input/raindrop-pipeline-train-pseudo-code
# dataset_dir_day: /kaggle/input/ntire2025/RainDrop/RainDrop
# dataset_dir_night: /kaggle/input/resfusion-inference/submission
# save_dir: /kaggle/working/
# -------------------------------------------
# Searching for model: model.proposed_model
# model.proposed_model.Model successfully created.
# initialize network with normal
# initialize network with normal
# initialize network with normal
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:07<00:00, 76.9MB/s]
# Length of dataset:731
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /kaggle/input/raindrop_removal/pytorch/default/1/Raindrop-Removal/utils.py:54: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_weights = torch.load(os.path.join(ckpt_dir, f'model_epoch{epoch}.pth'))
# Continued Training from EPOCH 700!!
# [proposed] TRAIN: EPOCH 701/800 | BATCH 1/92 | LOSS D: 0.6955 | LOSS G: 0.7726 | LOSS GAN: 0.6913 | LOSS MULTSCALE: 0.0039 | LOSS SSIM: 0.0362 | LOSS VGG: 0.0413 | LOSS MASK: 0.0006 |
# [proposed] TRAIN: EPOCH 701/800 | BATCH 10/92 | LOSS D: 0.6935 | LOSS G: 0.8152 | LOSS GAN: 0.7081 | LOSS MULTSCALE: 0.0033 | LOSS SSIM: 0.0697 | LOSS VGG: 0.0341 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 701/800 | BATCH 20/92 | LOSS D: 0.6929 | LOSS G: 0.8187 | LOSS GAN: 0.7088 | LOSS MULTSCALE: 0.0105 | LOSS SSIM: 0.0615 | LOSS VGG: 0.0380 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 701/800 | BATCH 30/92 | LOSS D: 0.6973 | LOSS G: 0.7668 | LOSS GAN: 0.6885 | LOSS MULTSCALE: 0.0030 | LOSS SSIM: 0.0377 | LOSS VGG: 0.0375 | LOSS MASK: 0.0005 |
# [proposed] TRAIN: EPOCH 701/800 | BATCH 40/92 | LOSS D: 0.6943 | LOSS G: 0.7758 | LOSS GAN: 0.7179 | LOSS MULTSCALE: 0.0020 | LOSS SSIM: 0.0290 | LOSS VGG: 0.0270 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 701/800 | BATCH 50/92 | LOSS D: 0.6973 | LOSS G: 0.7519 | LOSS GAN: 0.6931 | LOSS MULTSCALE: 0.0021 | LOSS SSIM: 0.0327 | LOSS VGG: 0.0241 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 701/800 | BATCH 60/92 | LOSS D: 0.6957 | LOSS G: 0.7612 | LOSS GAN: 0.6958 | LOSS MULTSCALE: 0.0029 | LOSS SSIM: 0.0386 | LOSS VGG: 0.0240 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 701/800 | BATCH 70/92 | LOSS D: 0.6938 | LOSS G: 0.7521 | LOSS GAN: 0.6943 | LOSS MULTSCALE: 0.0026 | LOSS SSIM: 0.0310 | LOSS VGG: 0.0242 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 701/800 | BATCH 80/92 | LOSS D: 0.6944 | LOSS G: 0.7727 | LOSS GAN: 0.6985 | LOSS MULTSCALE: 0.0032 | LOSS SSIM: 0.0338 | LOSS VGG: 0.0372 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 701/800 | BATCH 90/92 | LOSS D: 0.6940 | LOSS G: 0.7682 | LOSS GAN: 0.6900 | LOSS MULTSCALE: 0.0027 | LOSS SSIM: 0.0422 | LOSS VGG: 0.0333 | LOSS MASK: 0.0005 |
# [proposed] TRAIN: EPOCH 701/800 | BATCH 92/92 | LOSS D: 0.6899 | LOSS G: 0.8394 | LOSS GAN: 0.7177 | LOSS MULTSCALE: 0.0135 | LOSS SSIM: 0.0510 | LOSS VGG: 0.0572 | LOSS MASK: 0.0004 |
# [proposed: 110.199s] TRAIN MEAN LOSS: EPOCH 701/100 | LOSS D: 0.6944 | LOSS G: 0.7813 | LOSS GAN: 0.7004 | LOSS MULTSCALE: 0.0045 | LOSS SSIM: 0.0421 | LOSS VGG: 0.0343 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 702/800 | BATCH 1/92 | LOSS D: 0.6914 | LOSS G: 0.7989 | LOSS GAN: 0.6874 | LOSS MULTSCALE: 0.0056 | LOSS SSIM: 0.0765 | LOSS VGG: 0.0294 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 702/800 | BATCH 10/92 | LOSS D: 0.7030 | LOSS G: 0.7919 | LOSS GAN: 0.6803 | LOSS MULTSCALE: 0.0035 | LOSS SSIM: 0.0617 | LOSS VGG: 0.0464 | LOSS MASK: 0.0006 |
# [proposed] TRAIN: EPOCH 702/800 | BATCH 20/92 | LOSS D: 0.6907 | LOSS G: 0.8058 | LOSS GAN: 0.7291 | LOSS MULTSCALE: 0.0043 | LOSS SSIM: 0.0425 | LOSS VGG: 0.0299 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 702/800 | BATCH 30/92 | LOSS D: 0.6947 | LOSS G: 0.7882 | LOSS GAN: 0.7108 | LOSS MULTSCALE: 0.0072 | LOSS SSIM: 0.0411 | LOSS VGG: 0.0290 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 702/800 | BATCH 40/92 | LOSS D: 0.6953 | LOSS G: 0.7555 | LOSS GAN: 0.6959 | LOSS MULTSCALE: 0.0020 | LOSS SSIM: 0.0329 | LOSS VGG: 0.0247 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 702/800 | BATCH 50/92 | LOSS D: 0.6909 | LOSS G: 0.7682 | LOSS GAN: 0.6877 | LOSS MULTSCALE: 0.0052 | LOSS SSIM: 0.0504 | LOSS VGG: 0.0249 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 702/800 | BATCH 60/92 | LOSS D: 0.6961 | LOSS G: 0.7845 | LOSS GAN: 0.6972 | LOSS MULTSCALE: 0.0038 | LOSS SSIM: 0.0536 | LOSS VGG: 0.0299 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 702/800 | BATCH 70/92 | LOSS D: 0.6965 | LOSS G: 0.7637 | LOSS GAN: 0.6878 | LOSS MULTSCALE: 0.0047 | LOSS SSIM: 0.0326 | LOSS VGG: 0.0385 | LOSS MASK: 0.0006 |
# [proposed] TRAIN: EPOCH 702/800 | BATCH 80/92 | LOSS D: 0.6925 | LOSS G: 0.8136 | LOSS GAN: 0.7132 | LOSS MULTSCALE: 0.0077 | LOSS SSIM: 0.0528 | LOSS VGG: 0.0399 | LOSS MASK: 0.0006 |
# [proposed] TRAIN: EPOCH 702/800 | BATCH 90/92 | LOSS D: 0.6927 | LOSS G: 0.7809 | LOSS GAN: 0.7075 | LOSS MULTSCALE: 0.0059 | LOSS SSIM: 0.0389 | LOSS VGG: 0.0286 | LOSS MASK: 0.0005 |
# [proposed] TRAIN: EPOCH 702/800 | BATCH 92/92 | LOSS D: 0.6815 | LOSS G: 0.8445 | LOSS GAN: 0.7670 | LOSS MULTSCALE: 0.0084 | LOSS SSIM: 0.0356 | LOSS VGG: 0.0336 | LOSS MASK: 0.0007 |
# [proposed: 107.891s] TRAIN MEAN LOSS: EPOCH 702/100 | LOSS D: 0.6932 | LOSS G: 0.7905 | LOSS GAN: 0.7058 | LOSS MULTSCALE: 0.0053 | LOSS SSIM: 0.0471 | LOSS VGG: 0.0322 | LOSS MASK: 0.0005 |
# [proposed] TRAIN: EPOCH 703/800 | BATCH 1/92 | LOSS D: 0.6990 | LOSS G: 0.8422 | LOSS GAN: 0.7339 | LOSS MULTSCALE: 0.0062 | LOSS SSIM: 0.0726 | LOSS VGG: 0.0294 | LOSS MASK: 0.0007 |
# [proposed] TRAIN: EPOCH 703/800 | BATCH 10/92 | LOSS D: 0.6897 | LOSS G: 0.8259 | LOSS GAN: 0.7089 | LOSS MULTSCALE: 0.0050 | LOSS SSIM: 0.0810 | LOSS VGG: 0.0310 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 703/800 | BATCH 20/92 | LOSS D: 0.6992 | LOSS G: 0.8017 | LOSS GAN: 0.6906 | LOSS MULTSCALE: 0.0058 | LOSS SSIM: 0.0554 | LOSS VGG: 0.0499 | LOSS MASK: 0.0006 |
# [proposed] TRAIN: EPOCH 703/800 | BATCH 30/92 | LOSS D: 0.6940 | LOSS G: 0.7732 | LOSS GAN: 0.7022 | LOSS MULTSCALE: 0.0032 | LOSS SSIM: 0.0337 | LOSS VGG: 0.0342 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 703/800 | BATCH 40/92 | LOSS D: 0.6913 | LOSS G: 0.7842 | LOSS GAN: 0.7109 | LOSS MULTSCALE: 0.0041 | LOSS SSIM: 0.0368 | LOSS VGG: 0.0324 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 703/800 | BATCH 50/92 | LOSS D: 0.6924 | LOSS G: 0.7426 | LOSS GAN: 0.6831 | LOSS MULTSCALE: 0.0050 | LOSS SSIM: 0.0319 | LOSS VGG: 0.0226 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 703/800 | BATCH 60/92 | LOSS D: 0.6949 | LOSS G: 0.7531 | LOSS GAN: 0.6967 | LOSS MULTSCALE: 0.0028 | LOSS SSIM: 0.0304 | LOSS VGG: 0.0232 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 703/800 | BATCH 70/92 | LOSS D: 0.6941 | LOSS G: 0.7684 | LOSS GAN: 0.6858 | LOSS MULTSCALE: 0.0027 | LOSS SSIM: 0.0445 | LOSS VGG: 0.0354 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 703/800 | BATCH 80/92 | LOSS D: 0.6933 | LOSS G: 0.7557 | LOSS GAN: 0.6954 | LOSS MULTSCALE: 0.0024 | LOSS SSIM: 0.0305 | LOSS VGG: 0.0275 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 703/800 | BATCH 90/92 | LOSS D: 0.6933 | LOSS G: 0.7603 | LOSS GAN: 0.6999 | LOSS MULTSCALE: 0.0024 | LOSS SSIM: 0.0336 | LOSS VGG: 0.0244 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 703/800 | BATCH 92/92 | LOSS D: 0.6947 | LOSS G: 0.7907 | LOSS GAN: 0.6974 | LOSS MULTSCALE: 0.0058 | LOSS SSIM: 0.0415 | LOSS VGG: 0.0460 | LOSS MASK: 0.0003 |
# [proposed: 108.317s] TRAIN MEAN LOSS: EPOCH 703/100 | LOSS D: 0.6942 | LOSS G: 0.7816 | LOSS GAN: 0.7004 | LOSS MULTSCALE: 0.0041 | LOSS SSIM: 0.0447 | LOSS VGG: 0.0324 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 704/800 | BATCH 1/92 | LOSS D: 0.6980 | LOSS G: 0.8094 | LOSS GAN: 0.7373 | LOSS MULTSCALE: 0.0038 | LOSS SSIM: 0.0351 | LOSS VGG: 0.0333 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 704/800 | BATCH 10/92 | LOSS D: 0.6976 | LOSS G: 0.7640 | LOSS GAN: 0.7028 | LOSS MULTSCALE: 0.0035 | LOSS SSIM: 0.0311 | LOSS VGG: 0.0265 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 704/800 | BATCH 20/92 | LOSS D: 0.6978 | LOSS G: 0.7621 | LOSS GAN: 0.6889 | LOSS MULTSCALE: 0.0031 | LOSS SSIM: 0.0428 | LOSS VGG: 0.0273 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 704/800 | BATCH 30/92 | LOSS D: 0.6959 | LOSS G: 0.7586 | LOSS GAN: 0.7009 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0310 | LOSS VGG: 0.0243 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 704/800 | BATCH 40/92 | LOSS D: 0.6936 | LOSS G: 0.7359 | LOSS GAN: 0.6868 | LOSS MULTSCALE: 0.0019 | LOSS SSIM: 0.0252 | LOSS VGG: 0.0220 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 704/800 | BATCH 50/92 | LOSS D: 0.6949 | LOSS G: 0.8337 | LOSS GAN: 0.7282 | LOSS MULTSCALE: 0.0049 | LOSS SSIM: 0.0649 | LOSS VGG: 0.0357 | LOSS MASK: 0.0005 |
# [proposed] TRAIN: EPOCH 704/800 | BATCH 60/92 | LOSS D: 0.7011 | LOSS G: 0.7527 | LOSS GAN: 0.6957 | LOSS MULTSCALE: 0.0035 | LOSS SSIM: 0.0272 | LOSS VGG: 0.0264 | LOSS MASK: 0.0006 |
# [proposed] TRAIN: EPOCH 704/800 | BATCH 70/92 | LOSS D: 0.6889 | LOSS G: 0.7665 | LOSS GAN: 0.7041 | LOSS MULTSCALE: 0.0059 | LOSS SSIM: 0.0311 | LOSS VGG: 0.0254 | LOSS MASK: 0.0005 |
# [proposed] TRAIN: EPOCH 704/800 | BATCH 80/92 | LOSS D: 0.6933 | LOSS G: 0.8008 | LOSS GAN: 0.7010 | LOSS MULTSCALE: 0.0042 | LOSS SSIM: 0.0623 | LOSS VGG: 0.0333 | LOSS MASK: 0.0005 |
# [proposed] TRAIN: EPOCH 704/800 | BATCH 90/92 | LOSS D: 0.6934 | LOSS G: 0.7519 | LOSS GAN: 0.7011 | LOSS MULTSCALE: 0.0035 | LOSS SSIM: 0.0252 | LOSS VGG: 0.0221 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 704/800 | BATCH 92/92 | LOSS D: 0.6790 | LOSS G: 0.7641 | LOSS GAN: 0.7000 | LOSS MULTSCALE: 0.0078 | LOSS SSIM: 0.0328 | LOSS VGG: 0.0235 | LOSS MASK: 0.0006 |
# [proposed: 107.654s] TRAIN MEAN LOSS: EPOCH 704/100 | LOSS D: 0.6940 | LOSS G: 0.7727 | LOSS GAN: 0.7043 | LOSS MULTSCALE: 0.0040 | LOSS SSIM: 0.0372 | LOSS VGG: 0.0273 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 705/800 | BATCH 1/92 | LOSS D: 0.6916 | LOSS G: 0.8096 | LOSS GAN: 0.7157 | LOSS MULTSCALE: 0.0076 | LOSS SSIM: 0.0499 | LOSS VGG: 0.0364 | LOSS MASK: 0.0006 |
# [proposed] TRAIN: EPOCH 705/800 | BATCH 10/92 | LOSS D: 0.6870 | LOSS G: 0.7934 | LOSS GAN: 0.6983 | LOSS MULTSCALE: 0.0035 | LOSS SSIM: 0.0609 | LOSS VGG: 0.0308 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 705/800 | BATCH 20/92 | LOSS D: 0.6901 | LOSS G: 0.7616 | LOSS GAN: 0.6990 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0254 | LOSS VGG: 0.0347 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 705/800 | BATCH 30/92 | LOSS D: 0.7002 | LOSS G: 0.7683 | LOSS GAN: 0.7130 | LOSS MULTSCALE: 0.0035 | LOSS SSIM: 0.0292 | LOSS VGG: 0.0227 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 705/800 | BATCH 40/92 | LOSS D: 0.6967 | LOSS G: 0.7814 | LOSS GAN: 0.6917 | LOSS MULTSCALE: 0.0035 | LOSS SSIM: 0.0502 | LOSS VGG: 0.0360 | LOSS MASK: 0.0006 |
# [proposed] TRAIN: EPOCH 705/800 | BATCH 50/92 | LOSS D: 0.6973 | LOSS G: 0.7782 | LOSS GAN: 0.7009 | LOSS MULTSCALE: 0.0029 | LOSS SSIM: 0.0416 | LOSS VGG: 0.0328 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 705/800 | BATCH 60/92 | LOSS D: 0.6942 | LOSS G: 0.7862 | LOSS GAN: 0.6967 | LOSS MULTSCALE: 0.0021 | LOSS SSIM: 0.0578 | LOSS VGG: 0.0297 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 705/800 | BATCH 70/92 | LOSS D: 0.6861 | LOSS G: 0.8007 | LOSS GAN: 0.7227 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0475 | LOSS VGG: 0.0280 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 705/800 | BATCH 80/92 | LOSS D: 0.6878 | LOSS G: 0.8053 | LOSS GAN: 0.7248 | LOSS MULTSCALE: 0.0022 | LOSS SSIM: 0.0410 | LOSS VGG: 0.0373 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 705/800 | BATCH 90/92 | LOSS D: 0.6881 | LOSS G: 0.7589 | LOSS GAN: 0.6912 | LOSS MULTSCALE: 0.0022 | LOSS SSIM: 0.0403 | LOSS VGG: 0.0252 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 705/800 | BATCH 92/92 | LOSS D: 0.6934 | LOSS G: 0.8298 | LOSS GAN: 0.7096 | LOSS MULTSCALE: 0.0049 | LOSS SSIM: 0.0542 | LOSS VGG: 0.0611 | LOSS MASK: 0.0010 |
# [proposed: 107.746s] TRAIN MEAN LOSS: EPOCH 705/100 | LOSS D: 0.6921 | LOSS G: 0.7885 | LOSS GAN: 0.7058 | LOSS MULTSCALE: 0.0034 | LOSS SSIM: 0.0453 | LOSS VGG: 0.0341 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 706/800 | BATCH 1/92 | LOSS D: 0.6991 | LOSS G: 0.7841 | LOSS GAN: 0.7029 | LOSS MULTSCALE: 0.0043 | LOSS SSIM: 0.0493 | LOSS VGG: 0.0276 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 706/800 | BATCH 10/92 | LOSS D: 0.6968 | LOSS G: 0.7707 | LOSS GAN: 0.6845 | LOSS MULTSCALE: 0.0031 | LOSS SSIM: 0.0441 | LOSS VGG: 0.0390 | LOSS MASK: 0.0006 |
# [proposed] TRAIN: EPOCH 706/800 | BATCH 20/92 | LOSS D: 0.6937 | LOSS G: 0.7764 | LOSS GAN: 0.7011 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0404 | LOSS VGG: 0.0324 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 706/800 | BATCH 30/92 | LOSS D: 0.6935 | LOSS G: 0.7957 | LOSS GAN: 0.6993 | LOSS MULTSCALE: 0.0054 | LOSS SSIM: 0.0634 | LOSS VGG: 0.0276 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 706/800 | BATCH 40/92 | LOSS D: 0.6961 | LOSS G: 0.7500 | LOSS GAN: 0.6895 | LOSS MULTSCALE: 0.0049 | LOSS SSIM: 0.0293 | LOSS VGG: 0.0263 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 706/800 | BATCH 50/92 | LOSS D: 0.6842 | LOSS G: 0.8209 | LOSS GAN: 0.7228 | LOSS MULTSCALE: 0.0074 | LOSS SSIM: 0.0566 | LOSS VGG: 0.0341 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 706/800 | BATCH 60/92 | LOSS D: 0.6909 | LOSS G: 0.7692 | LOSS GAN: 0.6978 | LOSS MULTSCALE: 0.0027 | LOSS SSIM: 0.0394 | LOSS VGG: 0.0292 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 706/800 | BATCH 70/92 | LOSS D: 0.6957 | LOSS G: 0.7595 | LOSS GAN: 0.6898 | LOSS MULTSCALE: 0.0041 | LOSS SSIM: 0.0415 | LOSS VGG: 0.0241 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 706/800 | BATCH 80/92 | LOSS D: 0.6949 | LOSS G: 0.7547 | LOSS GAN: 0.7020 | LOSS MULTSCALE: 0.0017 | LOSS SSIM: 0.0250 | LOSS VGG: 0.0260 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 706/800 | BATCH 90/92 | LOSS D: 0.6930 | LOSS G: 0.7422 | LOSS GAN: 0.6808 | LOSS MULTSCALE: 0.0035 | LOSS SSIM: 0.0321 | LOSS VGG: 0.0258 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 706/800 | BATCH 92/92 | LOSS D: 0.6976 | LOSS G: 0.7870 | LOSS GAN: 0.7009 | LOSS MULTSCALE: 0.0036 | LOSS SSIM: 0.0448 | LOSS VGG: 0.0377 | LOSS MASK: 0.0004 |
# [proposed: 107.210s] TRAIN MEAN LOSS: EPOCH 706/100 | LOSS D: 0.6941 | LOSS G: 0.7737 | LOSS GAN: 0.6974 | LOSS MULTSCALE: 0.0039 | LOSS SSIM: 0.0424 | LOSS VGG: 0.0300 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 707/800 | BATCH 1/92 | LOSS D: 0.6817 | LOSS G: 0.8267 | LOSS GAN: 0.7099 | LOSS MULTSCALE: 0.0068 | LOSS SSIM: 0.0757 | LOSS VGG: 0.0343 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 707/800 | BATCH 10/92 | LOSS D: 0.7030 | LOSS G: 0.7474 | LOSS GAN: 0.6947 | LOSS MULTSCALE: 0.0030 | LOSS SSIM: 0.0267 | LOSS VGG: 0.0229 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 707/800 | BATCH 20/92 | LOSS D: 0.6949 | LOSS G: 0.7709 | LOSS GAN: 0.6960 | LOSS MULTSCALE: 0.0024 | LOSS SSIM: 0.0423 | LOSS VGG: 0.0301 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 707/800 | BATCH 30/92 | LOSS D: 0.6948 | LOSS G: 0.7860 | LOSS GAN: 0.7073 | LOSS MULTSCALE: 0.0029 | LOSS SSIM: 0.0381 | LOSS VGG: 0.0377 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 707/800 | BATCH 40/92 | LOSS D: 0.6902 | LOSS G: 0.7742 | LOSS GAN: 0.6985 | LOSS MULTSCALE: 0.0033 | LOSS SSIM: 0.0426 | LOSS VGG: 0.0298 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 707/800 | BATCH 50/92 | LOSS D: 0.6949 | LOSS G: 0.7570 | LOSS GAN: 0.6922 | LOSS MULTSCALE: 0.0022 | LOSS SSIM: 0.0360 | LOSS VGG: 0.0266 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 707/800 | BATCH 60/92 | LOSS D: 0.6927 | LOSS G: 0.7794 | LOSS GAN: 0.7006 | LOSS MULTSCALE: 0.0040 | LOSS SSIM: 0.0489 | LOSS VGG: 0.0260 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 707/800 | BATCH 70/92 | LOSS D: 0.6895 | LOSS G: 0.8111 | LOSS GAN: 0.6959 | LOSS MULTSCALE: 0.0046 | LOSS SSIM: 0.0817 | LOSS VGG: 0.0289 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 707/800 | BATCH 80/92 | LOSS D: 0.6946 | LOSS G: 0.7858 | LOSS GAN: 0.7124 | LOSS MULTSCALE: 0.0036 | LOSS SSIM: 0.0402 | LOSS VGG: 0.0297 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 707/800 | BATCH 90/92 | LOSS D: 0.6926 | LOSS G: 0.7696 | LOSS GAN: 0.6829 | LOSS MULTSCALE: 0.0060 | LOSS SSIM: 0.0484 | LOSS VGG: 0.0322 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 707/800 | BATCH 92/92 | LOSS D: 0.6899 | LOSS G: 0.7480 | LOSS GAN: 0.6908 | LOSS MULTSCALE: 0.0030 | LOSS SSIM: 0.0315 | LOSS VGG: 0.0227 | LOSS MASK: 0.0003 |
# [proposed: 108.119s] TRAIN MEAN LOSS: EPOCH 707/100 | LOSS D: 0.6926 | LOSS G: 0.7778 | LOSS GAN: 0.6983 | LOSS MULTSCALE: 0.0038 | LOSS SSIM: 0.0466 | LOSS VGG: 0.0292 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 708/800 | BATCH 1/92 | LOSS D: 0.6870 | LOSS G: 0.7664 | LOSS GAN: 0.7078 | LOSS MULTSCALE: 0.0030 | LOSS SSIM: 0.0356 | LOSS VGG: 0.0200 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 708/800 | BATCH 10/92 | LOSS D: 0.6918 | LOSS G: 0.7422 | LOSS GAN: 0.6900 | LOSS MULTSCALE: 0.0024 | LOSS SSIM: 0.0288 | LOSS VGG: 0.0210 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 708/800 | BATCH 20/92 | LOSS D: 0.6937 | LOSS G: 0.7674 | LOSS GAN: 0.6997 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0359 | LOSS VGG: 0.0293 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 708/800 | BATCH 30/92 | LOSS D: 0.7004 | LOSS G: 0.7530 | LOSS GAN: 0.7014 | LOSS MULTSCALE: 0.0026 | LOSS SSIM: 0.0254 | LOSS VGG: 0.0237 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 708/800 | BATCH 40/92 | LOSS D: 0.6910 | LOSS G: 0.7765 | LOSS GAN: 0.7013 | LOSS MULTSCALE: 0.0027 | LOSS SSIM: 0.0455 | LOSS VGG: 0.0269 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 708/800 | BATCH 50/92 | LOSS D: 0.6952 | LOSS G: 0.7912 | LOSS GAN: 0.7138 | LOSS MULTSCALE: 0.0028 | LOSS SSIM: 0.0418 | LOSS VGG: 0.0328 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 708/800 | BATCH 60/92 | LOSS D: 0.6911 | LOSS G: 0.7643 | LOSS GAN: 0.7020 | LOSS MULTSCALE: 0.0026 | LOSS SSIM: 0.0357 | LOSS VGG: 0.0240 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 708/800 | BATCH 70/92 | LOSS D: 0.6774 | LOSS G: 0.8144 | LOSS GAN: 0.7621 | LOSS MULTSCALE: 0.0020 | LOSS SSIM: 0.0236 | LOSS VGG: 0.0267 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 708/800 | BATCH 80/92 | LOSS D: 0.6921 | LOSS G: 0.7626 | LOSS GAN: 0.7049 | LOSS MULTSCALE: 0.0022 | LOSS SSIM: 0.0340 | LOSS VGG: 0.0215 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 708/800 | BATCH 90/92 | LOSS D: 0.6931 | LOSS G: 0.7529 | LOSS GAN: 0.7053 | LOSS MULTSCALE: 0.0022 | LOSS SSIM: 0.0257 | LOSS VGG: 0.0197 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 708/800 | BATCH 92/92 | LOSS D: 0.6774 | LOSS G: 0.8972 | LOSS GAN: 0.7419 | LOSS MULTSCALE: 0.0093 | LOSS SSIM: 0.0994 | LOSS VGG: 0.0466 | LOSS MASK: 0.0007 |
# [proposed: 107.809s] TRAIN MEAN LOSS: EPOCH 708/100 | LOSS D: 0.6900 | LOSS G: 0.7807 | LOSS GAN: 0.7118 | LOSS MULTSCALE: 0.0031 | LOSS SSIM: 0.0392 | LOSS VGG: 0.0266 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 709/800 | BATCH 1/92 | LOSS D: 0.7029 | LOSS G: 0.7918 | LOSS GAN: 0.6998 | LOSS MULTSCALE: 0.0056 | LOSS SSIM: 0.0483 | LOSS VGG: 0.0381 | LOSS MASK: 0.0008 |
# [proposed] TRAIN: EPOCH 709/800 | BATCH 10/92 | LOSS D: 0.6985 | LOSS G: 0.7826 | LOSS GAN: 0.7101 | LOSS MULTSCALE: 0.0033 | LOSS SSIM: 0.0480 | LOSS VGG: 0.0211 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 709/800 | BATCH 20/92 | LOSS D: 0.6958 | LOSS G: 0.7658 | LOSS GAN: 0.7071 | LOSS MULTSCALE: 0.0032 | LOSS SSIM: 0.0280 | LOSS VGG: 0.0275 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 709/800 | BATCH 30/92 | LOSS D: 0.6895 | LOSS G: 0.8177 | LOSS GAN: 0.7266 | LOSS MULTSCALE: 0.0042 | LOSS SSIM: 0.0548 | LOSS VGG: 0.0321 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 709/800 | BATCH 40/92 | LOSS D: 0.6914 | LOSS G: 0.7581 | LOSS GAN: 0.7006 | LOSS MULTSCALE: 0.0016 | LOSS SSIM: 0.0286 | LOSS VGG: 0.0273 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 709/800 | BATCH 50/92 | LOSS D: 0.6854 | LOSS G: 0.7596 | LOSS GAN: 0.6966 | LOSS MULTSCALE: 0.0024 | LOSS SSIM: 0.0288 | LOSS VGG: 0.0318 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 709/800 | BATCH 60/92 | LOSS D: 0.6932 | LOSS G: 0.7612 | LOSS GAN: 0.7046 | LOSS MULTSCALE: 0.0021 | LOSS SSIM: 0.0341 | LOSS VGG: 0.0204 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 709/800 | BATCH 70/92 | LOSS D: 0.6938 | LOSS G: 0.7591 | LOSS GAN: 0.6971 | LOSS MULTSCALE: 0.0021 | LOSS SSIM: 0.0325 | LOSS VGG: 0.0273 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 709/800 | BATCH 80/92 | LOSS D: 0.6897 | LOSS G: 0.7767 | LOSS GAN: 0.7118 | LOSS MULTSCALE: 0.0026 | LOSS SSIM: 0.0360 | LOSS VGG: 0.0263 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 709/800 | BATCH 90/92 | LOSS D: 0.6936 | LOSS G: 0.7671 | LOSS GAN: 0.7036 | LOSS MULTSCALE: 0.0057 | LOSS SSIM: 0.0294 | LOSS VGG: 0.0284 | LOSS MASK: 0.0012 |
# [proposed] TRAIN: EPOCH 709/800 | BATCH 92/92 | LOSS D: 0.6951 | LOSS G: 0.8003 | LOSS GAN: 0.7042 | LOSS MULTSCALE: 0.0136 | LOSS SSIM: 0.0471 | LOSS VGG: 0.0355 | LOSS MASK: 0.0035 |
# [proposed: 108.446s] TRAIN MEAN LOSS: EPOCH 709/100 | LOSS D: 0.6935 | LOSS G: 0.7764 | LOSS GAN: 0.7056 | LOSS MULTSCALE: 0.0042 | LOSS SSIM: 0.0378 | LOSS VGG: 0.0287 | LOSS MASK: 0.0007 |
# [proposed] TRAIN: EPOCH 710/800 | BATCH 1/92 | LOSS D: 0.6900 | LOSS G: 0.7976 | LOSS GAN: 0.6973 | LOSS MULTSCALE: 0.0111 | LOSS SSIM: 0.0455 | LOSS VGG: 0.0438 | LOSS MASK: 0.0032 |
# [proposed] TRAIN: EPOCH 710/800 | BATCH 10/92 | LOSS D: 0.6951 | LOSS G: 0.7596 | LOSS GAN: 0.6993 | LOSS MULTSCALE: 0.0021 | LOSS SSIM: 0.0346 | LOSS VGG: 0.0237 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 710/800 | BATCH 20/92 | LOSS D: 0.6889 | LOSS G: 0.7546 | LOSS GAN: 0.6955 | LOSS MULTSCALE: 0.0022 | LOSS SSIM: 0.0319 | LOSS VGG: 0.0250 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 710/800 | BATCH 30/92 | LOSS D: 0.6920 | LOSS G: 0.8105 | LOSS GAN: 0.7304 | LOSS MULTSCALE: 0.0028 | LOSS SSIM: 0.0469 | LOSS VGG: 0.0303 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 710/800 | BATCH 40/92 | LOSS D: 0.6886 | LOSS G: 0.7792 | LOSS GAN: 0.6987 | LOSS MULTSCALE: 0.0031 | LOSS SSIM: 0.0484 | LOSS VGG: 0.0289 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 710/800 | BATCH 50/92 | LOSS D: 0.6993 | LOSS G: 0.7876 | LOSS GAN: 0.6877 | LOSS MULTSCALE: 0.0034 | LOSS SSIM: 0.0632 | LOSS VGG: 0.0333 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 710/800 | BATCH 60/92 | LOSS D: 0.6923 | LOSS G: 0.7559 | LOSS GAN: 0.6920 | LOSS MULTSCALE: 0.0022 | LOSS SSIM: 0.0298 | LOSS VGG: 0.0318 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 710/800 | BATCH 70/92 | LOSS D: 0.6921 | LOSS G: 0.7645 | LOSS GAN: 0.6955 | LOSS MULTSCALE: 0.0024 | LOSS SSIM: 0.0377 | LOSS VGG: 0.0288 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 710/800 | BATCH 80/92 | LOSS D: 0.6963 | LOSS G: 0.7487 | LOSS GAN: 0.6864 | LOSS MULTSCALE: 0.0033 | LOSS SSIM: 0.0295 | LOSS VGG: 0.0294 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 710/800 | BATCH 90/92 | LOSS D: 0.6945 | LOSS G: 0.7864 | LOSS GAN: 0.7139 | LOSS MULTSCALE: 0.0032 | LOSS SSIM: 0.0341 | LOSS VGG: 0.0352 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 710/800 | BATCH 92/92 | LOSS D: 0.6943 | LOSS G: 0.8250 | LOSS GAN: 0.7029 | LOSS MULTSCALE: 0.0066 | LOSS SSIM: 0.0862 | LOSS VGG: 0.0294 | LOSS MASK: 0.0003 |
# [proposed: 108.397s] TRAIN MEAN LOSS: EPOCH 710/100 | LOSS D: 0.6930 | LOSS G: 0.7791 | LOSS GAN: 0.7000 | LOSS MULTSCALE: 0.0039 | LOSS SSIM: 0.0444 | LOSS VGG: 0.0309 | LOSS MASK: 0.0006 |
# [proposed] TRAIN: EPOCH 711/800 | BATCH 1/92 | LOSS D: 0.6955 | LOSS G: 0.7479 | LOSS GAN: 0.6912 | LOSS MULTSCALE: 0.0037 | LOSS SSIM: 0.0272 | LOSS VGG: 0.0258 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 711/800 | BATCH 10/92 | LOSS D: 0.6928 | LOSS G: 0.7723 | LOSS GAN: 0.6960 | LOSS MULTSCALE: 0.0024 | LOSS SSIM: 0.0392 | LOSS VGG: 0.0345 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 711/800 | BATCH 20/92 | LOSS D: 0.6948 | LOSS G: 0.7563 | LOSS GAN: 0.6928 | LOSS MULTSCALE: 0.0036 | LOSS SSIM: 0.0310 | LOSS VGG: 0.0289 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 711/800 | BATCH 30/92 | LOSS D: 0.6913 | LOSS G: 0.7600 | LOSS GAN: 0.6970 | LOSS MULTSCALE: 0.0034 | LOSS SSIM: 0.0371 | LOSS VGG: 0.0226 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 711/800 | BATCH 40/92 | LOSS D: 0.6915 | LOSS G: 0.7690 | LOSS GAN: 0.7076 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0320 | LOSS VGG: 0.0270 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 711/800 | BATCH 50/92 | LOSS D: 0.6870 | LOSS G: 0.7742 | LOSS GAN: 0.7086 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0404 | LOSS VGG: 0.0227 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 711/800 | BATCH 60/92 | LOSS D: 0.7042 | LOSS G: 0.7604 | LOSS GAN: 0.7102 | LOSS MULTSCALE: 0.0019 | LOSS SSIM: 0.0234 | LOSS VGG: 0.0249 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 711/800 | BATCH 70/92 | LOSS D: 0.6909 | LOSS G: 0.7972 | LOSS GAN: 0.6872 | LOSS MULTSCALE: 0.0034 | LOSS SSIM: 0.0733 | LOSS VGG: 0.0333 | LOSS MASK: 0.0005 |
# [proposed] TRAIN: EPOCH 711/800 | BATCH 80/92 | LOSS D: 0.6959 | LOSS G: 0.7766 | LOSS GAN: 0.7109 | LOSS MULTSCALE: 0.0028 | LOSS SSIM: 0.0341 | LOSS VGG: 0.0288 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 711/800 | BATCH 90/92 | LOSS D: 0.6866 | LOSS G: 0.7929 | LOSS GAN: 0.7111 | LOSS MULTSCALE: 0.0030 | LOSS SSIM: 0.0378 | LOSS VGG: 0.0411 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 711/800 | BATCH 92/92 | LOSS D: 0.6998 | LOSS G: 0.7248 | LOSS GAN: 0.6756 | LOSS MULTSCALE: 0.0020 | LOSS SSIM: 0.0287 | LOSS VGG: 0.0185 | LOSS MASK: 0.0003 |
# [proposed: 108.119s] TRAIN MEAN LOSS: EPOCH 711/100 | LOSS D: 0.6936 | LOSS G: 0.7665 | LOSS GAN: 0.6989 | LOSS MULTSCALE: 0.0028 | LOSS SSIM: 0.0367 | LOSS VGG: 0.0280 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 712/800 | BATCH 1/92 | LOSS D: 0.6945 | LOSS G: 0.7849 | LOSS GAN: 0.6997 | LOSS MULTSCALE: 0.0048 | LOSS SSIM: 0.0499 | LOSS VGG: 0.0305 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 712/800 | BATCH 10/92 | LOSS D: 0.6944 | LOSS G: 0.7591 | LOSS GAN: 0.6988 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0324 | LOSS VGG: 0.0254 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 712/800 | BATCH 20/92 | LOSS D: 0.6808 | LOSS G: 0.7909 | LOSS GAN: 0.7272 | LOSS MULTSCALE: 0.0024 | LOSS SSIM: 0.0307 | LOSS VGG: 0.0305 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 712/800 | BATCH 30/92 | LOSS D: 0.6873 | LOSS G: 0.7683 | LOSS GAN: 0.7047 | LOSS MULTSCALE: 0.0028 | LOSS SSIM: 0.0317 | LOSS VGG: 0.0291 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 712/800 | BATCH 40/92 | LOSS D: 0.6864 | LOSS G: 0.7790 | LOSS GAN: 0.6846 | LOSS MULTSCALE: 0.0039 | LOSS SSIM: 0.0545 | LOSS VGG: 0.0360 | LOSS MASK: 0.0006 |
# [proposed] TRAIN: EPOCH 712/800 | BATCH 50/92 | LOSS D: 0.6922 | LOSS G: 0.7891 | LOSS GAN: 0.7221 | LOSS MULTSCALE: 0.0026 | LOSS SSIM: 0.0342 | LOSS VGG: 0.0302 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 712/800 | BATCH 60/92 | LOSS D: 0.6970 | LOSS G: 0.7337 | LOSS GAN: 0.6909 | LOSS MULTSCALE: 0.0015 | LOSS SSIM: 0.0194 | LOSS VGG: 0.0219 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 712/800 | BATCH 70/92 | LOSS D: 0.6958 | LOSS G: 0.7614 | LOSS GAN: 0.6857 | LOSS MULTSCALE: 0.0032 | LOSS SSIM: 0.0407 | LOSS VGG: 0.0318 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 712/800 | BATCH 80/92 | LOSS D: 0.6885 | LOSS G: 0.7659 | LOSS GAN: 0.7019 | LOSS MULTSCALE: 0.0022 | LOSS SSIM: 0.0280 | LOSS VGG: 0.0338 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 712/800 | BATCH 90/92 | LOSS D: 0.7008 | LOSS G: 0.7901 | LOSS GAN: 0.7072 | LOSS MULTSCALE: 0.0029 | LOSS SSIM: 0.0524 | LOSS VGG: 0.0277 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 712/800 | BATCH 92/92 | LOSS D: 0.6890 | LOSS G: 0.7773 | LOSS GAN: 0.6969 | LOSS MULTSCALE: 0.0022 | LOSS SSIM: 0.0374 | LOSS VGG: 0.0408 | LOSS MASK: 0.0004 |
# [proposed: 107.730s] TRAIN MEAN LOSS: EPOCH 712/100 | LOSS D: 0.6915 | LOSS G: 0.7727 | LOSS GAN: 0.7018 | LOSS MULTSCALE: 0.0028 | LOSS SSIM: 0.0374 | LOSS VGG: 0.0307 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 713/800 | BATCH 1/92 | LOSS D: 0.6936 | LOSS G: 0.8077 | LOSS GAN: 0.6988 | LOSS MULTSCALE: 0.0053 | LOSS SSIM: 0.0624 | LOSS VGG: 0.0412 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 713/800 | BATCH 10/92 | LOSS D: 0.6927 | LOSS G: 0.8382 | LOSS GAN: 0.7102 | LOSS MULTSCALE: 0.0081 | LOSS SSIM: 0.0852 | LOSS VGG: 0.0347 | LOSS MASK: 0.0005 |
# [proposed] TRAIN: EPOCH 713/800 | BATCH 20/92 | LOSS D: 0.7040 | LOSS G: 0.7784 | LOSS GAN: 0.7011 | LOSS MULTSCALE: 0.0037 | LOSS SSIM: 0.0444 | LOSS VGG: 0.0291 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 713/800 | BATCH 30/92 | LOSS D: 0.7046 | LOSS G: 0.7534 | LOSS GAN: 0.6826 | LOSS MULTSCALE: 0.0037 | LOSS SSIM: 0.0384 | LOSS VGG: 0.0286 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 713/800 | BATCH 40/92 | LOSS D: 0.6932 | LOSS G: 0.7851 | LOSS GAN: 0.7205 | LOSS MULTSCALE: 0.0029 | LOSS SSIM: 0.0342 | LOSS VGG: 0.0275 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 713/800 | BATCH 50/92 | LOSS D: 0.6949 | LOSS G: 0.8068 | LOSS GAN: 0.6951 | LOSS MULTSCALE: 0.0062 | LOSS SSIM: 0.0740 | LOSS VGG: 0.0315 | LOSS MASK: 0.0011 |
# [proposed] TRAIN: EPOCH 713/800 | BATCH 60/92 | LOSS D: 0.6899 | LOSS G: 0.7879 | LOSS GAN: 0.6997 | LOSS MULTSCALE: 0.0036 | LOSS SSIM: 0.0442 | LOSS VGG: 0.0404 | LOSS MASK: 0.0008 |
# [proposed] TRAIN: EPOCH 713/800 | BATCH 70/92 | LOSS D: 0.6914 | LOSS G: 0.7621 | LOSS GAN: 0.6912 | LOSS MULTSCALE: 0.0033 | LOSS SSIM: 0.0378 | LOSS VGG: 0.0299 | LOSS MASK: 0.0005 |
# [proposed] TRAIN: EPOCH 713/800 | BATCH 80/92 | LOSS D: 0.6925 | LOSS G: 0.7721 | LOSS GAN: 0.7006 | LOSS MULTSCALE: 0.0029 | LOSS SSIM: 0.0416 | LOSS VGG: 0.0270 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 713/800 | BATCH 90/92 | LOSS D: 0.6968 | LOSS G: 0.7545 | LOSS GAN: 0.6966 | LOSS MULTSCALE: 0.0033 | LOSS SSIM: 0.0299 | LOSS VGG: 0.0246 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 713/800 | BATCH 92/92 | LOSS D: 0.6769 | LOSS G: 0.7859 | LOSS GAN: 0.6984 | LOSS MULTSCALE: 0.0039 | LOSS SSIM: 0.0502 | LOSS VGG: 0.0334 | LOSS MASK: 0.0006 |
# [proposed: 107.950s] TRAIN MEAN LOSS: EPOCH 713/100 | LOSS D: 0.6937 | LOSS G: 0.7847 | LOSS GAN: 0.6995 | LOSS MULTSCALE: 0.0043 | LOSS SSIM: 0.0493 | LOSS VGG: 0.0316 | LOSS MASK: 0.0005 |
# [proposed] TRAIN: EPOCH 714/800 | BATCH 1/92 | LOSS D: 0.6934 | LOSS G: 0.7783 | LOSS GAN: 0.6992 | LOSS MULTSCALE: 0.0038 | LOSS SSIM: 0.0480 | LOSS VGG: 0.0272 | LOSS MASK: 0.0005 |
# [proposed] TRAIN: EPOCH 714/800 | BATCH 10/92 | LOSS D: 0.7003 | LOSS G: 0.8050 | LOSS GAN: 0.6972 | LOSS MULTSCALE: 0.0055 | LOSS SSIM: 0.0597 | LOSS VGG: 0.0426 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 714/800 | BATCH 20/92 | LOSS D: 0.6961 | LOSS G: 0.7594 | LOSS GAN: 0.6996 | LOSS MULTSCALE: 0.0022 | LOSS SSIM: 0.0345 | LOSS VGG: 0.0231 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 714/800 | BATCH 30/92 | LOSS D: 0.6914 | LOSS G: 0.7801 | LOSS GAN: 0.6992 | LOSS MULTSCALE: 0.0027 | LOSS SSIM: 0.0393 | LOSS VGG: 0.0388 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 714/800 | BATCH 40/92 | LOSS D: 0.6928 | LOSS G: 0.7709 | LOSS GAN: 0.6996 | LOSS MULTSCALE: 0.0038 | LOSS SSIM: 0.0390 | LOSS VGG: 0.0284 | LOSS MASK: 0.0005 |
# [proposed] TRAIN: EPOCH 714/800 | BATCH 50/92 | LOSS D: 0.6937 | LOSS G: 0.7634 | LOSS GAN: 0.7020 | LOSS MULTSCALE: 0.0018 | LOSS SSIM: 0.0303 | LOSS VGG: 0.0292 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 714/800 | BATCH 60/92 | LOSS D: 0.6869 | LOSS G: 0.7835 | LOSS GAN: 0.7038 | LOSS MULTSCALE: 0.0028 | LOSS SSIM: 0.0440 | LOSS VGG: 0.0329 | LOSS MASK: 0.0005 |
# [proposed] TRAIN: EPOCH 714/800 | BATCH 70/92 | LOSS D: 0.6936 | LOSS G: 0.7593 | LOSS GAN: 0.6940 | LOSS MULTSCALE: 0.0027 | LOSS SSIM: 0.0366 | LOSS VGG: 0.0259 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 714/800 | BATCH 80/92 | LOSS D: 0.6914 | LOSS G: 0.7490 | LOSS GAN: 0.6901 | LOSS MULTSCALE: 0.0028 | LOSS SSIM: 0.0369 | LOSS VGG: 0.0192 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 714/800 | BATCH 90/92 | LOSS D: 0.6939 | LOSS G: 0.7502 | LOSS GAN: 0.7007 | LOSS MULTSCALE: 0.0020 | LOSS SSIM: 0.0243 | LOSS VGG: 0.0233 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 714/800 | BATCH 92/92 | LOSS D: 0.6895 | LOSS G: 0.8560 | LOSS GAN: 0.6931 | LOSS MULTSCALE: 0.0053 | LOSS SSIM: 0.1147 | LOSS VGG: 0.0429 | LOSS MASK: 0.0008 |
# [proposed: 107.607s] TRAIN MEAN LOSS: EPOCH 714/100 | LOSS D: 0.6930 | LOSS G: 0.7777 | LOSS GAN: 0.6980 | LOSS MULTSCALE: 0.0032 | LOSS SSIM: 0.0461 | LOSS VGG: 0.0303 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 715/800 | BATCH 1/92 | LOSS D: 0.6946 | LOSS G: 0.7652 | LOSS GAN: 0.7010 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0332 | LOSS VGG: 0.0286 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 715/800 | BATCH 10/92 | LOSS D: 0.6908 | LOSS G: 0.7822 | LOSS GAN: 0.7021 | LOSS MULTSCALE: 0.0034 | LOSS SSIM: 0.0406 | LOSS VGG: 0.0362 | LOSS MASK: 0.0006 |
# [proposed] TRAIN: EPOCH 715/800 | BATCH 20/92 | LOSS D: 0.6892 | LOSS G: 0.7893 | LOSS GAN: 0.7029 | LOSS MULTSCALE: 0.0024 | LOSS SSIM: 0.0554 | LOSS VGG: 0.0286 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 715/800 | BATCH 30/92 | LOSS D: 0.6961 | LOSS G: 0.8085 | LOSS GAN: 0.7004 | LOSS MULTSCALE: 0.0072 | LOSS SSIM: 0.0714 | LOSS VGG: 0.0295 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 715/800 | BATCH 40/92 | LOSS D: 0.6966 | LOSS G: 0.7665 | LOSS GAN: 0.7020 | LOSS MULTSCALE: 0.0029 | LOSS SSIM: 0.0310 | LOSS VGG: 0.0306 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 715/800 | BATCH 50/92 | LOSS D: 0.6955 | LOSS G: 0.7345 | LOSS GAN: 0.6766 | LOSS MULTSCALE: 0.0023 | LOSS SSIM: 0.0309 | LOSS VGG: 0.0247 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 715/800 | BATCH 60/92 | LOSS D: 0.6835 | LOSS G: 0.7638 | LOSS GAN: 0.7054 | LOSS MULTSCALE: 0.0027 | LOSS SSIM: 0.0299 | LOSS VGG: 0.0258 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 715/800 | BATCH 70/92 | LOSS D: 0.6946 | LOSS G: 0.7664 | LOSS GAN: 0.7096 | LOSS MULTSCALE: 0.0014 | LOSS SSIM: 0.0338 | LOSS VGG: 0.0217 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 715/800 | BATCH 80/92 | LOSS D: 0.6965 | LOSS G: 0.7756 | LOSS GAN: 0.7047 | LOSS MULTSCALE: 0.0023 | LOSS SSIM: 0.0447 | LOSS VGG: 0.0239 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 715/800 | BATCH 90/92 | LOSS D: 0.6968 | LOSS G: 0.7584 | LOSS GAN: 0.6907 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0367 | LOSS VGG: 0.0285 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 715/800 | BATCH 92/92 | LOSS D: 0.6964 | LOSS G: 0.7923 | LOSS GAN: 0.7092 | LOSS MULTSCALE: 0.0030 | LOSS SSIM: 0.0407 | LOSS VGG: 0.0394 | LOSS MASK: 0.0004 |
# [proposed: 107.017s] TRAIN MEAN LOSS: EPOCH 715/100 | LOSS D: 0.6937 | LOSS G: 0.7730 | LOSS GAN: 0.7004 | LOSS MULTSCALE: 0.0030 | LOSS SSIM: 0.0408 | LOSS VGG: 0.0289 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 716/800 | BATCH 1/92 | LOSS D: 0.7006 | LOSS G: 0.7657 | LOSS GAN: 0.7038 | LOSS MULTSCALE: 0.0041 | LOSS SSIM: 0.0348 | LOSS VGG: 0.0230 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 716/800 | BATCH 10/92 | LOSS D: 0.6925 | LOSS G: 0.7926 | LOSS GAN: 0.7000 | LOSS MULTSCALE: 0.0056 | LOSS SSIM: 0.0587 | LOSS VGG: 0.0283 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 716/800 | BATCH 20/92 | LOSS D: 0.6975 | LOSS G: 0.7728 | LOSS GAN: 0.7121 | LOSS MULTSCALE: 0.0038 | LOSS SSIM: 0.0307 | LOSS VGG: 0.0263 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 716/800 | BATCH 30/92 | LOSS D: 0.6873 | LOSS G: 0.7614 | LOSS GAN: 0.7040 | LOSS MULTSCALE: 0.0024 | LOSS SSIM: 0.0315 | LOSS VGG: 0.0234 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 716/800 | BATCH 40/92 | LOSS D: 0.6907 | LOSS G: 0.7247 | LOSS GAN: 0.6815 | LOSS MULTSCALE: 0.0032 | LOSS SSIM: 0.0210 | LOSS VGG: 0.0190 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 716/800 | BATCH 50/92 | LOSS D: 0.6926 | LOSS G: 0.7699 | LOSS GAN: 0.7037 | LOSS MULTSCALE: 0.0022 | LOSS SSIM: 0.0341 | LOSS VGG: 0.0299 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 716/800 | BATCH 60/92 | LOSS D: 0.6969 | LOSS G: 0.7707 | LOSS GAN: 0.6967 | LOSS MULTSCALE: 0.0050 | LOSS SSIM: 0.0476 | LOSS VGG: 0.0213 | LOSS MASK: 0.0005 |
# [proposed] TRAIN: EPOCH 716/800 | BATCH 70/92 | LOSS D: 0.6928 | LOSS G: 0.7795 | LOSS GAN: 0.7015 | LOSS MULTSCALE: 0.0022 | LOSS SSIM: 0.0419 | LOSS VGG: 0.0339 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 716/800 | BATCH 80/92 | LOSS D: 0.6956 | LOSS G: 0.7726 | LOSS GAN: 0.7040 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0433 | LOSS VGG: 0.0228 | LOSS MASK: 0.0006 |
# [proposed] TRAIN: EPOCH 716/800 | BATCH 90/92 | LOSS D: 0.6891 | LOSS G: 0.7926 | LOSS GAN: 0.7159 | LOSS MULTSCALE: 0.0029 | LOSS SSIM: 0.0479 | LOSS VGG: 0.0260 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 716/800 | BATCH 92/92 | LOSS D: 0.6885 | LOSS G: 0.7851 | LOSS GAN: 0.7042 | LOSS MULTSCALE: 0.0042 | LOSS SSIM: 0.0408 | LOSS VGG: 0.0359 | LOSS MASK: 0.0004 |
# [proposed: 107.092s] TRAIN MEAN LOSS: EPOCH 716/100 | LOSS D: 0.6931 | LOSS G: 0.7716 | LOSS GAN: 0.7025 | LOSS MULTSCALE: 0.0035 | LOSS SSIM: 0.0393 | LOSS VGG: 0.0263 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 717/800 | BATCH 1/92 | LOSS D: 0.6979 | LOSS G: 0.7654 | LOSS GAN: 0.7024 | LOSS MULTSCALE: 0.0034 | LOSS SSIM: 0.0364 | LOSS VGG: 0.0232 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 717/800 | BATCH 10/92 | LOSS D: 0.6804 | LOSS G: 0.7640 | LOSS GAN: 0.7009 | LOSS MULTSCALE: 0.0048 | LOSS SSIM: 0.0239 | LOSS VGG: 0.0344 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 717/800 | BATCH 20/92 | LOSS D: 0.6979 | LOSS G: 0.7667 | LOSS GAN: 0.7017 | LOSS MULTSCALE: 0.0026 | LOSS SSIM: 0.0322 | LOSS VGG: 0.0302 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 717/800 | BATCH 30/92 | LOSS D: 0.6843 | LOSS G: 0.7724 | LOSS GAN: 0.7203 | LOSS MULTSCALE: 0.0019 | LOSS SSIM: 0.0249 | LOSS VGG: 0.0252 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 717/800 | BATCH 40/92 | LOSS D: 0.6915 | LOSS G: 0.7565 | LOSS GAN: 0.6945 | LOSS MULTSCALE: 0.0020 | LOSS SSIM: 0.0343 | LOSS VGG: 0.0256 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 717/800 | BATCH 50/92 | LOSS D: 0.6826 | LOSS G: 0.7838 | LOSS GAN: 0.7177 | LOSS MULTSCALE: 0.0021 | LOSS SSIM: 0.0332 | LOSS VGG: 0.0308 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 717/800 | BATCH 60/92 | LOSS D: 0.6809 | LOSS G: 0.7841 | LOSS GAN: 0.7099 | LOSS MULTSCALE: 0.0042 | LOSS SSIM: 0.0373 | LOSS VGG: 0.0328 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 717/800 | BATCH 70/92 | LOSS D: 0.6986 | LOSS G: 0.7528 | LOSS GAN: 0.6903 | LOSS MULTSCALE: 0.0029 | LOSS SSIM: 0.0321 | LOSS VGG: 0.0275 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 717/800 | BATCH 80/92 | LOSS D: 0.6994 | LOSS G: 0.7435 | LOSS GAN: 0.6843 | LOSS MULTSCALE: 0.0017 | LOSS SSIM: 0.0287 | LOSS VGG: 0.0288 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 717/800 | BATCH 90/92 | LOSS D: 0.6957 | LOSS G: 0.7456 | LOSS GAN: 0.6875 | LOSS MULTSCALE: 0.0026 | LOSS SSIM: 0.0317 | LOSS VGG: 0.0238 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 717/800 | BATCH 92/92 | LOSS D: 0.6899 | LOSS G: 0.7789 | LOSS GAN: 0.6931 | LOSS MULTSCALE: 0.0041 | LOSS SSIM: 0.0499 | LOSS VGG: 0.0318 | LOSS MASK: 0.0005 |
# [proposed: 107.048s] TRAIN MEAN LOSS: EPOCH 717/100 | LOSS D: 0.6908 | LOSS G: 0.7649 | LOSS GAN: 0.7002 | LOSS MULTSCALE: 0.0029 | LOSS SSIM: 0.0331 | LOSS VGG: 0.0286 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 718/800 | BATCH 1/92 | LOSS D: 0.6952 | LOSS G: 0.7839 | LOSS GAN: 0.7172 | LOSS MULTSCALE: 0.0034 | LOSS SSIM: 0.0363 | LOSS VGG: 0.0271 | LOSS MASK: 0.0006 |
# [proposed] TRAIN: EPOCH 718/800 | BATCH 10/92 | LOSS D: 0.6972 | LOSS G: 0.7717 | LOSS GAN: 0.6965 | LOSS MULTSCALE: 0.0026 | LOSS SSIM: 0.0367 | LOSS VGG: 0.0359 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 718/800 | BATCH 20/92 | LOSS D: 0.6963 | LOSS G: 0.7703 | LOSS GAN: 0.7011 | LOSS MULTSCALE: 0.0023 | LOSS SSIM: 0.0358 | LOSS VGG: 0.0311 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 718/800 | BATCH 30/92 | LOSS D: 0.6992 | LOSS G: 0.7645 | LOSS GAN: 0.7016 | LOSS MULTSCALE: 0.0027 | LOSS SSIM: 0.0297 | LOSS VGG: 0.0305 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 718/800 | BATCH 40/92 | LOSS D: 0.6943 | LOSS G: 0.7591 | LOSS GAN: 0.6886 | LOSS MULTSCALE: 0.0020 | LOSS SSIM: 0.0396 | LOSS VGG: 0.0288 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 718/800 | BATCH 50/92 | LOSS D: 0.6932 | LOSS G: 0.7704 | LOSS GAN: 0.7073 | LOSS MULTSCALE: 0.0034 | LOSS SSIM: 0.0326 | LOSS VGG: 0.0271 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 718/800 | BATCH 60/92 | LOSS D: 0.6948 | LOSS G: 0.7654 | LOSS GAN: 0.7089 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0257 | LOSS VGG: 0.0282 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 718/800 | BATCH 70/92 | LOSS D: 0.6905 | LOSS G: 0.7705 | LOSS GAN: 0.6986 | LOSS MULTSCALE: 0.0029 | LOSS SSIM: 0.0391 | LOSS VGG: 0.0298 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 718/800 | BATCH 80/92 | LOSS D: 0.6969 | LOSS G: 0.7794 | LOSS GAN: 0.7274 | LOSS MULTSCALE: 0.0031 | LOSS SSIM: 0.0257 | LOSS VGG: 0.0233 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 718/800 | BATCH 90/92 | LOSS D: 0.6886 | LOSS G: 0.8149 | LOSS GAN: 0.7041 | LOSS MULTSCALE: 0.0041 | LOSS SSIM: 0.0688 | LOSS VGG: 0.0379 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 718/800 | BATCH 92/92 | LOSS D: 0.6847 | LOSS G: 0.9144 | LOSS GAN: 0.6985 | LOSS MULTSCALE: 0.0067 | LOSS SSIM: 0.1370 | LOSS VGG: 0.0721 | LOSS MASK: 0.0009 |
# [proposed: 107.143s] TRAIN MEAN LOSS: EPOCH 718/100 | LOSS D: 0.6937 | LOSS G: 0.7877 | LOSS GAN: 0.7045 | LOSS MULTSCALE: 0.0033 | LOSS SSIM: 0.0461 | LOSS VGG: 0.0338 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 719/800 | BATCH 1/92 | LOSS D: 0.6860 | LOSS G: 0.7955 | LOSS GAN: 0.7219 | LOSS MULTSCALE: 0.0049 | LOSS SSIM: 0.0442 | LOSS VGG: 0.0246 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 719/800 | BATCH 10/92 | LOSS D: 0.7112 | LOSS G: 0.8198 | LOSS GAN: 0.7232 | LOSS MULTSCALE: 0.0040 | LOSS SSIM: 0.0557 | LOSS VGG: 0.0369 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 719/800 | BATCH 20/92 | LOSS D: 0.7073 | LOSS G: 0.7582 | LOSS GAN: 0.6982 | LOSS MULTSCALE: 0.0022 | LOSS SSIM: 0.0322 | LOSS VGG: 0.0256 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 719/800 | BATCH 30/92 | LOSS D: 0.6812 | LOSS G: 0.8094 | LOSS GAN: 0.7072 | LOSS MULTSCALE: 0.0032 | LOSS SSIM: 0.0602 | LOSS VGG: 0.0389 | LOSS MASK: 0.0005 |
# [proposed] TRAIN: EPOCH 719/800 | BATCH 40/92 | LOSS D: 0.6926 | LOSS G: 0.7869 | LOSS GAN: 0.7199 | LOSS MULTSCALE: 0.0045 | LOSS SSIM: 0.0305 | LOSS VGG: 0.0320 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 719/800 | BATCH 50/92 | LOSS D: 0.6923 | LOSS G: 0.7530 | LOSS GAN: 0.6967 | LOSS MULTSCALE: 0.0049 | LOSS SSIM: 0.0278 | LOSS VGG: 0.0236 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 719/800 | BATCH 60/92 | LOSS D: 0.6961 | LOSS G: 0.7770 | LOSS GAN: 0.7182 | LOSS MULTSCALE: 0.0022 | LOSS SSIM: 0.0295 | LOSS VGG: 0.0271 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 719/800 | BATCH 70/92 | LOSS D: 0.7002 | LOSS G: 0.7642 | LOSS GAN: 0.6964 | LOSS MULTSCALE: 0.0023 | LOSS SSIM: 0.0362 | LOSS VGG: 0.0293 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 719/800 | BATCH 80/92 | LOSS D: 0.6905 | LOSS G: 0.7552 | LOSS GAN: 0.6898 | LOSS MULTSCALE: 0.0030 | LOSS SSIM: 0.0302 | LOSS VGG: 0.0323 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 719/800 | BATCH 90/92 | LOSS D: 0.6887 | LOSS G: 0.7636 | LOSS GAN: 0.7091 | LOSS MULTSCALE: 0.0027 | LOSS SSIM: 0.0244 | LOSS VGG: 0.0273 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 719/800 | BATCH 92/92 | LOSS D: 0.6788 | LOSS G: 0.7823 | LOSS GAN: 0.7063 | LOSS MULTSCALE: 0.0040 | LOSS SSIM: 0.0374 | LOSS VGG: 0.0347 | LOSS MASK: 0.0006 |
# [proposed: 106.431s] TRAIN MEAN LOSS: EPOCH 719/100 | LOSS D: 0.6932 | LOSS G: 0.7786 | LOSS GAN: 0.7079 | LOSS MULTSCALE: 0.0034 | LOSS SSIM: 0.0371 | LOSS VGG: 0.0302 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 720/800 | BATCH 1/92 | LOSS D: 0.6889 | LOSS G: 0.7599 | LOSS GAN: 0.6821 | LOSS MULTSCALE: 0.0036 | LOSS SSIM: 0.0426 | LOSS VGG: 0.0316 | LOSS MASK: 0.0006 |
# [proposed] TRAIN: EPOCH 720/800 | BATCH 10/92 | LOSS D: 0.6932 | LOSS G: 0.7481 | LOSS GAN: 0.6926 | LOSS MULTSCALE: 0.0035 | LOSS SSIM: 0.0293 | LOSS VGG: 0.0226 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 720/800 | BATCH 20/92 | LOSS D: 0.6936 | LOSS G: 0.7587 | LOSS GAN: 0.7007 | LOSS MULTSCALE: 0.0026 | LOSS SSIM: 0.0305 | LOSS VGG: 0.0249 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 720/800 | BATCH 30/92 | LOSS D: 0.6923 | LOSS G: 0.7678 | LOSS GAN: 0.7129 | LOSS MULTSCALE: 0.0024 | LOSS SSIM: 0.0291 | LOSS VGG: 0.0234 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 720/800 | BATCH 40/92 | LOSS D: 0.6895 | LOSS G: 0.7465 | LOSS GAN: 0.6963 | LOSS MULTSCALE: 0.0028 | LOSS SSIM: 0.0248 | LOSS VGG: 0.0227 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 720/800 | BATCH 50/92 | LOSS D: 0.6969 | LOSS G: 0.7469 | LOSS GAN: 0.6917 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0312 | LOSS VGG: 0.0214 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 720/800 | BATCH 60/92 | LOSS D: 0.6892 | LOSS G: 0.7694 | LOSS GAN: 0.6990 | LOSS MULTSCALE: 0.0030 | LOSS SSIM: 0.0437 | LOSS VGG: 0.0237 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 720/800 | BATCH 70/92 | LOSS D: 0.6964 | LOSS G: 0.7572 | LOSS GAN: 0.6890 | LOSS MULTSCALE: 0.0028 | LOSS SSIM: 0.0414 | LOSS VGG: 0.0241 | LOSS MASK: 0.0005 |
# [proposed] TRAIN: EPOCH 720/800 | BATCH 80/92 | LOSS D: 0.6951 | LOSS G: 0.7737 | LOSS GAN: 0.7167 | LOSS MULTSCALE: 0.0036 | LOSS SSIM: 0.0302 | LOSS VGG: 0.0232 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 720/800 | BATCH 90/92 | LOSS D: 0.6911 | LOSS G: 0.7855 | LOSS GAN: 0.7091 | LOSS MULTSCALE: 0.0028 | LOSS SSIM: 0.0428 | LOSS VGG: 0.0309 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 720/800 | BATCH 92/92 | LOSS D: 0.6946 | LOSS G: 0.8218 | LOSS GAN: 0.7375 | LOSS MULTSCALE: 0.0032 | LOSS SSIM: 0.0404 | LOSS VGG: 0.0406 | LOSS MASK: 0.0003 |
# [proposed: 106.601s] TRAIN MEAN LOSS: EPOCH 720/100 | LOSS D: 0.6928 | LOSS G: 0.7669 | LOSS GAN: 0.7025 | LOSS MULTSCALE: 0.0030 | LOSS SSIM: 0.0351 | LOSS VGG: 0.0263 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 721/800 | BATCH 1/92 | LOSS D: 0.6971 | LOSS G: 0.7946 | LOSS GAN: 0.7229 | LOSS MULTSCALE: 0.0029 | LOSS SSIM: 0.0431 | LOSS VGG: 0.0256 | LOSS MASK: 0.0002 |
# ...
# [proposed: 106.978s] TRAIN MEAN LOSS: EPOCH 793/100 | LOSS D: 0.6946 | LOSS G: 0.7700 | LOSS GAN: 0.7045 | LOSS MULTSCALE: 0.0027 | LOSS SSIM: 0.0380 | LOSS VGG: 0.0249 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 794/800 | BATCH 1/92 | LOSS D: 0.6928 | LOSS G: 0.7587 | LOSS GAN: 0.6949 | LOSS MULTSCALE: 0.0029 | LOSS SSIM: 0.0416 | LOSS VGG: 0.0193 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 794/800 | BATCH 10/92 | LOSS D: 0.6932 | LOSS G: 0.7611 | LOSS GAN: 0.7059 | LOSS MULTSCALE: 0.0020 | LOSS SSIM: 0.0277 | LOSS VGG: 0.0255 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 794/800 | BATCH 20/92 | LOSS D: 0.7022 | LOSS G: 0.7767 | LOSS GAN: 0.7282 | LOSS MULTSCALE: 0.0017 | LOSS SSIM: 0.0247 | LOSS VGG: 0.0220 | LOSS MASK: 0.0001 |
# [proposed] TRAIN: EPOCH 794/800 | BATCH 30/92 | LOSS D: 0.6952 | LOSS G: 0.7594 | LOSS GAN: 0.6819 | LOSS MULTSCALE: 0.0026 | LOSS SSIM: 0.0492 | LOSS VGG: 0.0258 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 794/800 | BATCH 40/92 | LOSS D: 0.6930 | LOSS G: 0.7357 | LOSS GAN: 0.6873 | LOSS MULTSCALE: 0.0018 | LOSS SSIM: 0.0246 | LOSS VGG: 0.0221 | LOSS MASK: 0.0001 |
# [proposed] TRAIN: EPOCH 794/800 | BATCH 50/92 | LOSS D: 0.6949 | LOSS G: 0.7528 | LOSS GAN: 0.7037 | LOSS MULTSCALE: 0.0021 | LOSS SSIM: 0.0236 | LOSS VGG: 0.0233 | LOSS MASK: 0.0001 |
# [proposed] TRAIN: EPOCH 794/800 | BATCH 60/92 | LOSS D: 0.6967 | LOSS G: 0.7570 | LOSS GAN: 0.6971 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0366 | LOSS VGG: 0.0208 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 794/800 | BATCH 70/92 | LOSS D: 0.6901 | LOSS G: 0.7422 | LOSS GAN: 0.6895 | LOSS MULTSCALE: 0.0030 | LOSS SSIM: 0.0258 | LOSS VGG: 0.0240 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 794/800 | BATCH 80/92 | LOSS D: 0.7022 | LOSS G: 0.7417 | LOSS GAN: 0.6838 | LOSS MULTSCALE: 0.0021 | LOSS SSIM: 0.0343 | LOSS VGG: 0.0215 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 794/800 | BATCH 90/92 | LOSS D: 0.6872 | LOSS G: 0.7604 | LOSS GAN: 0.7119 | LOSS MULTSCALE: 0.0035 | LOSS SSIM: 0.0254 | LOSS VGG: 0.0196 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 794/800 | BATCH 92/92 | LOSS D: 0.6922 | LOSS G: 0.7705 | LOSS GAN: 0.6994 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0354 | LOSS VGG: 0.0333 | LOSS MASK: 0.0005 |
# [proposed: 106.605s] TRAIN MEAN LOSS: EPOCH 794/100 | LOSS D: 0.6945 | LOSS G: 0.7560 | LOSS GAN: 0.6985 | LOSS MULTSCALE: 0.0024 | LOSS SSIM: 0.0317 | LOSS VGG: 0.0234 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 795/800 | BATCH 1/92 | LOSS D: 0.6914 | LOSS G: 0.7720 | LOSS GAN: 0.7090 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0307 | LOSS VGG: 0.0298 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 795/800 | BATCH 10/92 | LOSS D: 0.6879 | LOSS G: 0.7616 | LOSS GAN: 0.7006 | LOSS MULTSCALE: 0.0019 | LOSS SSIM: 0.0343 | LOSS VGG: 0.0249 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 795/800 | BATCH 20/92 | LOSS D: 0.7004 | LOSS G: 0.7564 | LOSS GAN: 0.7025 | LOSS MULTSCALE: 0.0017 | LOSS SSIM: 0.0273 | LOSS VGG: 0.0250 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 795/800 | BATCH 30/92 | LOSS D: 0.6992 | LOSS G: 0.7475 | LOSS GAN: 0.7037 | LOSS MULTSCALE: 0.0019 | LOSS SSIM: 0.0210 | LOSS VGG: 0.0209 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 795/800 | BATCH 40/92 | LOSS D: 0.6947 | LOSS G: 0.7628 | LOSS GAN: 0.7117 | LOSS MULTSCALE: 0.0028 | LOSS SSIM: 0.0252 | LOSS VGG: 0.0230 | LOSS MASK: 0.0001 |
# [proposed] TRAIN: EPOCH 795/800 | BATCH 50/92 | LOSS D: 0.6953 | LOSS G: 0.7561 | LOSS GAN: 0.6925 | LOSS MULTSCALE: 0.0031 | LOSS SSIM: 0.0384 | LOSS VGG: 0.0220 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 795/800 | BATCH 60/92 | LOSS D: 0.6952 | LOSS G: 0.7766 | LOSS GAN: 0.6959 | LOSS MULTSCALE: 0.0022 | LOSS SSIM: 0.0511 | LOSS VGG: 0.0274 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 795/800 | BATCH 70/92 | LOSS D: 0.6786 | LOSS G: 0.7810 | LOSS GAN: 0.7197 | LOSS MULTSCALE: 0.0024 | LOSS SSIM: 0.0357 | LOSS VGG: 0.0232 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 795/800 | BATCH 80/92 | LOSS D: 0.6940 | LOSS G: 0.7461 | LOSS GAN: 0.6952 | LOSS MULTSCALE: 0.0014 | LOSS SSIM: 0.0289 | LOSS VGG: 0.0206 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 795/800 | BATCH 90/92 | LOSS D: 0.6973 | LOSS G: 0.7763 | LOSS GAN: 0.6937 | LOSS MULTSCALE: 0.0114 | LOSS SSIM: 0.0475 | LOSS VGG: 0.0238 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 795/800 | BATCH 92/92 | LOSS D: 0.6904 | LOSS G: 0.7833 | LOSS GAN: 0.7236 | LOSS MULTSCALE: 0.0035 | LOSS SSIM: 0.0284 | LOSS VGG: 0.0277 | LOSS MASK: 0.0002 |
# [proposed: 106.323s] TRAIN MEAN LOSS: EPOCH 795/100 | LOSS D: 0.6931 | LOSS G: 0.7654 | LOSS GAN: 0.7044 | LOSS MULTSCALE: 0.0032 | LOSS SSIM: 0.0335 | LOSS VGG: 0.0244 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 796/800 | BATCH 1/92 | LOSS D: 0.6951 | LOSS G: 0.7594 | LOSS GAN: 0.7150 | LOSS MULTSCALE: 0.0037 | LOSS SSIM: 0.0247 | LOSS VGG: 0.0160 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 796/800 | BATCH 10/92 | LOSS D: 0.6905 | LOSS G: 0.7387 | LOSS GAN: 0.6885 | LOSS MULTSCALE: 0.0020 | LOSS SSIM: 0.0257 | LOSS VGG: 0.0225 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 796/800 | BATCH 20/92 | LOSS D: 0.6959 | LOSS G: 0.7557 | LOSS GAN: 0.6956 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0335 | LOSS VGG: 0.0241 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 796/800 | BATCH 30/92 | LOSS D: 0.6957 | LOSS G: 0.7753 | LOSS GAN: 0.7096 | LOSS MULTSCALE: 0.0023 | LOSS SSIM: 0.0323 | LOSS VGG: 0.0311 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 796/800 | BATCH 40/92 | LOSS D: 0.7004 | LOSS G: 0.7673 | LOSS GAN: 0.7031 | LOSS MULTSCALE: 0.0021 | LOSS SSIM: 0.0359 | LOSS VGG: 0.0263 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 796/800 | BATCH 50/92 | LOSS D: 0.6882 | LOSS G: 0.7427 | LOSS GAN: 0.6908 | LOSS MULTSCALE: 0.0018 | LOSS SSIM: 0.0293 | LOSS VGG: 0.0208 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 796/800 | BATCH 60/92 | LOSS D: 0.6936 | LOSS G: 0.7875 | LOSS GAN: 0.6963 | LOSS MULTSCALE: 0.0050 | LOSS SSIM: 0.0568 | LOSS VGG: 0.0294 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 796/800 | BATCH 70/92 | LOSS D: 0.6933 | LOSS G: 0.7665 | LOSS GAN: 0.7155 | LOSS MULTSCALE: 0.0019 | LOSS SSIM: 0.0261 | LOSS VGG: 0.0230 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 796/800 | BATCH 80/92 | LOSS D: 0.6920 | LOSS G: 0.7777 | LOSS GAN: 0.6956 | LOSS MULTSCALE: 0.0023 | LOSS SSIM: 0.0532 | LOSS VGG: 0.0266 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 796/800 | BATCH 90/92 | LOSS D: 0.6976 | LOSS G: 0.7278 | LOSS GAN: 0.6896 | LOSS MULTSCALE: 0.0019 | LOSS SSIM: 0.0181 | LOSS VGG: 0.0182 | LOSS MASK: 0.0001 |
# [proposed] TRAIN: EPOCH 796/800 | BATCH 92/92 | LOSS D: 0.6967 | LOSS G: 0.7452 | LOSS GAN: 0.7010 | LOSS MULTSCALE: 0.0022 | LOSS SSIM: 0.0257 | LOSS VGG: 0.0162 | LOSS MASK: 0.0001 |
# [proposed: 106.540s] TRAIN MEAN LOSS: EPOCH 796/100 | LOSS D: 0.6944 | LOSS G: 0.7585 | LOSS GAN: 0.7001 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0328 | LOSS VGG: 0.0231 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 797/800 | BATCH 1/92 | LOSS D: 0.6931 | LOSS G: 0.7506 | LOSS GAN: 0.6963 | LOSS MULTSCALE: 0.0026 | LOSS SSIM: 0.0274 | LOSS VGG: 0.0243 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 797/800 | BATCH 10/92 | LOSS D: 0.6986 | LOSS G: 0.7617 | LOSS GAN: 0.7052 | LOSS MULTSCALE: 0.0020 | LOSS SSIM: 0.0308 | LOSS VGG: 0.0238 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 797/800 | BATCH 20/92 | LOSS D: 0.6903 | LOSS G: 0.7842 | LOSS GAN: 0.6985 | LOSS MULTSCALE: 0.0039 | LOSS SSIM: 0.0529 | LOSS VGG: 0.0288 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 797/800 | BATCH 30/92 | LOSS D: 0.6941 | LOSS G: 0.7371 | LOSS GAN: 0.6883 | LOSS MULTSCALE: 0.0026 | LOSS SSIM: 0.0266 | LOSS VGG: 0.0195 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 797/800 | BATCH 40/92 | LOSS D: 0.6911 | LOSS G: 0.7415 | LOSS GAN: 0.6918 | LOSS MULTSCALE: 0.0026 | LOSS SSIM: 0.0262 | LOSS VGG: 0.0208 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 797/800 | BATCH 50/92 | LOSS D: 0.6932 | LOSS G: 0.7593 | LOSS GAN: 0.7126 | LOSS MULTSCALE: 0.0019 | LOSS SSIM: 0.0233 | LOSS VGG: 0.0215 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 797/800 | BATCH 60/92 | LOSS D: 0.6924 | LOSS G: 0.7582 | LOSS GAN: 0.7038 | LOSS MULTSCALE: 0.0031 | LOSS SSIM: 0.0264 | LOSS VGG: 0.0249 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 797/800 | BATCH 70/92 | LOSS D: 0.6904 | LOSS G: 0.7351 | LOSS GAN: 0.6851 | LOSS MULTSCALE: 0.0041 | LOSS SSIM: 0.0249 | LOSS VGG: 0.0211 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 797/800 | BATCH 80/92 | LOSS D: 0.6955 | LOSS G: 0.7579 | LOSS GAN: 0.7010 | LOSS MULTSCALE: 0.0019 | LOSS SSIM: 0.0270 | LOSS VGG: 0.0279 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 797/800 | BATCH 90/92 | LOSS D: 0.6940 | LOSS G: 0.7510 | LOSS GAN: 0.7025 | LOSS MULTSCALE: 0.0021 | LOSS SSIM: 0.0262 | LOSS VGG: 0.0202 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 797/800 | BATCH 92/92 | LOSS D: 0.6920 | LOSS G: 0.7695 | LOSS GAN: 0.7077 | LOSS MULTSCALE: 0.0026 | LOSS SSIM: 0.0322 | LOSS VGG: 0.0271 | LOSS MASK: 0.0002 |
# [proposed: 106.928s] TRAIN MEAN LOSS: EPOCH 797/100 | LOSS D: 0.6931 | LOSS G: 0.7551 | LOSS GAN: 0.6994 | LOSS MULTSCALE: 0.0027 | LOSS SSIM: 0.0295 | LOSS VGG: 0.0236 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 798/800 | BATCH 1/92 | LOSS D: 0.6863 | LOSS G: 0.7713 | LOSS GAN: 0.7005 | LOSS MULTSCALE: 0.0034 | LOSS SSIM: 0.0417 | LOSS VGG: 0.0258 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 798/800 | BATCH 10/92 | LOSS D: 0.6890 | LOSS G: 0.7737 | LOSS GAN: 0.7128 | LOSS MULTSCALE: 0.0020 | LOSS SSIM: 0.0339 | LOSS VGG: 0.0250 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 798/800 | BATCH 20/92 | LOSS D: 0.6895 | LOSS G: 0.7492 | LOSS GAN: 0.6909 | LOSS MULTSCALE: 0.0031 | LOSS SSIM: 0.0320 | LOSS VGG: 0.0232 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 798/800 | BATCH 30/92 | LOSS D: 0.6924 | LOSS G: 0.7559 | LOSS GAN: 0.6967 | LOSS MULTSCALE: 0.0021 | LOSS SSIM: 0.0283 | LOSS VGG: 0.0288 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 798/800 | BATCH 40/92 | LOSS D: 0.6977 | LOSS G: 0.7379 | LOSS GAN: 0.6916 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0217 | LOSS VGG: 0.0220 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 798/800 | BATCH 50/92 | LOSS D: 0.6959 | LOSS G: 0.7614 | LOSS GAN: 0.7033 | LOSS MULTSCALE: 0.0034 | LOSS SSIM: 0.0335 | LOSS VGG: 0.0211 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 798/800 | BATCH 60/92 | LOSS D: 0.7012 | LOSS G: 0.7900 | LOSS GAN: 0.7015 | LOSS MULTSCALE: 0.0032 | LOSS SSIM: 0.0518 | LOSS VGG: 0.0335 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 798/800 | BATCH 70/92 | LOSS D: 0.6980 | LOSS G: 0.7680 | LOSS GAN: 0.6925 | LOSS MULTSCALE: 0.0030 | LOSS SSIM: 0.0436 | LOSS VGG: 0.0289 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 798/800 | BATCH 80/92 | LOSS D: 0.6926 | LOSS G: 0.7993 | LOSS GAN: 0.7125 | LOSS MULTSCALE: 0.0031 | LOSS SSIM: 0.0447 | LOSS VGG: 0.0391 | LOSS MASK: 0.0004 |
# [proposed] TRAIN: EPOCH 798/800 | BATCH 90/92 | LOSS D: 0.6951 | LOSS G: 0.7521 | LOSS GAN: 0.7051 | LOSS MULTSCALE: 0.0021 | LOSS SSIM: 0.0253 | LOSS VGG: 0.0197 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 798/800 | BATCH 92/92 | LOSS D: 0.6963 | LOSS G: 0.7407 | LOSS GAN: 0.6904 | LOSS MULTSCALE: 0.0041 | LOSS SSIM: 0.0299 | LOSS VGG: 0.0164 | LOSS MASK: 0.0001 |
# [proposed: 106.507s] TRAIN MEAN LOSS: EPOCH 798/100 | LOSS D: 0.6940 | LOSS G: 0.7636 | LOSS GAN: 0.6998 | LOSS MULTSCALE: 0.0029 | LOSS SSIM: 0.0351 | LOSS VGG: 0.0258 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 799/800 | BATCH 1/92 | LOSS D: 0.6987 | LOSS G: 0.7333 | LOSS GAN: 0.6823 | LOSS MULTSCALE: 0.0021 | LOSS SSIM: 0.0231 | LOSS VGG: 0.0258 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 799/800 | BATCH 10/92 | LOSS D: 0.6962 | LOSS G: 0.7529 | LOSS GAN: 0.6913 | LOSS MULTSCALE: 0.0022 | LOSS SSIM: 0.0332 | LOSS VGG: 0.0261 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 799/800 | BATCH 20/92 | LOSS D: 0.6915 | LOSS G: 0.7642 | LOSS GAN: 0.7130 | LOSS MULTSCALE: 0.0020 | LOSS SSIM: 0.0272 | LOSS VGG: 0.0220 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 799/800 | BATCH 30/92 | LOSS D: 0.6926 | LOSS G: 0.7377 | LOSS GAN: 0.6926 | LOSS MULTSCALE: 0.0017 | LOSS SSIM: 0.0261 | LOSS VGG: 0.0173 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 799/800 | BATCH 40/92 | LOSS D: 0.6948 | LOSS G: 0.7384 | LOSS GAN: 0.6786 | LOSS MULTSCALE: 0.0020 | LOSS SSIM: 0.0302 | LOSS VGG: 0.0276 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 799/800 | BATCH 50/92 | LOSS D: 0.6957 | LOSS G: 0.7231 | LOSS GAN: 0.6814 | LOSS MULTSCALE: 0.0017 | LOSS SSIM: 0.0239 | LOSS VGG: 0.0161 | LOSS MASK: 0.0001 |
# [proposed] TRAIN: EPOCH 799/800 | BATCH 60/92 | LOSS D: 0.6954 | LOSS G: 0.7503 | LOSS GAN: 0.6948 | LOSS MULTSCALE: 0.0016 | LOSS SSIM: 0.0282 | LOSS VGG: 0.0257 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 799/800 | BATCH 70/92 | LOSS D: 0.6945 | LOSS G: 0.7434 | LOSS GAN: 0.6860 | LOSS MULTSCALE: 0.0021 | LOSS SSIM: 0.0291 | LOSS VGG: 0.0262 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 799/800 | BATCH 80/92 | LOSS D: 0.6841 | LOSS G: 0.7851 | LOSS GAN: 0.7182 | LOSS MULTSCALE: 0.0020 | LOSS SSIM: 0.0381 | LOSS VGG: 0.0267 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 799/800 | BATCH 90/92 | LOSS D: 0.6983 | LOSS G: 0.7203 | LOSS GAN: 0.6818 | LOSS MULTSCALE: 0.0018 | LOSS SSIM: 0.0187 | LOSS VGG: 0.0180 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 799/800 | BATCH 92/92 | LOSS D: 0.6835 | LOSS G: 0.7905 | LOSS GAN: 0.7052 | LOSS MULTSCALE: 0.0041 | LOSS SSIM: 0.0535 | LOSS VGG: 0.0277 | LOSS MASK: 0.0005 |
# [proposed: 107.147s] TRAIN MEAN LOSS: EPOCH 799/100 | LOSS D: 0.6932 | LOSS G: 0.7490 | LOSS GAN: 0.6932 | LOSS MULTSCALE: 0.0021 | LOSS SSIM: 0.0301 | LOSS VGG: 0.0236 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 800/800 | BATCH 1/92 | LOSS D: 0.6942 | LOSS G: 0.7787 | LOSS GAN: 0.7258 | LOSS MULTSCALE: 0.0021 | LOSS SSIM: 0.0298 | LOSS VGG: 0.0209 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 800/800 | BATCH 10/92 | LOSS D: 0.6903 | LOSS G: 0.7625 | LOSS GAN: 0.7041 | LOSS MULTSCALE: 0.0021 | LOSS SSIM: 0.0327 | LOSS VGG: 0.0236 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 800/800 | BATCH 20/92 | LOSS D: 0.6965 | LOSS G: 0.7407 | LOSS GAN: 0.6841 | LOSS MULTSCALE: 0.0046 | LOSS SSIM: 0.0307 | LOSS VGG: 0.0214 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 800/800 | BATCH 30/92 | LOSS D: 0.6930 | LOSS G: 0.7620 | LOSS GAN: 0.7095 | LOSS MULTSCALE: 0.0019 | LOSS SSIM: 0.0252 | LOSS VGG: 0.0255 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 800/800 | BATCH 40/92 | LOSS D: 0.6935 | LOSS G: 0.7587 | LOSS GAN: 0.7063 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0302 | LOSS VGG: 0.0197 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 800/800 | BATCH 50/92 | LOSS D: 0.6924 | LOSS G: 0.7283 | LOSS GAN: 0.6800 | LOSS MULTSCALE: 0.0018 | LOSS SSIM: 0.0301 | LOSS VGG: 0.0164 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 800/800 | BATCH 60/92 | LOSS D: 0.6946 | LOSS G: 0.7553 | LOSS GAN: 0.6911 | LOSS MULTSCALE: 0.0034 | LOSS SSIM: 0.0359 | LOSS VGG: 0.0249 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 800/800 | BATCH 70/92 | LOSS D: 0.6951 | LOSS G: 0.7523 | LOSS GAN: 0.7021 | LOSS MULTSCALE: 0.0014 | LOSS SSIM: 0.0276 | LOSS VGG: 0.0211 | LOSS MASK: 0.0002 |
# [proposed] TRAIN: EPOCH 800/800 | BATCH 80/92 | LOSS D: 0.6998 | LOSS G: 0.7629 | LOSS GAN: 0.7065 | LOSS MULTSCALE: 0.0024 | LOSS SSIM: 0.0350 | LOSS VGG: 0.0191 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 800/800 | BATCH 90/92 | LOSS D: 0.6940 | LOSS G: 0.7571 | LOSS GAN: 0.6943 | LOSS MULTSCALE: 0.0024 | LOSS SSIM: 0.0361 | LOSS VGG: 0.0243 | LOSS MASK: 0.0003 |
# [proposed] TRAIN: EPOCH 800/800 | BATCH 92/92 | LOSS D: 0.6779 | LOSS G: 0.7953 | LOSS GAN: 0.7381 | LOSS MULTSCALE: 0.0031 | LOSS SSIM: 0.0265 | LOSS VGG: 0.0277 | LOSS MASK: 0.0002 |
# [proposed: 106.343s] TRAIN MEAN LOSS: EPOCH 800/100 | LOSS D: 0.6928 | LOSS G: 0.7594 | LOSS GAN: 0.7038 | LOSS MULTSCALE: 0.0025 | LOSS SSIM: 0.0309 | LOSS VGG: 0.0222 | LOSS MASK: 0.0002 |
# Training Finished!!: 2025-03-22 06:00:21.405848
