# %%
import sys
import os

# Thêm đường dẫn vào sys.path
sys.path.append('/kaggle/input/raindrop_removal/pytorch/default/1/Raindrop-Removal')

# %% [markdown]
# https://github.com/Hyukju/Raindrop-Removal
#
# https://www.mdpi.com/2227-7390/11/15/3318

# %%
# %cd /kaggle/input/raindrop_removal/pytorch/default/1/Raindrop-Removal
# Out:
# /kaggle/input/raindrop_removal/pytorch/default/1/Raindrop-Removal

# %%
import sys
sys.argv = sys.argv[:1]  # Loại bỏ đối số '-f' của Jupyter

# %% [markdown]
# ## import libaries

# %%
import os
import cv2 
import numpy as np 
import torch
from torch.utils.data import Dataset
from torchvision.transforms import transforms

# %% [markdown]
# ## intialize dataset

# %%
class ToTensor():
    def __call__(self, data):
        for k, v in data.items():
            if v.ndim == 2:
                v = v[:,:,np.newaxis]
            data[k] = torch.from_numpy(v.transpose((2,0,1)).astype('float32'))

        return data

class Normalization():
    def __init__(self, mean=0.5, std=0.5):
        self.mean = mean
        self.std = std 

    def __call__(self, data):
        
        for k, v in data.items():
            data[k] = (v - self.mean) / self.std

        return data


class RandomFlip():
    def __call__(self, data):

        flag_lr = False 
        flag_ud = False 

        if np.random.rand() > 0.5: flag_lr = True
        if np.random.rand() > 0.5: flag_ud = True

        for k, v in data.items():
            if flag_lr: v = np.fliplr(v)
            if flag_ud: v = np.flipud(v)
            data[k] = v

        return data

class RandomCrop():
    def __init__(self, shape):
        self.shape = shape
    
    def __call__(self, data):
        input  = data['input']
        h, w = input.shape[:2]
        new_h, new_w = self.shape

        top = np.random.randint(0, h - new_h)
        left = np.random.randint(0, w - new_w)
        
        id_y = np.arange(top, top + new_h, 1)[:, np.newaxis]
        id_x = np.arange(left, left + new_w, 1)

        for k, v in data.items():
            data[k] = v[id_y, id_x]

        return data

# %%
# class ModelDataset(Dataset):
#     def __init__(self, data_dir, dataA_dir = 'Drop', dataB_dir='Clear', use_transform=False):
#         self.data_dir = data_dir
#         self.use_transform = use_transform
#         self.transform =  transforms.Compose([
#                                             RandomCrop(shape=(256, 256)),
#                                             RandomFlip(),
#                                             Normalization(mean=0.5, std=0.5),
#                                             ToTensor(),
#                                             ])
#         self.dataA_dir = dataA_dir
#         self.dataB_dir = dataB_dir

#         lst_dataA = []
#         for folder in os.listdir(os.path.join(self.data_dir, self.dataA_dir)):
#             folder_path = os.path.join(self.data_dir, self.dataA_dir, folder)
#             if os.path.isdir(folder_path):  # Check if it's a folder
#                 images = sorted([img for img in os.listdir(folder_path) if img.lower().endswith(('jpg', 'png'))])
#                 if images:  # Ensure there is at least one image
#                     lst_dataA.append(os.path.join(folder_path, images[1]))  # Take the first image
#         lst_dataA.sort()

        
#         lst_dataB = []
#         for folder in os.listdir(os.path.join(self.data_dir, self.dataB_dir)):
#             folder_path = os.path.join(self.data_dir, self.dataB_dir, folder)
#             if os.path.isdir(folder_path):  # Check if it's a folder
#                 images = ([img for img in os.listdir(folder_path) if img.lower().endswith(('jpg', 'png'))])
#                 if images:  # Ensure there is at least one image
#                     lst_dataB.append(os.path.join(folder_path, images[1]))  # Take the first image
#         lst_dataB.sort()

#         self.lst_dataA = lst_dataA
#         self.lst_dataB = lst_dataB

#     def __len__(self):
#         return len(self.lst_dataA)

#     def __getitem__(self, index):

#         imgA = cv2.imread(os.path.join(self.data_dir, self.dataA_dir, self.lst_dataA[index]))
#         imgB = cv2.imread(os.path.join(self.data_dir, self.dataB_dir, self.lst_dataB[index]))
#         imgA = cv2.cvtColor(imgA, cv2.COLOR_BGR2RGB)
#         imgB = cv2.cvtColor(imgB, cv2.COLOR_BGR2RGB)

#         if imgA.dtype == np.uint8:
#             imgA = imgA / 255.0  
#         if imgB.dtype == np.uint8:
#             imgB = imgB / 255.0      

#         grayA = cv2.cvtColor(imgA.astype('float32'), cv2.COLOR_RGB2GRAY)
#         grayB = cv2.cvtColor(imgB.astype('float32'), cv2.COLOR_RGB2GRAY)

#         mask = (grayA - grayB) * 0.5 + 0.5
     
#         data = {'input':imgA, 'label':imgB, 'mask':mask}

#         if self.use_transform:
#             data = self.transform(data)

#         return data

# %%
import os
import cv2
import torch
import random
import numpy as np
from torch.utils.data import Dataset

class ModelDataset(Dataset):
    def __init__(self, root_dir='/kaggle/input/ntire2025', subset_day="DayRainDrop_Train_img/DayRainDrop_Train", 
                 subset_night="NightRainDrop_Train_img/NightRainDrop_Train", use_transform=False):
        """
        Initialize the dataset with the same path structure as RaindropDataset.
        :param root_dir: Root directory of the dataset
        :param subset_day: Path to the daytime dataset
        :param subset_night: Path to the nighttime dataset
        :param use_transform: Whether to apply transformations
        """
        self.root_dir = root_dir
        self.use_transform = use_transform

        self.transform = transforms.Compose([
            RandomCrop(shape=(256, 256)),
            RandomFlip(),
            Normalization(mean=0.5, std=0.5),
            ToTensor(),
        ])

        # Daytime paths
        subset_path_day = os.path.join(root_dir, subset_day)
        self.drop_path_day = os.path.join(subset_path_day, "Drop")
        self.clear_path_day = os.path.join(subset_path_day, "Clear")

        # Nighttime paths
        subset_path_night = os.path.join(root_dir, subset_night)
        self.drop_path_night = os.path.join(subset_path_night, "Drop")
        self.clear_path_night = os.path.join(subset_path_night, "Clear")

        # Load image lists
        self.lst_dataA_all = []  # Drop images
        self.lst_dataB_all = []  # Clear images

        # Add day images if they exist
        if os.path.exists(self.drop_path_day) and os.path.exists(self.clear_path_day):
            drop_images_day = sorted([os.path.join(self.drop_path_day, img) 
                                   for img in os.listdir(self.drop_path_day)
                                   if img.lower().endswith(('.png', '.jpg', '.jpeg'))])
            clear_images_day = sorted([os.path.join(self.clear_path_day, img) 
                                    for img in os.listdir(self.clear_path_day)
                                    if img.lower().endswith(('.png', '.jpg', '.jpeg'))])
            self.lst_dataA_all.extend(drop_images_day)
            self.lst_dataB_all.extend(clear_images_day)

        # Add night images if they exist
        if os.path.exists(self.drop_path_night) and os.path.exists(self.clear_path_night):
            drop_images_night = sorted([os.path.join(self.drop_path_night, img) 
                                     for img in os.listdir(self.drop_path_night)
                                     if img.lower().endswith(('.png', '.jpg', '.jpeg'))])
            clear_images_night = sorted([os.path.join(self.clear_path_night, img) 
                                      for img in os.listdir(self.clear_path_night)
                                      if img.lower().endswith(('.png', '.jpg', '.jpeg'))])
            self.lst_dataA_all.extend(drop_images_night)
            self.lst_dataB_all.extend(clear_images_night)

        # Ensure the lists have the same length and corresponding pairs
        assert len(self.lst_dataA_all) == len(self.lst_dataB_all), "Mismatch in number of input and label images"

    def __len__(self):
        return len(self.lst_dataA_all)

    def __getitem__(self, index):
        imgA_path = self.lst_dataA_all[index]
        imgB_path = self.lst_dataB_all[index]

        imgA = cv2.imread(imgA_path)
        imgB = cv2.imread(imgB_path)

        if imgA is None or imgB is None:
            raise ValueError(f"Error loading images: {imgA_path} or {imgB_path}")

        imgA = cv2.cvtColor(imgA, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
        imgB = cv2.cvtColor(imgB, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0

        grayA = cv2.cvtColor(imgA, cv2.COLOR_RGB2GRAY)
        grayB = cv2.cvtColor(imgB, cv2.COLOR_RGB2GRAY)
        mask = (grayA - grayB) * 0.5 + 0.5

        data = {'input': imgA, 'label': imgB, 'mask': mask}

        if self.use_transform:
            data = self.transform(data)

        return data

# %%
import importlib

def find_model(model_name, phase='train', learning_rate=0.002):
    """
    Searches for the specified model inside the 'model' directory.
    Imports the corresponding <model_name>_model.py and instantiates the 'Model' class.
    
    Parameters:
        model_name (str): Name of the model.
        phase (str): Either 'train' or 'test'.
        learning_rate (float): Learning rate for the model.

    Returns:
        model: Instantiated model class or None if not found.
    """
    
    model = None
    model_module_name = f'model.{model_name.lower()}_model'

    print(f'Searching for model: {model_module_name}')
    
    try:
        # Import the model module dynamically
        model_module = importlib.import_module(model_module_name)
    except ModuleNotFoundError:
        print(f'Error: {model_module_name} module not found.')
        return None
    
    target_model_name = 'Model'

    # Search for the class inside the module
    for name, cls in model_module.__dict__.items():
        if name.lower() == target_model_name.lower() and isinstance(cls, type):
            model = cls  # Store the class

    if model is None:
        print(f'Error: {target_model_name} class not found in {model_module_name}.')
        return None

    print(f'{model_module_name}.{target_model_name} successfully created.')
    
    # Instantiate the model with provided parameters
    return model(phase=phase, in_channels=3, out_channels=3, nker=64, lr=learning_rate)

# %% [markdown]
# ## Train

# %%
import os
import argparse
import utils
import torch
import gc
from torch.utils.data import DataLoader
from datetime import datetime
from time import time

def train(args):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    #ckpt_dir = os.path.join(args.ckpt_dir, args.model)
    ckpt_dir=args.ckpt_dir
    os.makedirs(ckpt_dir, exist_ok=True)
    save_dir= args.save_dir
    utils.print_args(args)
    utils.save_log(save_dir, 'train', args)
    
    model = find_model(model_name=args.model, phase='train', learning_rate=args.learning_rate)

    dataset = ModelDataset(
        use_transform=True
    )
    print(len(dataset))
    data_loader = DataLoader(
        dataset=dataset,
        batch_size=args.batch_size,
        shuffle=True,
        num_workers=args.num_workers,
        pin_memory=True  # ✅ Optimizes GPU memory transfer
    )

    max_batches = len(data_loader)
    start_epoch = 1

    # Check for continued training
    if args.train_continue:
        last_epoch = model.load(ckpt_dir,epoch=args.ckpt_epoch)
        if last_epoch > 1:
            start_epoch = last_epoch + 1
            print(f'Continued Training from EPOCH {last_epoch}!!')

    for epoch in range(start_epoch, args.ckpt_epoch+args.max_epochs + 1):
        start_t = time()
        losses_list = []

        for batch, data in enumerate(data_loader, 1):
            # Move data to GPU
            for key in data.keys():
                data[key] = data[key].to(device, non_blocking=True)

            # Forward pass
            model.set_inputs(data)
            model.train_on_batch()  # 🚨 Ensure this function returns loss tensor

            # Backward pass
            #loss.backward()
            #model.optimizer.step()
            #model.optimizer.zero_grad(set_to_none=True)  # ✅ Free memory

            # Print loss for each batch
            if batch == 1 or batch % 10 == 0 or batch == max_batches:
                losses_list.append(model.get_losses())
                utils.print_losses(epoch, args.max_epochs, batch, max_batches, losses_list, title=f'[{args.model}] TRAIN', mode='last')

            # ✅ Free memory after every batch
            del data  # Delete unnecessary variables
            torch.cuda.empty_cache()  # Free GPU cache
            gc.collect()  # Run garbage collection

        # Print loss for each epoch (average of batch losses)
        delay_t = time() - start_t
        utils.print_losses(epoch, args.max_epochs, batch, max_batches, losses_list, title=f'[{args.model}: {delay_t:.3f}s] TRAIN MEAN LOSS', mode='mean')
        utils.save_losses(save_dir, epoch, losses_list, mode='mean')

        # Save images
        utils.save_outputs(
           save_dir=os.path.join(args.save_dir, args.model, 'train'),
           filename=f'{epoch:04d}.png',
           outputs=model.get_outputs(),
           max_display=3
        )

        # Save model every 200 epochs
        if epoch % 2 == 0:
            model.save(save_dir, epoch)

    print(f'Training Finished!!: {datetime.now()}')

if __name__ == '__main__':
    parser = argparse.ArgumentParser(prog='DeRainDrop')             
    
    parser.add_argument('--train_continue', action='store_true', dest='train_continue', default=True)
    parser.add_argument('--model', default='proposed', type=str, dest='model')
    parser.add_argument('--ckpt_epoch', default=580, type=int, dest='ckpt_epoch')
    parser.add_argument('--max_epochs', default=20, type=int, dest='max_epochs')
    parser.add_argument('--batch_size', default=8, type=int, dest='batch_size')
    parser.add_argument('--num_workers', default=8, type=int, dest='num_workers')
    parser.add_argument('--lr', default=0.0001, type=float, dest='learning_rate')
    parser.add_argument('--ckpt_dir', default='/kaggle/input/raindrop-pipeline-train', type=str, dest='ckpt_dir')    
    parser.add_argument('--dataset_dir_day', default='/kaggle/input/ntire2025/DayRainDrop_Train', type=str, dest='dataset_dir_day')
    parser.add_argument('--dataset_dir_night', default='/kaggle/input/ntire2025/NightRainDrop_Train', type=str, dest='dataset_dir_night')    

    parser.add_argument('--save_dir', default='/kaggle/working/', type=str, dest='save_dir')
    
    args = parser.parse_args()
    train(args)
# Out:
# -------------------------------------------
# train_continue: True
# model: proposed
# ckpt_epoch: 580
# max_epochs: 20
# batch_size: 8
# num_workers: 8
# learning_rate: 0.0001
# ckpt_dir: /kaggle/input/raindrop-pipeline-train
# dataset_dir_day: /kaggle/input/ntire2025/DayRainDrop_Train
# dataset_dir_night: /kaggle/input/ntire2025/NightRainDrop_Train
# save_dir: /kaggle/working/
# -------------------------------------------
# Searching for model: model.proposed_model
# model.proposed_model.Model successfully created.
# initialize network with normal
# initialize network with normal
# initialize network with normal
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:02<00:00, 201MB/s]
# 13368
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /kaggle/input/raindrop_removal/pytorch/default/1/Raindrop-Removal/utils.py:54: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_weights = torch.load(os.path.join(ckpt_dir, f'model_epoch{epoch}.pth'))
# Continued Training from EPOCH 580!!
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1/1671 | LOSS D: 0.6921 | LOSS G: 1.1789 | LOSS GAN: 0.7527 | LOSS MULTSCALE: 0.0115 | LOSS SSIM: 0.2639 | LOSS VGG: 0.1507 | LOSS MASK: 0.0029 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 10/1671 | LOSS D: 0.7042 | LOSS G: 1.0909 | LOSS GAN: 0.6893 | LOSS MULTSCALE: 0.0216 | LOSS SSIM: 0.2684 | LOSS VGG: 0.1116 | LOSS MASK: 0.0045 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 20/1671 | LOSS D: 0.6999 | LOSS G: 1.1726 | LOSS GAN: 0.7201 | LOSS MULTSCALE: 0.0157 | LOSS SSIM: 0.2675 | LOSS VGG: 0.1692 | LOSS MASK: 0.0046 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 30/1671 | LOSS D: 0.7171 | LOSS G: 1.0245 | LOSS GAN: 0.6875 | LOSS MULTSCALE: 0.0154 | LOSS SSIM: 0.2287 | LOSS VGG: 0.0930 | LOSS MASK: 0.0044 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 40/1671 | LOSS D: 0.6915 | LOSS G: 1.1307 | LOSS GAN: 0.7429 | LOSS MULTSCALE: 0.0132 | LOSS SSIM: 0.2516 | LOSS VGG: 0.1230 | LOSS MASK: 0.0033 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 50/1671 | LOSS D: 0.7122 | LOSS G: 1.1555 | LOSS GAN: 0.7947 | LOSS MULTSCALE: 0.0173 | LOSS SSIM: 0.2307 | LOSS VGG: 0.1128 | LOSS MASK: 0.0046 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 60/1671 | LOSS D: 0.7097 | LOSS G: 1.1894 | LOSS GAN: 0.7808 | LOSS MULTSCALE: 0.0137 | LOSS SSIM: 0.2641 | LOSS VGG: 0.1308 | LOSS MASK: 0.0030 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 70/1671 | LOSS D: 0.6844 | LOSS G: 1.1857 | LOSS GAN: 0.7136 | LOSS MULTSCALE: 0.0255 | LOSS SSIM: 0.2903 | LOSS VGG: 0.1563 | LOSS MASK: 0.0069 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 80/1671 | LOSS D: 0.7061 | LOSS G: 1.0782 | LOSS GAN: 0.7024 | LOSS MULTSCALE: 0.0124 | LOSS SSIM: 0.2366 | LOSS VGG: 0.1268 | LOSS MASK: 0.0036 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 90/1671 | LOSS D: 0.7089 | LOSS G: 1.0364 | LOSS GAN: 0.6757 | LOSS MULTSCALE: 0.0134 | LOSS SSIM: 0.2485 | LOSS VGG: 0.0987 | LOSS MASK: 0.0034 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 100/1671 | LOSS D: 0.6891 | LOSS G: 1.1567 | LOSS GAN: 0.7428 | LOSS MULTSCALE: 0.0106 | LOSS SSIM: 0.2603 | LOSS VGG: 0.1430 | LOSS MASK: 0.0025 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 110/1671 | LOSS D: 0.6479 | LOSS G: 1.2330 | LOSS GAN: 0.7991 | LOSS MULTSCALE: 0.0143 | LOSS SSIM: 0.2621 | LOSS VGG: 0.1576 | LOSS MASK: 0.0040 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 120/1671 | LOSS D: 0.6906 | LOSS G: 1.2212 | LOSS GAN: 0.8146 | LOSS MULTSCALE: 0.0157 | LOSS SSIM: 0.2417 | LOSS VGG: 0.1493 | LOSS MASK: 0.0041 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 130/1671 | LOSS D: 0.6945 | LOSS G: 1.1331 | LOSS GAN: 0.7167 | LOSS MULTSCALE: 0.0253 | LOSS SSIM: 0.2665 | LOSS VGG: 0.1247 | LOSS MASK: 0.0044 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 140/1671 | LOSS D: 0.6861 | LOSS G: 1.1642 | LOSS GAN: 0.7434 | LOSS MULTSCALE: 0.0128 | LOSS SSIM: 0.2691 | LOSS VGG: 0.1389 | LOSS MASK: 0.0033 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 150/1671 | LOSS D: 0.6201 | LOSS G: 1.2180 | LOSS GAN: 0.7317 | LOSS MULTSCALE: 0.0263 | LOSS SSIM: 0.3009 | LOSS VGG: 0.1591 | LOSS MASK: 0.0051 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 160/1671 | LOSS D: 0.6935 | LOSS G: 1.2287 | LOSS GAN: 0.7937 | LOSS MULTSCALE: 0.0134 | LOSS SSIM: 0.2693 | LOSS VGG: 0.1523 | LOSS MASK: 0.0035 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 170/1671 | LOSS D: 0.7119 | LOSS G: 1.1696 | LOSS GAN: 0.7525 | LOSS MULTSCALE: 0.0143 | LOSS SSIM: 0.2423 | LOSS VGG: 0.1605 | LOSS MASK: 0.0029 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 180/1671 | LOSS D: 0.7103 | LOSS G: 1.0928 | LOSS GAN: 0.7491 | LOSS MULTSCALE: 0.0114 | LOSS SSIM: 0.2611 | LOSS VGG: 0.0711 | LOSS MASK: 0.0029 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 190/1671 | LOSS D: 0.7067 | LOSS G: 1.1712 | LOSS GAN: 0.7020 | LOSS MULTSCALE: 0.0157 | LOSS SSIM: 0.2649 | LOSS VGG: 0.1886 | LOSS MASK: 0.0044 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 200/1671 | LOSS D: 0.7018 | LOSS G: 1.0912 | LOSS GAN: 0.6847 | LOSS MULTSCALE: 0.0113 | LOSS SSIM: 0.2667 | LOSS VGG: 0.1284 | LOSS MASK: 0.0024 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 210/1671 | LOSS D: 0.8242 | LOSS G: 0.8395 | LOSS GAN: 0.4747 | LOSS MULTSCALE: 0.0169 | LOSS SSIM: 0.2357 | LOSS VGG: 0.1122 | LOSS MASK: 0.0042 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 220/1671 | LOSS D: 0.6944 | LOSS G: 0.9866 | LOSS GAN: 0.7028 | LOSS MULTSCALE: 0.0091 | LOSS SSIM: 0.1993 | LOSS VGG: 0.0753 | LOSS MASK: 0.0019 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 230/1671 | LOSS D: 0.6855 | LOSS G: 0.9959 | LOSS GAN: 0.7132 | LOSS MULTSCALE: 0.0082 | LOSS SSIM: 0.2007 | LOSS VGG: 0.0739 | LOSS MASK: 0.0018 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 240/1671 | LOSS D: 0.6585 | LOSS G: 1.1178 | LOSS GAN: 0.7676 | LOSS MULTSCALE: 0.0098 | LOSS SSIM: 0.2267 | LOSS VGG: 0.1138 | LOSS MASK: 0.0025 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 250/1671 | LOSS D: 0.6941 | LOSS G: 1.0617 | LOSS GAN: 0.6458 | LOSS MULTSCALE: 0.0186 | LOSS SSIM: 0.2716 | LOSS VGG: 0.1257 | LOSS MASK: 0.0048 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 260/1671 | LOSS D: 0.6738 | LOSS G: 1.2429 | LOSS GAN: 0.7522 | LOSS MULTSCALE: 0.0180 | LOSS SSIM: 0.2920 | LOSS VGG: 0.1807 | LOSS MASK: 0.0062 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 270/1671 | LOSS D: 0.7042 | LOSS G: 1.1084 | LOSS GAN: 0.7455 | LOSS MULTSCALE: 0.0101 | LOSS SSIM: 0.2607 | LOSS VGG: 0.0921 | LOSS MASK: 0.0022 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 280/1671 | LOSS D: 0.6717 | LOSS G: 1.1367 | LOSS GAN: 0.7460 | LOSS MULTSCALE: 0.0134 | LOSS SSIM: 0.2628 | LOSS VGG: 0.1144 | LOSS MASK: 0.0038 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 290/1671 | LOSS D: 0.7183 | LOSS G: 1.1548 | LOSS GAN: 0.7073 | LOSS MULTSCALE: 0.0161 | LOSS SSIM: 0.2744 | LOSS VGG: 0.1569 | LOSS MASK: 0.0049 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 300/1671 | LOSS D: 0.7157 | LOSS G: 0.9683 | LOSS GAN: 0.5976 | LOSS MULTSCALE: 0.0131 | LOSS SSIM: 0.2469 | LOSS VGG: 0.1107 | LOSS MASK: 0.0036 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 310/1671 | LOSS D: 0.7058 | LOSS G: 1.1500 | LOSS GAN: 0.7322 | LOSS MULTSCALE: 0.0204 | LOSS SSIM: 0.2644 | LOSS VGG: 0.1330 | LOSS MASK: 0.0053 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 320/1671 | LOSS D: 0.6882 | LOSS G: 1.1204 | LOSS GAN: 0.6604 | LOSS MULTSCALE: 0.0257 | LOSS SSIM: 0.3004 | LOSS VGG: 0.1340 | LOSS MASK: 0.0052 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 330/1671 | LOSS D: 0.7444 | LOSS G: 0.9325 | LOSS GAN: 0.6024 | LOSS MULTSCALE: 0.0097 | LOSS SSIM: 0.2232 | LOSS VGG: 0.0971 | LOSS MASK: 0.0027 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 340/1671 | LOSS D: 0.7427 | LOSS G: 1.0634 | LOSS GAN: 0.5351 | LOSS MULTSCALE: 0.0388 | LOSS SSIM: 0.3066 | LOSS VGG: 0.1829 | LOSS MASK: 0.0094 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 350/1671 | LOSS D: 0.6923 | LOSS G: 1.1010 | LOSS GAN: 0.6861 | LOSS MULTSCALE: 0.0220 | LOSS SSIM: 0.2930 | LOSS VGG: 0.0999 | LOSS MASK: 0.0046 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 360/1671 | LOSS D: 0.7037 | LOSS G: 1.1773 | LOSS GAN: 0.7368 | LOSS MULTSCALE: 0.0267 | LOSS SSIM: 0.2906 | LOSS VGG: 0.1232 | LOSS MASK: 0.0060 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 370/1671 | LOSS D: 0.6847 | LOSS G: 1.2290 | LOSS GAN: 0.7538 | LOSS MULTSCALE: 0.0184 | LOSS SSIM: 0.3016 | LOSS VGG: 0.1552 | LOSS MASK: 0.0046 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 380/1671 | LOSS D: 0.6962 | LOSS G: 1.1157 | LOSS GAN: 0.7509 | LOSS MULTSCALE: 0.0107 | LOSS SSIM: 0.2296 | LOSS VGG: 0.1245 | LOSS MASK: 0.0028 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 390/1671 | LOSS D: 0.6786 | LOSS G: 1.1722 | LOSS GAN: 0.6889 | LOSS MULTSCALE: 0.0346 | LOSS SSIM: 0.3242 | LOSS VGG: 0.1246 | LOSS MASK: 0.0101 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 400/1671 | LOSS D: 0.7222 | LOSS G: 0.9153 | LOSS GAN: 0.5824 | LOSS MULTSCALE: 0.0115 | LOSS SSIM: 0.2189 | LOSS VGG: 0.1025 | LOSS MASK: 0.0035 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 410/1671 | LOSS D: 0.6932 | LOSS G: 1.2251 | LOSS GAN: 0.8145 | LOSS MULTSCALE: 0.0173 | LOSS SSIM: 0.2669 | LOSS VGG: 0.1263 | LOSS MASK: 0.0050 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 420/1671 | LOSS D: 0.7000 | LOSS G: 1.1589 | LOSS GAN: 0.6957 | LOSS MULTSCALE: 0.0155 | LOSS SSIM: 0.2725 | LOSS VGG: 0.1752 | LOSS MASK: 0.0037 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 430/1671 | LOSS D: 0.6490 | LOSS G: 1.2311 | LOSS GAN: 0.8061 | LOSS MULTSCALE: 0.0145 | LOSS SSIM: 0.2286 | LOSS VGG: 0.1819 | LOSS MASK: 0.0032 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 440/1671 | LOSS D: 0.7151 | LOSS G: 1.2463 | LOSS GAN: 0.8515 | LOSS MULTSCALE: 0.0144 | LOSS SSIM: 0.2655 | LOSS VGG: 0.1149 | LOSS MASK: 0.0029 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 450/1671 | LOSS D: 0.6942 | LOSS G: 0.9923 | LOSS GAN: 0.7024 | LOSS MULTSCALE: 0.0093 | LOSS SSIM: 0.2215 | LOSS VGG: 0.0591 | LOSS MASK: 0.0019 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 460/1671 | LOSS D: 0.6690 | LOSS G: 1.1469 | LOSS GAN: 0.7059 | LOSS MULTSCALE: 0.0156 | LOSS SSIM: 0.2514 | LOSS VGG: 0.1740 | LOSS MASK: 0.0056 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 470/1671 | LOSS D: 0.6993 | LOSS G: 1.0991 | LOSS GAN: 0.7198 | LOSS MULTSCALE: 0.0109 | LOSS SSIM: 0.2434 | LOSS VGG: 0.1250 | LOSS MASK: 0.0025 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 480/1671 | LOSS D: 0.7012 | LOSS G: 1.1031 | LOSS GAN: 0.6940 | LOSS MULTSCALE: 0.0187 | LOSS SSIM: 0.2707 | LOSS VGG: 0.1197 | LOSS MASK: 0.0047 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 490/1671 | LOSS D: 0.7780 | LOSS G: 0.8792 | LOSS GAN: 0.4883 | LOSS MULTSCALE: 0.0192 | LOSS SSIM: 0.2378 | LOSS VGG: 0.1338 | LOSS MASK: 0.0049 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 500/1671 | LOSS D: 0.6995 | LOSS G: 1.1587 | LOSS GAN: 0.7551 | LOSS MULTSCALE: 0.0313 | LOSS SSIM: 0.2751 | LOSS VGG: 0.0973 | LOSS MASK: 0.0049 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 510/1671 | LOSS D: 0.7127 | LOSS G: 1.0253 | LOSS GAN: 0.6943 | LOSS MULTSCALE: 0.0120 | LOSS SSIM: 0.2053 | LOSS VGG: 0.1137 | LOSS MASK: 0.0025 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 520/1671 | LOSS D: 0.6586 | LOSS G: 1.0816 | LOSS GAN: 0.7582 | LOSS MULTSCALE: 0.0088 | LOSS SSIM: 0.2165 | LOSS VGG: 0.0981 | LOSS MASK: 0.0024 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 530/1671 | LOSS D: 0.6526 | LOSS G: 1.3017 | LOSS GAN: 0.8151 | LOSS MULTSCALE: 0.0191 | LOSS SSIM: 0.2806 | LOSS VGG: 0.1869 | LOSS MASK: 0.0052 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 540/1671 | LOSS D: 0.7154 | LOSS G: 1.1107 | LOSS GAN: 0.6566 | LOSS MULTSCALE: 0.0146 | LOSS SSIM: 0.2668 | LOSS VGG: 0.1727 | LOSS MASK: 0.0036 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 550/1671 | LOSS D: 0.6985 | LOSS G: 1.0824 | LOSS GAN: 0.6492 | LOSS MULTSCALE: 0.0133 | LOSS SSIM: 0.2608 | LOSS VGG: 0.1591 | LOSS MASK: 0.0036 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 560/1671 | LOSS D: 0.7499 | LOSS G: 1.0676 | LOSS GAN: 0.7167 | LOSS MULTSCALE: 0.0100 | LOSS SSIM: 0.2359 | LOSS VGG: 0.1049 | LOSS MASK: 0.0023 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 570/1671 | LOSS D: 0.6935 | LOSS G: 1.2683 | LOSS GAN: 0.7546 | LOSS MULTSCALE: 0.0358 | LOSS SSIM: 0.3473 | LOSS VGG: 0.1306 | LOSS MASK: 0.0102 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 580/1671 | LOSS D: 0.5931 | LOSS G: 1.2801 | LOSS GAN: 0.8123 | LOSS MULTSCALE: 0.0159 | LOSS SSIM: 0.2800 | LOSS VGG: 0.1718 | LOSS MASK: 0.0050 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 590/1671 | LOSS D: 0.7221 | LOSS G: 1.2533 | LOSS GAN: 0.8422 | LOSS MULTSCALE: 0.0105 | LOSS SSIM: 0.2457 | LOSS VGG: 0.1548 | LOSS MASK: 0.0026 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 600/1671 | LOSS D: 0.7373 | LOSS G: 1.0277 | LOSS GAN: 0.5749 | LOSS MULTSCALE: 0.0201 | LOSS SSIM: 0.2796 | LOSS VGG: 0.1531 | LOSS MASK: 0.0054 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 610/1671 | LOSS D: 0.6951 | LOSS G: 1.1780 | LOSS GAN: 0.6840 | LOSS MULTSCALE: 0.0284 | LOSS SSIM: 0.2996 | LOSS VGG: 0.1660 | LOSS MASK: 0.0068 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 620/1671 | LOSS D: 0.7047 | LOSS G: 1.0518 | LOSS GAN: 0.6503 | LOSS MULTSCALE: 0.0163 | LOSS SSIM: 0.2623 | LOSS VGG: 0.1228 | LOSS MASK: 0.0039 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 630/1671 | LOSS D: 0.6911 | LOSS G: 1.0833 | LOSS GAN: 0.6883 | LOSS MULTSCALE: 0.0203 | LOSS SSIM: 0.2604 | LOSS VGG: 0.1143 | LOSS MASK: 0.0058 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 640/1671 | LOSS D: 0.6836 | LOSS G: 1.1473 | LOSS GAN: 0.7241 | LOSS MULTSCALE: 0.0216 | LOSS SSIM: 0.2726 | LOSS VGG: 0.1290 | LOSS MASK: 0.0070 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 650/1671 | LOSS D: 0.6931 | LOSS G: 1.1211 | LOSS GAN: 0.7311 | LOSS MULTSCALE: 0.0211 | LOSS SSIM: 0.2856 | LOSS VGG: 0.0833 | LOSS MASK: 0.0041 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 660/1671 | LOSS D: 0.6726 | LOSS G: 1.1452 | LOSS GAN: 0.7195 | LOSS MULTSCALE: 0.0129 | LOSS SSIM: 0.2465 | LOSS VGG: 0.1662 | LOSS MASK: 0.0039 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 670/1671 | LOSS D: 0.7187 | LOSS G: 1.0745 | LOSS GAN: 0.6553 | LOSS MULTSCALE: 0.0196 | LOSS SSIM: 0.2615 | LOSS VGG: 0.1381 | LOSS MASK: 0.0047 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 680/1671 | LOSS D: 0.6911 | LOSS G: 1.1263 | LOSS GAN: 0.7725 | LOSS MULTSCALE: 0.0106 | LOSS SSIM: 0.2306 | LOSS VGG: 0.1127 | LOSS MASK: 0.0019 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 690/1671 | LOSS D: 0.7082 | LOSS G: 1.0326 | LOSS GAN: 0.6359 | LOSS MULTSCALE: 0.0263 | LOSS SSIM: 0.2867 | LOSS VGG: 0.0837 | LOSS MASK: 0.0069 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 700/1671 | LOSS D: 0.6227 | LOSS G: 1.1868 | LOSS GAN: 0.8062 | LOSS MULTSCALE: 0.0129 | LOSS SSIM: 0.2357 | LOSS VGG: 0.1320 | LOSS MASK: 0.0039 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 710/1671 | LOSS D: 0.7008 | LOSS G: 1.1431 | LOSS GAN: 0.7480 | LOSS MULTSCALE: 0.0163 | LOSS SSIM: 0.2877 | LOSS VGG: 0.0911 | LOSS MASK: 0.0030 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 720/1671 | LOSS D: 0.7163 | LOSS G: 1.0610 | LOSS GAN: 0.6673 | LOSS MULTSCALE: 0.0223 | LOSS SSIM: 0.2707 | LOSS VGG: 0.1007 | LOSS MASK: 0.0067 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 730/1671 | LOSS D: 0.7030 | LOSS G: 1.1716 | LOSS GAN: 0.7175 | LOSS MULTSCALE: 0.0206 | LOSS SSIM: 0.2682 | LOSS VGG: 0.1654 | LOSS MASK: 0.0056 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 740/1671 | LOSS D: 0.6945 | LOSS G: 1.1753 | LOSS GAN: 0.7330 | LOSS MULTSCALE: 0.0175 | LOSS SSIM: 0.2631 | LOSS VGG: 0.1616 | LOSS MASK: 0.0045 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 750/1671 | LOSS D: 0.6818 | LOSS G: 1.1710 | LOSS GAN: 0.7057 | LOSS MULTSCALE: 0.0241 | LOSS SSIM: 0.3077 | LOSS VGG: 0.1335 | LOSS MASK: 0.0051 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 760/1671 | LOSS D: 0.5931 | LOSS G: 1.3559 | LOSS GAN: 0.8538 | LOSS MULTSCALE: 0.0216 | LOSS SSIM: 0.3128 | LOSS VGG: 0.1677 | LOSS MASK: 0.0056 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 770/1671 | LOSS D: 0.6438 | LOSS G: 1.1978 | LOSS GAN: 0.7550 | LOSS MULTSCALE: 0.0168 | LOSS SSIM: 0.2736 | LOSS VGG: 0.1524 | LOSS MASK: 0.0053 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 780/1671 | LOSS D: 0.6973 | LOSS G: 1.1189 | LOSS GAN: 0.6989 | LOSS MULTSCALE: 0.0170 | LOSS SSIM: 0.2730 | LOSS VGG: 0.1300 | LOSS MASK: 0.0041 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 790/1671 | LOSS D: 0.6924 | LOSS G: 1.0681 | LOSS GAN: 0.6907 | LOSS MULTSCALE: 0.0123 | LOSS SSIM: 0.2526 | LOSS VGG: 0.1125 | LOSS MASK: 0.0029 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 800/1671 | LOSS D: 0.6953 | LOSS G: 1.1759 | LOSS GAN: 0.7437 | LOSS MULTSCALE: 0.0143 | LOSS SSIM: 0.2673 | LOSS VGG: 0.1506 | LOSS MASK: 0.0038 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 810/1671 | LOSS D: 0.6982 | LOSS G: 1.0175 | LOSS GAN: 0.6931 | LOSS MULTSCALE: 0.0088 | LOSS SSIM: 0.2063 | LOSS VGG: 0.1093 | LOSS MASK: 0.0021 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 820/1671 | LOSS D: 0.7008 | LOSS G: 1.0338 | LOSS GAN: 0.6969 | LOSS MULTSCALE: 0.0165 | LOSS SSIM: 0.2271 | LOSS VGG: 0.0934 | LOSS MASK: 0.0039 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 830/1671 | LOSS D: 0.6575 | LOSS G: 1.3281 | LOSS GAN: 0.7579 | LOSS MULTSCALE: 0.0199 | LOSS SSIM: 0.3019 | LOSS VGG: 0.2484 | LOSS MASK: 0.0064 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 840/1671 | LOSS D: 0.6920 | LOSS G: 1.1129 | LOSS GAN: 0.7625 | LOSS MULTSCALE: 0.0118 | LOSS SSIM: 0.2322 | LOSS VGG: 0.1064 | LOSS MASK: 0.0035 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 850/1671 | LOSS D: 0.6928 | LOSS G: 1.0646 | LOSS GAN: 0.6797 | LOSS MULTSCALE: 0.0146 | LOSS SSIM: 0.2525 | LOSS VGG: 0.1178 | LOSS MASK: 0.0026 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 860/1671 | LOSS D: 0.6771 | LOSS G: 1.0901 | LOSS GAN: 0.7273 | LOSS MULTSCALE: 0.0141 | LOSS SSIM: 0.2444 | LOSS VGG: 0.1043 | LOSS MASK: 0.0033 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 870/1671 | LOSS D: 0.7079 | LOSS G: 1.1235 | LOSS GAN: 0.7649 | LOSS MULTSCALE: 0.0135 | LOSS SSIM: 0.2169 | LOSS VGG: 0.1282 | LOSS MASK: 0.0038 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 880/1671 | LOSS D: 0.6881 | LOSS G: 1.1464 | LOSS GAN: 0.7166 | LOSS MULTSCALE: 0.0242 | LOSS SSIM: 0.2727 | LOSS VGG: 0.1329 | LOSS MASK: 0.0057 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 890/1671 | LOSS D: 0.6904 | LOSS G: 1.1091 | LOSS GAN: 0.7161 | LOSS MULTSCALE: 0.0173 | LOSS SSIM: 0.2531 | LOSS VGG: 0.1225 | LOSS MASK: 0.0039 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 900/1671 | LOSS D: 0.7077 | LOSS G: 1.0243 | LOSS GAN: 0.6615 | LOSS MULTSCALE: 0.0123 | LOSS SSIM: 0.2402 | LOSS VGG: 0.1103 | LOSS MASK: 0.0029 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 910/1671 | LOSS D: 0.7010 | LOSS G: 1.2076 | LOSS GAN: 0.7830 | LOSS MULTSCALE: 0.0155 | LOSS SSIM: 0.2786 | LOSS VGG: 0.1304 | LOSS MASK: 0.0033 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 920/1671 | LOSS D: 0.6834 | LOSS G: 1.1385 | LOSS GAN: 0.7195 | LOSS MULTSCALE: 0.0108 | LOSS SSIM: 0.2562 | LOSS VGG: 0.1520 | LOSS MASK: 0.0029 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 930/1671 | LOSS D: 0.5843 | LOSS G: 1.2104 | LOSS GAN: 0.7474 | LOSS MULTSCALE: 0.0214 | LOSS SSIM: 0.2882 | LOSS VGG: 0.1534 | LOSS MASK: 0.0076 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 940/1671 | LOSS D: 0.7020 | LOSS G: 1.1625 | LOSS GAN: 0.7294 | LOSS MULTSCALE: 0.0220 | LOSS SSIM: 0.2723 | LOSS VGG: 0.1388 | LOSS MASK: 0.0049 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 950/1671 | LOSS D: 0.6439 | LOSS G: 1.0681 | LOSS GAN: 0.6989 | LOSS MULTSCALE: 0.0130 | LOSS SSIM: 0.2361 | LOSS VGG: 0.1201 | LOSS MASK: 0.0047 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 960/1671 | LOSS D: 0.5480 | LOSS G: 1.3322 | LOSS GAN: 0.7953 | LOSS MULTSCALE: 0.0168 | LOSS SSIM: 0.2896 | LOSS VGG: 0.2305 | LOSS MASK: 0.0047 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 970/1671 | LOSS D: 0.7014 | LOSS G: 1.1399 | LOSS GAN: 0.7499 | LOSS MULTSCALE: 0.0140 | LOSS SSIM: 0.2344 | LOSS VGG: 0.1416 | LOSS MASK: 0.0039 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 980/1671 | LOSS D: 0.6636 | LOSS G: 1.1371 | LOSS GAN: 0.7078 | LOSS MULTSCALE: 0.0164 | LOSS SSIM: 0.2783 | LOSS VGG: 0.1345 | LOSS MASK: 0.0038 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 990/1671 | LOSS D: 0.7037 | LOSS G: 1.0752 | LOSS GAN: 0.7237 | LOSS MULTSCALE: 0.0134 | LOSS SSIM: 0.2377 | LOSS VGG: 0.1004 | LOSS MASK: 0.0038 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1000/1671 | LOSS D: 0.6790 | LOSS G: 1.1293 | LOSS GAN: 0.7328 | LOSS MULTSCALE: 0.0236 | LOSS SSIM: 0.2670 | LOSS VGG: 0.1059 | LOSS MASK: 0.0063 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1010/1671 | LOSS D: 0.6874 | LOSS G: 1.1026 | LOSS GAN: 0.6873 | LOSS MULTSCALE: 0.0175 | LOSS SSIM: 0.2725 | LOSS VGG: 0.1253 | LOSS MASK: 0.0049 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1020/1671 | LOSS D: 0.6896 | LOSS G: 1.1774 | LOSS GAN: 0.7954 | LOSS MULTSCALE: 0.0134 | LOSS SSIM: 0.2301 | LOSS VGG: 0.1385 | LOSS MASK: 0.0038 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1030/1671 | LOSS D: 0.6835 | LOSS G: 1.2244 | LOSS GAN: 0.7702 | LOSS MULTSCALE: 0.0256 | LOSS SSIM: 0.2777 | LOSS VGG: 0.1509 | LOSS MASK: 0.0078 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1040/1671 | LOSS D: 0.6996 | LOSS G: 1.1608 | LOSS GAN: 0.7739 | LOSS MULTSCALE: 0.0151 | LOSS SSIM: 0.2569 | LOSS VGG: 0.1149 | LOSS MASK: 0.0041 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1050/1671 | LOSS D: 0.6868 | LOSS G: 1.1106 | LOSS GAN: 0.6851 | LOSS MULTSCALE: 0.0141 | LOSS SSIM: 0.2513 | LOSS VGG: 0.1602 | LOSS MASK: 0.0040 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1060/1671 | LOSS D: 0.6986 | LOSS G: 1.1518 | LOSS GAN: 0.7640 | LOSS MULTSCALE: 0.0152 | LOSS SSIM: 0.2585 | LOSS VGG: 0.1141 | LOSS MASK: 0.0027 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1070/1671 | LOSS D: 0.6676 | LOSS G: 1.1835 | LOSS GAN: 0.8135 | LOSS MULTSCALE: 0.0127 | LOSS SSIM: 0.2530 | LOSS VGG: 0.1044 | LOSS MASK: 0.0038 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1080/1671 | LOSS D: 0.7118 | LOSS G: 1.0345 | LOSS GAN: 0.7146 | LOSS MULTSCALE: 0.0098 | LOSS SSIM: 0.2098 | LOSS VGG: 0.1002 | LOSS MASK: 0.0021 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1090/1671 | LOSS D: 0.7533 | LOSS G: 0.9390 | LOSS GAN: 0.5611 | LOSS MULTSCALE: 0.0120 | LOSS SSIM: 0.2394 | LOSS VGG: 0.1264 | LOSS MASK: 0.0037 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1100/1671 | LOSS D: 0.6835 | LOSS G: 1.3004 | LOSS GAN: 0.7884 | LOSS MULTSCALE: 0.0233 | LOSS SSIM: 0.3189 | LOSS VGG: 0.1698 | LOSS MASK: 0.0062 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1110/1671 | LOSS D: 0.6977 | LOSS G: 1.0939 | LOSS GAN: 0.6918 | LOSS MULTSCALE: 0.0186 | LOSS SSIM: 0.2734 | LOSS VGG: 0.1101 | LOSS MASK: 0.0036 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1120/1671 | LOSS D: 0.6979 | LOSS G: 1.0616 | LOSS GAN: 0.6306 | LOSS MULTSCALE: 0.0307 | LOSS SSIM: 0.2625 | LOSS VGG: 0.1379 | LOSS MASK: 0.0090 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1130/1671 | LOSS D: 0.7025 | LOSS G: 1.1106 | LOSS GAN: 0.7943 | LOSS MULTSCALE: 0.0095 | LOSS SSIM: 0.2212 | LOSS VGG: 0.0857 | LOSS MASK: 0.0019 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1140/1671 | LOSS D: 0.6706 | LOSS G: 1.1835 | LOSS GAN: 0.7704 | LOSS MULTSCALE: 0.0127 | LOSS SSIM: 0.2567 | LOSS VGG: 0.1438 | LOSS MASK: 0.0036 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1150/1671 | LOSS D: 0.7042 | LOSS G: 1.0302 | LOSS GAN: 0.7261 | LOSS MULTSCALE: 0.0079 | LOSS SSIM: 0.2033 | LOSS VGG: 0.0928 | LOSS MASK: 0.0020 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1160/1671 | LOSS D: 0.6990 | LOSS G: 1.1215 | LOSS GAN: 0.7557 | LOSS MULTSCALE: 0.0118 | LOSS SSIM: 0.2298 | LOSS VGG: 0.1242 | LOSS MASK: 0.0034 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1170/1671 | LOSS D: 0.6366 | LOSS G: 1.2720 | LOSS GAN: 0.8427 | LOSS MULTSCALE: 0.0164 | LOSS SSIM: 0.2860 | LOSS VGG: 0.1269 | LOSS MASK: 0.0041 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1180/1671 | LOSS D: 0.6912 | LOSS G: 1.2201 | LOSS GAN: 0.7184 | LOSS MULTSCALE: 0.0316 | LOSS SSIM: 0.2812 | LOSS VGG: 0.1889 | LOSS MASK: 0.0082 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1190/1671 | LOSS D: 0.7103 | LOSS G: 1.0207 | LOSS GAN: 0.6586 | LOSS MULTSCALE: 0.0102 | LOSS SSIM: 0.2401 | LOSS VGG: 0.1118 | LOSS MASK: 0.0024 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1200/1671 | LOSS D: 0.6975 | LOSS G: 1.0735 | LOSS GAN: 0.7284 | LOSS MULTSCALE: 0.0102 | LOSS SSIM: 0.2246 | LOSS VGG: 0.1103 | LOSS MASK: 0.0026 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1210/1671 | LOSS D: 0.7065 | LOSS G: 1.2143 | LOSS GAN: 0.6757 | LOSS MULTSCALE: 0.0379 | LOSS SSIM: 0.3030 | LOSS VGG: 0.1976 | LOSS MASK: 0.0072 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1220/1671 | LOSS D: 0.6959 | LOSS G: 1.1012 | LOSS GAN: 0.6855 | LOSS MULTSCALE: 0.0173 | LOSS SSIM: 0.2602 | LOSS VGG: 0.1382 | LOSS MASK: 0.0047 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1230/1671 | LOSS D: 0.6754 | LOSS G: 1.2997 | LOSS GAN: 0.7255 | LOSS MULTSCALE: 0.0266 | LOSS SSIM: 0.3503 | LOSS VGG: 0.1974 | LOSS MASK: 0.0075 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1240/1671 | LOSS D: 0.6889 | LOSS G: 1.0748 | LOSS GAN: 0.7032 | LOSS MULTSCALE: 0.0117 | LOSS SSIM: 0.2546 | LOSS VGG: 0.1053 | LOSS MASK: 0.0030 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1250/1671 | LOSS D: 0.6976 | LOSS G: 1.2730 | LOSS GAN: 0.8148 | LOSS MULTSCALE: 0.0290 | LOSS SSIM: 0.3080 | LOSS VGG: 0.1212 | LOSS MASK: 0.0082 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1260/1671 | LOSS D: 0.6993 | LOSS G: 1.2978 | LOSS GAN: 0.8915 | LOSS MULTSCALE: 0.0156 | LOSS SSIM: 0.2677 | LOSS VGG: 0.1231 | LOSS MASK: 0.0041 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1270/1671 | LOSS D: 0.7535 | LOSS G: 1.1410 | LOSS GAN: 0.7400 | LOSS MULTSCALE: 0.0163 | LOSS SSIM: 0.2458 | LOSS VGG: 0.1388 | LOSS MASK: 0.0048 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1280/1671 | LOSS D: 0.6836 | LOSS G: 1.0852 | LOSS GAN: 0.7525 | LOSS MULTSCALE: 0.0090 | LOSS SSIM: 0.2280 | LOSS VGG: 0.0957 | LOSS MASK: 0.0025 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1290/1671 | LOSS D: 0.7062 | LOSS G: 1.1090 | LOSS GAN: 0.7103 | LOSS MULTSCALE: 0.0109 | LOSS SSIM: 0.2563 | LOSS VGG: 0.1316 | LOSS MASK: 0.0028 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1300/1671 | LOSS D: 0.6462 | LOSS G: 1.1998 | LOSS GAN: 0.8160 | LOSS MULTSCALE: 0.0095 | LOSS SSIM: 0.2505 | LOSS VGG: 0.1238 | LOSS MASK: 0.0027 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1310/1671 | LOSS D: 0.7104 | LOSS G: 1.1073 | LOSS GAN: 0.7506 | LOSS MULTSCALE: 0.0096 | LOSS SSIM: 0.2338 | LOSS VGG: 0.1132 | LOSS MASK: 0.0025 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1320/1671 | LOSS D: 0.6532 | LOSS G: 1.4161 | LOSS GAN: 0.8341 | LOSS MULTSCALE: 0.0365 | LOSS SSIM: 0.3165 | LOSS VGG: 0.2290 | LOSS MASK: 0.0103 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1330/1671 | LOSS D: 0.6721 | LOSS G: 1.0749 | LOSS GAN: 0.7132 | LOSS MULTSCALE: 0.0122 | LOSS SSIM: 0.2301 | LOSS VGG: 0.1195 | LOSS MASK: 0.0034 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1340/1671 | LOSS D: 0.6641 | LOSS G: 1.0891 | LOSS GAN: 0.7180 | LOSS MULTSCALE: 0.0097 | LOSS SSIM: 0.2139 | LOSS VGG: 0.1474 | LOSS MASK: 0.0028 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1350/1671 | LOSS D: 0.7120 | LOSS G: 1.0292 | LOSS GAN: 0.6888 | LOSS MULTSCALE: 0.0109 | LOSS SSIM: 0.2464 | LOSS VGG: 0.0831 | LOSS MASK: 0.0029 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1360/1671 | LOSS D: 0.6459 | LOSS G: 1.3178 | LOSS GAN: 0.8090 | LOSS MULTSCALE: 0.0191 | LOSS SSIM: 0.3092 | LOSS VGG: 0.1804 | LOSS MASK: 0.0046 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1370/1671 | LOSS D: 0.6898 | LOSS G: 1.0181 | LOSS GAN: 0.6929 | LOSS MULTSCALE: 0.0092 | LOSS SSIM: 0.2158 | LOSS VGG: 0.1002 | LOSS MASK: 0.0030 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1380/1671 | LOSS D: 0.6819 | LOSS G: 1.1658 | LOSS GAN: 0.7448 | LOSS MULTSCALE: 0.0130 | LOSS SSIM: 0.2577 | LOSS VGG: 0.1503 | LOSS MASK: 0.0026 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1390/1671 | LOSS D: 0.7003 | LOSS G: 1.1734 | LOSS GAN: 0.7160 | LOSS MULTSCALE: 0.0143 | LOSS SSIM: 0.2588 | LOSS VGG: 0.1843 | LOSS MASK: 0.0037 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1400/1671 | LOSS D: 0.7025 | LOSS G: 1.2331 | LOSS GAN: 0.7761 | LOSS MULTSCALE: 0.0191 | LOSS SSIM: 0.2877 | LOSS VGG: 0.1503 | LOSS MASK: 0.0046 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1410/1671 | LOSS D: 0.6855 | LOSS G: 1.0843 | LOSS GAN: 0.7367 | LOSS MULTSCALE: 0.0079 | LOSS SSIM: 0.2165 | LOSS VGG: 0.1232 | LOSS MASK: 0.0022 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1420/1671 | LOSS D: 0.6893 | LOSS G: 1.1788 | LOSS GAN: 0.7311 | LOSS MULTSCALE: 0.0151 | LOSS SSIM: 0.2592 | LOSS VGG: 0.1733 | LOSS MASK: 0.0042 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1430/1671 | LOSS D: 0.6963 | LOSS G: 1.1316 | LOSS GAN: 0.7397 | LOSS MULTSCALE: 0.0132 | LOSS SSIM: 0.2468 | LOSS VGG: 0.1318 | LOSS MASK: 0.0033 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1440/1671 | LOSS D: 0.7078 | LOSS G: 1.0509 | LOSS GAN: 0.6916 | LOSS MULTSCALE: 0.0111 | LOSS SSIM: 0.2349 | LOSS VGG: 0.1134 | LOSS MASK: 0.0022 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1450/1671 | LOSS D: 0.6629 | LOSS G: 1.1702 | LOSS GAN: 0.7312 | LOSS MULTSCALE: 0.0184 | LOSS SSIM: 0.2845 | LOSS VGG: 0.1361 | LOSS MASK: 0.0054 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1460/1671 | LOSS D: 0.6936 | LOSS G: 1.1729 | LOSS GAN: 0.7814 | LOSS MULTSCALE: 0.0147 | LOSS SSIM: 0.2475 | LOSS VGG: 0.1293 | LOSS MASK: 0.0039 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1470/1671 | LOSS D: 0.6969 | LOSS G: 1.0627 | LOSS GAN: 0.7224 | LOSS MULTSCALE: 0.0094 | LOSS SSIM: 0.2368 | LOSS VGG: 0.0941 | LOSS MASK: 0.0022 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1480/1671 | LOSS D: 0.7256 | LOSS G: 1.1844 | LOSS GAN: 0.7719 | LOSS MULTSCALE: 0.0148 | LOSS SSIM: 0.2692 | LOSS VGG: 0.1285 | LOSS MASK: 0.0032 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1490/1671 | LOSS D: 0.7183 | LOSS G: 1.1326 | LOSS GAN: 0.7992 | LOSS MULTSCALE: 0.0116 | LOSS SSIM: 0.2395 | LOSS VGG: 0.0824 | LOSS MASK: 0.0028 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1500/1671 | LOSS D: 0.6974 | LOSS G: 1.2143 | LOSS GAN: 0.7818 | LOSS MULTSCALE: 0.0181 | LOSS SSIM: 0.2764 | LOSS VGG: 0.1381 | LOSS MASK: 0.0039 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1510/1671 | LOSS D: 0.6905 | LOSS G: 1.1205 | LOSS GAN: 0.7337 | LOSS MULTSCALE: 0.0098 | LOSS SSIM: 0.2428 | LOSS VGG: 0.1342 | LOSS MASK: 0.0029 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1520/1671 | LOSS D: 0.6763 | LOSS G: 1.1189 | LOSS GAN: 0.7289 | LOSS MULTSCALE: 0.0226 | LOSS SSIM: 0.2737 | LOSS VGG: 0.0938 | LOSS MASK: 0.0067 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1530/1671 | LOSS D: 0.6962 | LOSS G: 1.1550 | LOSS GAN: 0.7503 | LOSS MULTSCALE: 0.0194 | LOSS SSIM: 0.2715 | LOSS VGG: 0.1138 | LOSS MASK: 0.0064 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1540/1671 | LOSS D: 0.6406 | LOSS G: 1.1379 | LOSS GAN: 0.7711 | LOSS MULTSCALE: 0.0195 | LOSS SSIM: 0.2274 | LOSS VGG: 0.1199 | LOSS MASK: 0.0041 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1550/1671 | LOSS D: 0.6742 | LOSS G: 1.1891 | LOSS GAN: 0.7767 | LOSS MULTSCALE: 0.0132 | LOSS SSIM: 0.2469 | LOSS VGG: 0.1523 | LOSS MASK: 0.0039 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1560/1671 | LOSS D: 0.6516 | LOSS G: 1.2768 | LOSS GAN: 0.8361 | LOSS MULTSCALE: 0.0189 | LOSS SSIM: 0.2800 | LOSS VGG: 0.1418 | LOSS MASK: 0.0046 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1570/1671 | LOSS D: 0.6767 | LOSS G: 1.2287 | LOSS GAN: 0.7502 | LOSS MULTSCALE: 0.0242 | LOSS SSIM: 0.2860 | LOSS VGG: 0.1682 | LOSS MASK: 0.0077 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1580/1671 | LOSS D: 0.6811 | LOSS G: 1.0883 | LOSS GAN: 0.6498 | LOSS MULTSCALE: 0.0110 | LOSS SSIM: 0.2413 | LOSS VGG: 0.1861 | LOSS MASK: 0.0029 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1590/1671 | LOSS D: 0.6864 | LOSS G: 1.1638 | LOSS GAN: 0.7914 | LOSS MULTSCALE: 0.0086 | LOSS SSIM: 0.2396 | LOSS VGG: 0.1242 | LOSS MASK: 0.0020 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1600/1671 | LOSS D: 0.6925 | LOSS G: 1.0767 | LOSS GAN: 0.7270 | LOSS MULTSCALE: 0.0139 | LOSS SSIM: 0.2312 | LOSS VGG: 0.1046 | LOSS MASK: 0.0041 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1610/1671 | LOSS D: 0.7066 | LOSS G: 1.1330 | LOSS GAN: 0.7505 | LOSS MULTSCALE: 0.0149 | LOSS SSIM: 0.2303 | LOSS VGG: 0.1373 | LOSS MASK: 0.0036 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1620/1671 | LOSS D: 0.7042 | LOSS G: 1.0451 | LOSS GAN: 0.7163 | LOSS MULTSCALE: 0.0079 | LOSS SSIM: 0.2279 | LOSS VGG: 0.0929 | LOSS MASK: 0.0020 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1630/1671 | LOSS D: 0.6869 | LOSS G: 1.0925 | LOSS GAN: 0.7128 | LOSS MULTSCALE: 0.0108 | LOSS SSIM: 0.2538 | LOSS VGG: 0.1150 | LOSS MASK: 0.0024 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1640/1671 | LOSS D: 0.6793 | LOSS G: 1.1668 | LOSS GAN: 0.7267 | LOSS MULTSCALE: 0.0141 | LOSS SSIM: 0.2605 | LOSS VGG: 0.1655 | LOSS MASK: 0.0039 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1650/1671 | LOSS D: 0.7073 | LOSS G: 1.1432 | LOSS GAN: 0.7261 | LOSS MULTSCALE: 0.0128 | LOSS SSIM: 0.2473 | LOSS VGG: 0.1570 | LOSS MASK: 0.0031 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1660/1671 | LOSS D: 0.6842 | LOSS G: 1.1703 | LOSS GAN: 0.7568 | LOSS MULTSCALE: 0.0130 | LOSS SSIM: 0.2433 | LOSS VGG: 0.1573 | LOSS MASK: 0.0039 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1670/1671 | LOSS D: 0.6740 | LOSS G: 1.0893 | LOSS GAN: 0.6715 | LOSS MULTSCALE: 0.0164 | LOSS SSIM: 0.2572 | LOSS VGG: 0.1442 | LOSS MASK: 0.0042 |
# [proposed] TRAIN: EPOCH 581/20 | BATCH 1671/1671 | LOSS D: 0.6860 | LOSS G: 1.1452 | LOSS GAN: 0.7441 | LOSS MULTSCALE: 0.0131 | LOSS SSIM: 0.2452 | LOSS VGG: 0.1429 | LOSS MASK: 0.0034 |
# [proposed: 1963.397s] TRAIN MEAN LOSS: EPOCH 581/20 | LOSS D: 0.6909 | LOSS G: 1.1349 | LOSS GAN: 0.7276 | LOSS MULTSCALE: 0.0163 | LOSS SSIM: 0.2585 | LOSS VGG: 0.1325 | LOSS MASK: 0.0042 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 1/1671 | LOSS D: 0.6972 | LOSS G: 1.0667 | LOSS GAN: 0.6644 | LOSS MULTSCALE: 0.0203 | LOSS SSIM: 0.2610 | LOSS VGG: 0.1210 | LOSS MASK: 0.0046 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 10/1671 | LOSS D: 0.7085 | LOSS G: 1.0429 | LOSS GAN: 0.7211 | LOSS MULTSCALE: 0.0086 | LOSS SSIM: 0.2017 | LOSS VGG: 0.1114 | LOSS MASK: 0.0019 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 20/1671 | LOSS D: 0.6899 | LOSS G: 1.1044 | LOSS GAN: 0.7618 | LOSS MULTSCALE: 0.0109 | LOSS SSIM: 0.2311 | LOSS VGG: 0.1005 | LOSS MASK: 0.0035 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 30/1671 | LOSS D: 0.6733 | LOSS G: 1.2784 | LOSS GAN: 0.7537 | LOSS MULTSCALE: 0.0299 | LOSS SSIM: 0.3032 | LOSS VGG: 0.1917 | LOSS MASK: 0.0076 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 40/1671 | LOSS D: 0.7641 | LOSS G: 1.3459 | LOSS GAN: 0.9063 | LOSS MULTSCALE: 0.0175 | LOSS SSIM: 0.2934 | LOSS VGG: 0.1287 | LOSS MASK: 0.0028 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 50/1671 | LOSS D: 0.7046 | LOSS G: 1.2182 | LOSS GAN: 0.7167 | LOSS MULTSCALE: 0.0273 | LOSS SSIM: 0.2925 | LOSS VGG: 0.1817 | LOSS MASK: 0.0063 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 60/1671 | LOSS D: 0.6931 | LOSS G: 1.0942 | LOSS GAN: 0.7255 | LOSS MULTSCALE: 0.0168 | LOSS SSIM: 0.2570 | LOSS VGG: 0.0948 | LOSS MASK: 0.0041 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 70/1671 | LOSS D: 0.6690 | LOSS G: 1.1856 | LOSS GAN: 0.7744 | LOSS MULTSCALE: 0.0143 | LOSS SSIM: 0.2758 | LOSS VGG: 0.1211 | LOSS MASK: 0.0034 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 80/1671 | LOSS D: 0.5669 | LOSS G: 1.3934 | LOSS GAN: 0.9412 | LOSS MULTSCALE: 0.0209 | LOSS SSIM: 0.2772 | LOSS VGG: 0.1541 | LOSS MASK: 0.0078 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 90/1671 | LOSS D: 0.6577 | LOSS G: 1.1355 | LOSS GAN: 0.8144 | LOSS MULTSCALE: 0.0062 | LOSS SSIM: 0.2241 | LOSS VGG: 0.0908 | LOSS MASK: 0.0015 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 100/1671 | LOSS D: 0.7097 | LOSS G: 1.1252 | LOSS GAN: 0.7254 | LOSS MULTSCALE: 0.0139 | LOSS SSIM: 0.2469 | LOSS VGG: 0.1389 | LOSS MASK: 0.0031 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 110/1671 | LOSS D: 0.6898 | LOSS G: 1.0988 | LOSS GAN: 0.7194 | LOSS MULTSCALE: 0.0127 | LOSS SSIM: 0.2357 | LOSS VGG: 0.1310 | LOSS MASK: 0.0026 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 120/1671 | LOSS D: 0.6493 | LOSS G: 1.3912 | LOSS GAN: 0.8757 | LOSS MULTSCALE: 0.0159 | LOSS SSIM: 0.3020 | LOSS VGG: 0.1976 | LOSS MASK: 0.0045 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 130/1671 | LOSS D: 0.7036 | LOSS G: 1.1910 | LOSS GAN: 0.7494 | LOSS MULTSCALE: 0.0198 | LOSS SSIM: 0.2702 | LOSS VGG: 0.1516 | LOSS MASK: 0.0053 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 140/1671 | LOSS D: 0.6236 | LOSS G: 1.2531 | LOSS GAN: 0.8161 | LOSS MULTSCALE: 0.0214 | LOSS SSIM: 0.2749 | LOSS VGG: 0.1407 | LOSS MASK: 0.0056 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 150/1671 | LOSS D: 0.6997 | LOSS G: 1.0513 | LOSS GAN: 0.7021 | LOSS MULTSCALE: 0.0107 | LOSS SSIM: 0.2197 | LOSS VGG: 0.1187 | LOSS MASK: 0.0029 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 160/1671 | LOSS D: 0.6966 | LOSS G: 1.1474 | LOSS GAN: 0.7592 | LOSS MULTSCALE: 0.0118 | LOSS SSIM: 0.2297 | LOSS VGG: 0.1468 | LOSS MASK: 0.0030 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 170/1671 | LOSS D: 0.6951 | LOSS G: 1.1396 | LOSS GAN: 0.7534 | LOSS MULTSCALE: 0.0135 | LOSS SSIM: 0.2505 | LOSS VGG: 0.1222 | LOSS MASK: 0.0022 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 180/1671 | LOSS D: 0.7216 | LOSS G: 1.1511 | LOSS GAN: 0.7744 | LOSS MULTSCALE: 0.0156 | LOSS SSIM: 0.2639 | LOSS VGG: 0.0971 | LOSS MASK: 0.0037 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 190/1671 | LOSS D: 0.6972 | LOSS G: 1.0844 | LOSS GAN: 0.7368 | LOSS MULTSCALE: 0.0112 | LOSS SSIM: 0.2349 | LOSS VGG: 0.1014 | LOSS MASK: 0.0024 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 200/1671 | LOSS D: 0.6866 | LOSS G: 1.1043 | LOSS GAN: 0.7425 | LOSS MULTSCALE: 0.0139 | LOSS SSIM: 0.2476 | LOSS VGG: 0.1003 | LOSS MASK: 0.0038 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 210/1671 | LOSS D: 0.7016 | LOSS G: 1.1668 | LOSS GAN: 0.6783 | LOSS MULTSCALE: 0.0218 | LOSS SSIM: 0.3020 | LOSS VGG: 0.1647 | LOSS MASK: 0.0056 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 220/1671 | LOSS D: 0.6827 | LOSS G: 1.1467 | LOSS GAN: 0.7416 | LOSS MULTSCALE: 0.0089 | LOSS SSIM: 0.2614 | LOSS VGG: 0.1348 | LOSS MASK: 0.0026 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 230/1671 | LOSS D: 0.6624 | LOSS G: 1.1621 | LOSS GAN: 0.7164 | LOSS MULTSCALE: 0.0157 | LOSS SSIM: 0.2804 | LOSS VGG: 0.1496 | LOSS MASK: 0.0042 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 240/1671 | LOSS D: 0.6391 | LOSS G: 1.2627 | LOSS GAN: 0.7733 | LOSS MULTSCALE: 0.0156 | LOSS SSIM: 0.2656 | LOSS VGG: 0.2083 | LOSS MASK: 0.0041 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 250/1671 | LOSS D: 0.6708 | LOSS G: 1.1343 | LOSS GAN: 0.7205 | LOSS MULTSCALE: 0.0108 | LOSS SSIM: 0.2661 | LOSS VGG: 0.1369 | LOSS MASK: 0.0024 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 260/1671 | LOSS D: 0.7029 | LOSS G: 1.3616 | LOSS GAN: 0.8569 | LOSS MULTSCALE: 0.0217 | LOSS SSIM: 0.2918 | LOSS VGG: 0.1912 | LOSS MASK: 0.0059 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 270/1671 | LOSS D: 0.7349 | LOSS G: 1.0650 | LOSS GAN: 0.6861 | LOSS MULTSCALE: 0.0127 | LOSS SSIM: 0.2485 | LOSS VGG: 0.1177 | LOSS MASK: 0.0026 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 280/1671 | LOSS D: 0.7077 | LOSS G: 1.2221 | LOSS GAN: 0.8462 | LOSS MULTSCALE: 0.0166 | LOSS SSIM: 0.2545 | LOSS VGG: 0.1048 | LOSS MASK: 0.0037 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 290/1671 | LOSS D: 0.6974 | LOSS G: 1.1123 | LOSS GAN: 0.7696 | LOSS MULTSCALE: 0.0127 | LOSS SSIM: 0.2446 | LOSS VGG: 0.0854 | LOSS MASK: 0.0027 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 300/1671 | LOSS D: 0.7088 | LOSS G: 1.0978 | LOSS GAN: 0.6498 | LOSS MULTSCALE: 0.0207 | LOSS SSIM: 0.3148 | LOSS VGG: 0.1124 | LOSS MASK: 0.0065 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 310/1671 | LOSS D: 0.6921 | LOSS G: 1.1188 | LOSS GAN: 0.7155 | LOSS MULTSCALE: 0.0120 | LOSS SSIM: 0.2435 | LOSS VGG: 0.1477 | LOSS MASK: 0.0032 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 320/1671 | LOSS D: 0.7097 | LOSS G: 1.1439 | LOSS GAN: 0.7912 | LOSS MULTSCALE: 0.0079 | LOSS SSIM: 0.2177 | LOSS VGG: 0.1271 | LOSS MASK: 0.0021 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 330/1671 | LOSS D: 0.6813 | LOSS G: 1.1325 | LOSS GAN: 0.7507 | LOSS MULTSCALE: 0.0115 | LOSS SSIM: 0.2581 | LOSS VGG: 0.1123 | LOSS MASK: 0.0026 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 340/1671 | LOSS D: 0.6816 | LOSS G: 1.2243 | LOSS GAN: 0.7884 | LOSS MULTSCALE: 0.0118 | LOSS SSIM: 0.2516 | LOSS VGG: 0.1725 | LOSS MASK: 0.0034 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 350/1671 | LOSS D: 0.6803 | LOSS G: 1.1405 | LOSS GAN: 0.7738 | LOSS MULTSCALE: 0.0101 | LOSS SSIM: 0.2509 | LOSS VGG: 0.1056 | LOSS MASK: 0.0034 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 360/1671 | LOSS D: 0.7089 | LOSS G: 1.1028 | LOSS GAN: 0.7114 | LOSS MULTSCALE: 0.0209 | LOSS SSIM: 0.2390 | LOSS VGG: 0.1316 | LOSS MASK: 0.0033 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 370/1671 | LOSS D: 0.7147 | LOSS G: 1.1239 | LOSS GAN: 0.6975 | LOSS MULTSCALE: 0.0219 | LOSS SSIM: 0.2562 | LOSS VGG: 0.1483 | LOSS MASK: 0.0066 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 380/1671 | LOSS D: 0.6783 | LOSS G: 1.2569 | LOSS GAN: 0.7665 | LOSS MULTSCALE: 0.0176 | LOSS SSIM: 0.2738 | LOSS VGG: 0.1990 | LOSS MASK: 0.0054 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 390/1671 | LOSS D: 0.6960 | LOSS G: 1.1749 | LOSS GAN: 0.7485 | LOSS MULTSCALE: 0.0324 | LOSS SSIM: 0.2845 | LOSS VGG: 0.1095 | LOSS MASK: 0.0084 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 400/1671 | LOSS D: 0.7081 | LOSS G: 1.0424 | LOSS GAN: 0.7154 | LOSS MULTSCALE: 0.0091 | LOSS SSIM: 0.2473 | LOSS VGG: 0.0706 | LOSS MASK: 0.0017 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 410/1671 | LOSS D: 0.6980 | LOSS G: 1.0918 | LOSS GAN: 0.6948 | LOSS MULTSCALE: 0.0153 | LOSS SSIM: 0.2598 | LOSS VGG: 0.1219 | LOSS MASK: 0.0052 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 420/1671 | LOSS D: 0.7021 | LOSS G: 1.1068 | LOSS GAN: 0.6631 | LOSS MULTSCALE: 0.0167 | LOSS SSIM: 0.2890 | LOSS VGG: 0.1380 | LOSS MASK: 0.0040 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 430/1671 | LOSS D: 0.6973 | LOSS G: 1.1881 | LOSS GAN: 0.8173 | LOSS MULTSCALE: 0.0139 | LOSS SSIM: 0.2564 | LOSS VGG: 0.1005 | LOSS MASK: 0.0045 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 440/1671 | LOSS D: 0.6843 | LOSS G: 1.0678 | LOSS GAN: 0.6992 | LOSS MULTSCALE: 0.0100 | LOSS SSIM: 0.2497 | LOSS VGG: 0.1088 | LOSS MASK: 0.0023 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 450/1671 | LOSS D: 0.7028 | LOSS G: 1.2014 | LOSS GAN: 0.7039 | LOSS MULTSCALE: 0.0255 | LOSS SSIM: 0.2912 | LOSS VGG: 0.1808 | LOSS MASK: 0.0063 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 460/1671 | LOSS D: 0.6765 | LOSS G: 1.0814 | LOSS GAN: 0.6902 | LOSS MULTSCALE: 0.0141 | LOSS SSIM: 0.2462 | LOSS VGG: 0.1309 | LOSS MASK: 0.0048 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 470/1671 | LOSS D: 0.6980 | LOSS G: 1.2030 | LOSS GAN: 0.7621 | LOSS MULTSCALE: 0.0271 | LOSS SSIM: 0.2950 | LOSS VGG: 0.1188 | LOSS MASK: 0.0073 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 480/1671 | LOSS D: 0.6943 | LOSS G: 1.1828 | LOSS GAN: 0.7380 | LOSS MULTSCALE: 0.0196 | LOSS SSIM: 0.2922 | LOSS VGG: 0.1331 | LOSS MASK: 0.0050 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 490/1671 | LOSS D: 0.6876 | LOSS G: 1.1999 | LOSS GAN: 0.7295 | LOSS MULTSCALE: 0.0145 | LOSS SSIM: 0.2771 | LOSS VGG: 0.1788 | LOSS MASK: 0.0048 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 500/1671 | LOSS D: 0.6917 | LOSS G: 1.1276 | LOSS GAN: 0.7467 | LOSS MULTSCALE: 0.0084 | LOSS SSIM: 0.2244 | LOSS VGG: 0.1481 | LOSS MASK: 0.0021 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 510/1671 | LOSS D: 0.7022 | LOSS G: 1.2975 | LOSS GAN: 0.8072 | LOSS MULTSCALE: 0.0248 | LOSS SSIM: 0.3091 | LOSS VGG: 0.1563 | LOSS MASK: 0.0070 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 520/1671 | LOSS D: 0.6834 | LOSS G: 1.1075 | LOSS GAN: 0.7133 | LOSS MULTSCALE: 0.0178 | LOSS SSIM: 0.2373 | LOSS VGG: 0.1391 | LOSS MASK: 0.0031 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 530/1671 | LOSS D: 0.6632 | LOSS G: 1.0721 | LOSS GAN: 0.6890 | LOSS MULTSCALE: 0.0182 | LOSS SSIM: 0.2340 | LOSS VGG: 0.1309 | LOSS MASK: 0.0039 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 540/1671 | LOSS D: 0.7099 | LOSS G: 1.0961 | LOSS GAN: 0.7256 | LOSS MULTSCALE: 0.0099 | LOSS SSIM: 0.2293 | LOSS VGG: 0.1314 | LOSS MASK: 0.0035 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 550/1671 | LOSS D: 0.5883 | LOSS G: 1.2734 | LOSS GAN: 0.8310 | LOSS MULTSCALE: 0.0222 | LOSS SSIM: 0.2884 | LOSS VGG: 0.1318 | LOSS MASK: 0.0065 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 560/1671 | LOSS D: 0.6794 | LOSS G: 1.1844 | LOSS GAN: 0.7589 | LOSS MULTSCALE: 0.0135 | LOSS SSIM: 0.2707 | LOSS VGG: 0.1413 | LOSS MASK: 0.0033 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 570/1671 | LOSS D: 0.7037 | LOSS G: 1.0574 | LOSS GAN: 0.7205 | LOSS MULTSCALE: 0.0089 | LOSS SSIM: 0.2344 | LOSS VGG: 0.0937 | LOSS MASK: 0.0024 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 580/1671 | LOSS D: 0.6839 | LOSS G: 1.1769 | LOSS GAN: 0.7600 | LOSS MULTSCALE: 0.0170 | LOSS SSIM: 0.2310 | LOSS VGG: 0.1688 | LOSS MASK: 0.0043 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 590/1671 | LOSS D: 0.7029 | LOSS G: 1.1442 | LOSS GAN: 0.7016 | LOSS MULTSCALE: 0.0218 | LOSS SSIM: 0.2882 | LOSS VGG: 0.1326 | LOSS MASK: 0.0046 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 600/1671 | LOSS D: 0.6982 | LOSS G: 1.0764 | LOSS GAN: 0.6671 | LOSS MULTSCALE: 0.0151 | LOSS SSIM: 0.2551 | LOSS VGG: 0.1391 | LOSS MASK: 0.0042 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 610/1671 | LOSS D: 0.6720 | LOSS G: 1.1541 | LOSS GAN: 0.7257 | LOSS MULTSCALE: 0.0205 | LOSS SSIM: 0.2538 | LOSS VGG: 0.1540 | LOSS MASK: 0.0050 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 620/1671 | LOSS D: 0.6943 | LOSS G: 1.1748 | LOSS GAN: 0.7448 | LOSS MULTSCALE: 0.0168 | LOSS SSIM: 0.2784 | LOSS VGG: 0.1348 | LOSS MASK: 0.0039 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 630/1671 | LOSS D: 0.7175 | LOSS G: 0.8793 | LOSS GAN: 0.5914 | LOSS MULTSCALE: 0.0070 | LOSS SSIM: 0.1883 | LOSS VGG: 0.0926 | LOSS MASK: 0.0017 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 640/1671 | LOSS D: 0.6968 | LOSS G: 1.0248 | LOSS GAN: 0.7034 | LOSS MULTSCALE: 0.0078 | LOSS SSIM: 0.1993 | LOSS VGG: 0.1142 | LOSS MASK: 0.0021 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 650/1671 | LOSS D: 0.6771 | LOSS G: 1.1275 | LOSS GAN: 0.7654 | LOSS MULTSCALE: 0.0098 | LOSS SSIM: 0.2410 | LOSS VGG: 0.1113 | LOSS MASK: 0.0025 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 660/1671 | LOSS D: 0.6910 | LOSS G: 1.2437 | LOSS GAN: 0.7352 | LOSS MULTSCALE: 0.0180 | LOSS SSIM: 0.2844 | LOSS VGG: 0.2061 | LOSS MASK: 0.0046 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 670/1671 | LOSS D: 0.6439 | LOSS G: 1.2543 | LOSS GAN: 0.7641 | LOSS MULTSCALE: 0.0200 | LOSS SSIM: 0.2612 | LOSS VGG: 0.2091 | LOSS MASK: 0.0060 |
# [proposed] TRAIN: EPOCH 582/20 | BATCH 680/1671 | LOSS D: 0.6914 | LOSS G: 1.2044 | LOSS GAN: 0.7724 | LOSS MULTSCALE: 0.0173 | LOSS SSIM: 0.2893 | LOSS VGG: 0.1254 | LOSS MASK: 0.0053 |
# ...
# [proposed] TRAIN: EPOCH 600/20 | BATCH 860/1671 | LOSS D: 0.6983 | LOSS G: 1.0956 | LOSS GAN: 0.6472 | LOSS MULTSCALE: 0.0136 | LOSS SSIM: 0.2631 | LOSS VGG: 0.1718 | LOSS MASK: 0.0036 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 870/1671 | LOSS D: 0.6724 | LOSS G: 1.2247 | LOSS GAN: 0.7718 | LOSS MULTSCALE: 0.0166 | LOSS SSIM: 0.2539 | LOSS VGG: 0.1824 | LOSS MASK: 0.0050 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 880/1671 | LOSS D: 0.4992 | LOSS G: 1.5027 | LOSS GAN: 0.9664 | LOSS MULTSCALE: 0.0239 | LOSS SSIM: 0.3137 | LOSS VGG: 0.1987 | LOSS MASK: 0.0063 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 890/1671 | LOSS D: 0.6588 | LOSS G: 1.1317 | LOSS GAN: 0.7372 | LOSS MULTSCALE: 0.0192 | LOSS SSIM: 0.2610 | LOSS VGG: 0.1143 | LOSS MASK: 0.0050 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 900/1671 | LOSS D: 0.6880 | LOSS G: 1.1171 | LOSS GAN: 0.7377 | LOSS MULTSCALE: 0.0131 | LOSS SSIM: 0.2263 | LOSS VGG: 0.1400 | LOSS MASK: 0.0028 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 910/1671 | LOSS D: 0.7029 | LOSS G: 1.1041 | LOSS GAN: 0.7029 | LOSS MULTSCALE: 0.0166 | LOSS SSIM: 0.2340 | LOSS VGG: 0.1506 | LOSS MASK: 0.0039 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 920/1671 | LOSS D: 0.6985 | LOSS G: 1.1422 | LOSS GAN: 0.7724 | LOSS MULTSCALE: 0.0208 | LOSS SSIM: 0.2531 | LOSS VGG: 0.0959 | LOSS MASK: 0.0031 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 930/1671 | LOSS D: 0.6301 | LOSS G: 1.1721 | LOSS GAN: 0.8309 | LOSS MULTSCALE: 0.0089 | LOSS SSIM: 0.2257 | LOSS VGG: 0.1065 | LOSS MASK: 0.0025 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 940/1671 | LOSS D: 0.7081 | LOSS G: 1.3245 | LOSS GAN: 0.7970 | LOSS MULTSCALE: 0.0220 | LOSS SSIM: 0.3071 | LOSS VGG: 0.1984 | LOSS MASK: 0.0052 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 950/1671 | LOSS D: 0.7008 | LOSS G: 1.0259 | LOSS GAN: 0.6928 | LOSS MULTSCALE: 0.0086 | LOSS SSIM: 0.2109 | LOSS VGG: 0.1136 | LOSS MASK: 0.0024 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 960/1671 | LOSS D: 0.7077 | LOSS G: 1.0263 | LOSS GAN: 0.6761 | LOSS MULTSCALE: 0.0107 | LOSS SSIM: 0.2422 | LOSS VGG: 0.0973 | LOSS MASK: 0.0021 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 970/1671 | LOSS D: 0.6648 | LOSS G: 1.1485 | LOSS GAN: 0.7155 | LOSS MULTSCALE: 0.0244 | LOSS SSIM: 0.2563 | LOSS VGG: 0.1523 | LOSS MASK: 0.0060 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 980/1671 | LOSS D: 0.6844 | LOSS G: 1.0565 | LOSS GAN: 0.6532 | LOSS MULTSCALE: 0.0173 | LOSS SSIM: 0.2507 | LOSS VGG: 0.1353 | LOSS MASK: 0.0040 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 990/1671 | LOSS D: 0.5657 | LOSS G: 1.3668 | LOSS GAN: 0.9223 | LOSS MULTSCALE: 0.0166 | LOSS SSIM: 0.2704 | LOSS VGG: 0.1575 | LOSS MASK: 0.0038 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1000/1671 | LOSS D: 0.7002 | LOSS G: 1.1121 | LOSS GAN: 0.7435 | LOSS MULTSCALE: 0.0132 | LOSS SSIM: 0.2578 | LOSS VGG: 0.0976 | LOSS MASK: 0.0029 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1010/1671 | LOSS D: 0.7144 | LOSS G: 0.9557 | LOSS GAN: 0.6651 | LOSS MULTSCALE: 0.0062 | LOSS SSIM: 0.1968 | LOSS VGG: 0.0875 | LOSS MASK: 0.0016 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1020/1671 | LOSS D: 0.7839 | LOSS G: 0.9991 | LOSS GAN: 0.5796 | LOSS MULTSCALE: 0.0199 | LOSS SSIM: 0.2724 | LOSS VGG: 0.1271 | LOSS MASK: 0.0041 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1030/1671 | LOSS D: 0.7021 | LOSS G: 1.0846 | LOSS GAN: 0.7050 | LOSS MULTSCALE: 0.0093 | LOSS SSIM: 0.2241 | LOSS VGG: 0.1461 | LOSS MASK: 0.0021 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1040/1671 | LOSS D: 0.6653 | LOSS G: 1.1103 | LOSS GAN: 0.6576 | LOSS MULTSCALE: 0.0228 | LOSS SSIM: 0.2680 | LOSS VGG: 0.1620 | LOSS MASK: 0.0060 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1050/1671 | LOSS D: 0.6842 | LOSS G: 1.0739 | LOSS GAN: 0.6738 | LOSS MULTSCALE: 0.0161 | LOSS SSIM: 0.2209 | LOSS VGG: 0.1631 | LOSS MASK: 0.0037 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1060/1671 | LOSS D: 0.6728 | LOSS G: 1.2122 | LOSS GAN: 0.7150 | LOSS MULTSCALE: 0.0288 | LOSS SSIM: 0.3196 | LOSS VGG: 0.1488 | LOSS MASK: 0.0088 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1070/1671 | LOSS D: 0.7083 | LOSS G: 1.2295 | LOSS GAN: 0.7793 | LOSS MULTSCALE: 0.0146 | LOSS SSIM: 0.2562 | LOSS VGG: 0.1793 | LOSS MASK: 0.0038 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1080/1671 | LOSS D: 0.6976 | LOSS G: 1.2634 | LOSS GAN: 0.8056 | LOSS MULTSCALE: 0.0254 | LOSS SSIM: 0.2870 | LOSS VGG: 0.1453 | LOSS MASK: 0.0071 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1090/1671 | LOSS D: 0.7084 | LOSS G: 1.1992 | LOSS GAN: 0.7424 | LOSS MULTSCALE: 0.0124 | LOSS SSIM: 0.2844 | LOSS VGG: 0.1601 | LOSS MASK: 0.0036 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1100/1671 | LOSS D: 0.7010 | LOSS G: 1.1357 | LOSS GAN: 0.7764 | LOSS MULTSCALE: 0.0124 | LOSS SSIM: 0.2461 | LOSS VGG: 0.1007 | LOSS MASK: 0.0040 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1110/1671 | LOSS D: 0.7369 | LOSS G: 1.0555 | LOSS GAN: 0.6931 | LOSS MULTSCALE: 0.0119 | LOSS SSIM: 0.2189 | LOSS VGG: 0.1316 | LOSS MASK: 0.0031 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1120/1671 | LOSS D: 0.6810 | LOSS G: 1.1763 | LOSS GAN: 0.7547 | LOSS MULTSCALE: 0.0160 | LOSS SSIM: 0.2583 | LOSS VGG: 0.1473 | LOSS MASK: 0.0037 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1130/1671 | LOSS D: 0.7052 | LOSS G: 1.1461 | LOSS GAN: 0.7964 | LOSS MULTSCALE: 0.0089 | LOSS SSIM: 0.2217 | LOSS VGG: 0.1191 | LOSS MASK: 0.0016 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1140/1671 | LOSS D: 0.7064 | LOSS G: 1.1229 | LOSS GAN: 0.7493 | LOSS MULTSCALE: 0.0167 | LOSS SSIM: 0.2224 | LOSS VGG: 0.1345 | LOSS MASK: 0.0038 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1150/1671 | LOSS D: 0.6877 | LOSS G: 1.1373 | LOSS GAN: 0.7540 | LOSS MULTSCALE: 0.0148 | LOSS SSIM: 0.2508 | LOSS VGG: 0.1176 | LOSS MASK: 0.0039 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1160/1671 | LOSS D: 0.6729 | LOSS G: 1.1519 | LOSS GAN: 0.8262 | LOSS MULTSCALE: 0.0084 | LOSS SSIM: 0.2164 | LOSS VGG: 0.1010 | LOSS MASK: 0.0016 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1170/1671 | LOSS D: 0.6766 | LOSS G: 1.0362 | LOSS GAN: 0.6824 | LOSS MULTSCALE: 0.0140 | LOSS SSIM: 0.2233 | LOSS VGG: 0.1164 | LOSS MASK: 0.0032 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1180/1671 | LOSS D: 0.6650 | LOSS G: 1.2521 | LOSS GAN: 0.7811 | LOSS MULTSCALE: 0.0219 | LOSS SSIM: 0.2602 | LOSS VGG: 0.1889 | LOSS MASK: 0.0054 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1190/1671 | LOSS D: 0.6977 | LOSS G: 1.1862 | LOSS GAN: 0.7642 | LOSS MULTSCALE: 0.0175 | LOSS SSIM: 0.2733 | LOSS VGG: 0.1313 | LOSS MASK: 0.0035 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1200/1671 | LOSS D: 0.6994 | LOSS G: 1.1013 | LOSS GAN: 0.7407 | LOSS MULTSCALE: 0.0151 | LOSS SSIM: 0.2277 | LOSS VGG: 0.1178 | LOSS MASK: 0.0035 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1210/1671 | LOSS D: 0.6952 | LOSS G: 1.2863 | LOSS GAN: 0.8277 | LOSS MULTSCALE: 0.0116 | LOSS SSIM: 0.2571 | LOSS VGG: 0.1898 | LOSS MASK: 0.0032 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1220/1671 | LOSS D: 0.7138 | LOSS G: 0.9557 | LOSS GAN: 0.6613 | LOSS MULTSCALE: 0.0153 | LOSS SSIM: 0.1944 | LOSS VGG: 0.0848 | LOSS MASK: 0.0019 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1230/1671 | LOSS D: 0.5319 | LOSS G: 1.2928 | LOSS GAN: 0.8946 | LOSS MULTSCALE: 0.0184 | LOSS SSIM: 0.2713 | LOSS VGG: 0.1085 | LOSS MASK: 0.0075 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1240/1671 | LOSS D: 0.6857 | LOSS G: 1.1689 | LOSS GAN: 0.7388 | LOSS MULTSCALE: 0.0277 | LOSS SSIM: 0.2872 | LOSS VGG: 0.1151 | LOSS MASK: 0.0069 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1250/1671 | LOSS D: 0.7010 | LOSS G: 1.1815 | LOSS GAN: 0.7895 | LOSS MULTSCALE: 0.0140 | LOSS SSIM: 0.2661 | LOSS VGG: 0.1120 | LOSS MASK: 0.0039 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1260/1671 | LOSS D: 0.6626 | LOSS G: 1.2230 | LOSS GAN: 0.7442 | LOSS MULTSCALE: 0.0303 | LOSS SSIM: 0.3159 | LOSS VGG: 0.1327 | LOSS MASK: 0.0079 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1270/1671 | LOSS D: 0.7015 | LOSS G: 1.2731 | LOSS GAN: 0.7687 | LOSS MULTSCALE: 0.0244 | LOSS SSIM: 0.2928 | LOSS VGG: 0.1872 | LOSS MASK: 0.0070 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1280/1671 | LOSS D: 0.6897 | LOSS G: 1.2426 | LOSS GAN: 0.7862 | LOSS MULTSCALE: 0.0133 | LOSS SSIM: 0.2446 | LOSS VGG: 0.1986 | LOSS MASK: 0.0029 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1290/1671 | LOSS D: 0.5337 | LOSS G: 1.3138 | LOSS GAN: 0.8905 | LOSS MULTSCALE: 0.0132 | LOSS SSIM: 0.2681 | LOSS VGG: 0.1420 | LOSS MASK: 0.0028 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1300/1671 | LOSS D: 0.7076 | LOSS G: 1.1630 | LOSS GAN: 0.7007 | LOSS MULTSCALE: 0.0144 | LOSS SSIM: 0.2798 | LOSS VGG: 0.1682 | LOSS MASK: 0.0034 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1310/1671 | LOSS D: 0.6799 | LOSS G: 1.1164 | LOSS GAN: 0.7263 | LOSS MULTSCALE: 0.0190 | LOSS SSIM: 0.2699 | LOSS VGG: 0.1013 | LOSS MASK: 0.0050 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1320/1671 | LOSS D: 0.7650 | LOSS G: 1.0963 | LOSS GAN: 0.7116 | LOSS MULTSCALE: 0.0151 | LOSS SSIM: 0.2426 | LOSS VGG: 0.1271 | LOSS MASK: 0.0034 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1330/1671 | LOSS D: 0.6935 | LOSS G: 1.0964 | LOSS GAN: 0.7209 | LOSS MULTSCALE: 0.0122 | LOSS SSIM: 0.2548 | LOSS VGG: 0.1085 | LOSS MASK: 0.0031 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1340/1671 | LOSS D: 0.6974 | LOSS G: 1.3109 | LOSS GAN: 0.8296 | LOSS MULTSCALE: 0.0224 | LOSS SSIM: 0.2903 | LOSS VGG: 0.1685 | LOSS MASK: 0.0068 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1350/1671 | LOSS D: 0.6807 | LOSS G: 1.1936 | LOSS GAN: 0.7997 | LOSS MULTSCALE: 0.0160 | LOSS SSIM: 0.2620 | LOSS VGG: 0.1159 | LOSS MASK: 0.0043 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1360/1671 | LOSS D: 0.6530 | LOSS G: 1.2042 | LOSS GAN: 0.7843 | LOSS MULTSCALE: 0.0126 | LOSS SSIM: 0.2569 | LOSS VGG: 0.1505 | LOSS MASK: 0.0029 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1370/1671 | LOSS D: 0.6839 | LOSS G: 1.1448 | LOSS GAN: 0.7501 | LOSS MULTSCALE: 0.0177 | LOSS SSIM: 0.2532 | LOSS VGG: 0.1237 | LOSS MASK: 0.0037 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1380/1671 | LOSS D: 0.7041 | LOSS G: 1.2172 | LOSS GAN: 0.7459 | LOSS MULTSCALE: 0.0172 | LOSS SSIM: 0.2877 | LOSS VGG: 0.1664 | LOSS MASK: 0.0046 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1390/1671 | LOSS D: 0.6864 | LOSS G: 1.2494 | LOSS GAN: 0.8809 | LOSS MULTSCALE: 0.0107 | LOSS SSIM: 0.2277 | LOSS VGG: 0.1301 | LOSS MASK: 0.0027 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1400/1671 | LOSS D: 0.5134 | LOSS G: 1.4014 | LOSS GAN: 0.9132 | LOSS MULTSCALE: 0.0185 | LOSS SSIM: 0.3093 | LOSS VGG: 0.1605 | LOSS MASK: 0.0049 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1410/1671 | LOSS D: 0.6594 | LOSS G: 1.3122 | LOSS GAN: 0.8018 | LOSS MULTSCALE: 0.0281 | LOSS SSIM: 0.3118 | LOSS VGG: 0.1704 | LOSS MASK: 0.0079 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1420/1671 | LOSS D: 0.6973 | LOSS G: 1.2834 | LOSS GAN: 0.8464 | LOSS MULTSCALE: 0.0125 | LOSS SSIM: 0.2612 | LOSS VGG: 0.1632 | LOSS MASK: 0.0031 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1430/1671 | LOSS D: 0.6907 | LOSS G: 1.3165 | LOSS GAN: 0.8481 | LOSS MULTSCALE: 0.0206 | LOSS SSIM: 0.2970 | LOSS VGG: 0.1508 | LOSS MASK: 0.0059 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1440/1671 | LOSS D: 0.6939 | LOSS G: 1.1869 | LOSS GAN: 0.8205 | LOSS MULTSCALE: 0.0121 | LOSS SSIM: 0.2448 | LOSS VGG: 0.1096 | LOSS MASK: 0.0037 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1450/1671 | LOSS D: 0.6272 | LOSS G: 1.3341 | LOSS GAN: 0.8190 | LOSS MULTSCALE: 0.0309 | LOSS SSIM: 0.3151 | LOSS VGG: 0.1690 | LOSS MASK: 0.0103 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1460/1671 | LOSS D: 0.6615 | LOSS G: 1.1634 | LOSS GAN: 0.7600 | LOSS MULTSCALE: 0.0149 | LOSS SSIM: 0.2658 | LOSS VGG: 0.1227 | LOSS MASK: 0.0049 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1470/1671 | LOSS D: 0.6795 | LOSS G: 1.2445 | LOSS GAN: 0.8302 | LOSS MULTSCALE: 0.0097 | LOSS SSIM: 0.2452 | LOSS VGG: 0.1593 | LOSS MASK: 0.0024 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1480/1671 | LOSS D: 0.6846 | LOSS G: 1.2763 | LOSS GAN: 0.8359 | LOSS MULTSCALE: 0.0192 | LOSS SSIM: 0.2653 | LOSS VGG: 0.1560 | LOSS MASK: 0.0044 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1490/1671 | LOSS D: 0.6907 | LOSS G: 1.1326 | LOSS GAN: 0.7741 | LOSS MULTSCALE: 0.0211 | LOSS SSIM: 0.2194 | LOSS VGG: 0.1180 | LOSS MASK: 0.0050 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1500/1671 | LOSS D: 0.7261 | LOSS G: 1.1188 | LOSS GAN: 0.7265 | LOSS MULTSCALE: 0.0151 | LOSS SSIM: 0.2616 | LOSS VGG: 0.1156 | LOSS MASK: 0.0038 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1510/1671 | LOSS D: 0.6905 | LOSS G: 1.1424 | LOSS GAN: 0.7391 | LOSS MULTSCALE: 0.0250 | LOSS SSIM: 0.2576 | LOSS VGG: 0.1207 | LOSS MASK: 0.0063 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1520/1671 | LOSS D: 0.6993 | LOSS G: 1.0679 | LOSS GAN: 0.7285 | LOSS MULTSCALE: 0.0078 | LOSS SSIM: 0.2217 | LOSS VGG: 0.1099 | LOSS MASK: 0.0018 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1530/1671 | LOSS D: 0.7287 | LOSS G: 1.1507 | LOSS GAN: 0.7181 | LOSS MULTSCALE: 0.0165 | LOSS SSIM: 0.2596 | LOSS VGG: 0.1565 | LOSS MASK: 0.0048 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1540/1671 | LOSS D: 0.6638 | LOSS G: 1.3676 | LOSS GAN: 0.9430 | LOSS MULTSCALE: 0.0158 | LOSS SSIM: 0.2820 | LOSS VGG: 0.1267 | LOSS MASK: 0.0043 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1550/1671 | LOSS D: 0.7137 | LOSS G: 1.1268 | LOSS GAN: 0.7787 | LOSS MULTSCALE: 0.0108 | LOSS SSIM: 0.2463 | LOSS VGG: 0.0912 | LOSS MASK: 0.0018 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1560/1671 | LOSS D: 0.6954 | LOSS G: 1.1032 | LOSS GAN: 0.7247 | LOSS MULTSCALE: 0.0177 | LOSS SSIM: 0.2504 | LOSS VGG: 0.1104 | LOSS MASK: 0.0049 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1570/1671 | LOSS D: 0.7048 | LOSS G: 1.1952 | LOSS GAN: 0.8160 | LOSS MULTSCALE: 0.0114 | LOSS SSIM: 0.2476 | LOSS VGG: 0.1203 | LOSS MASK: 0.0029 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1580/1671 | LOSS D: 0.7026 | LOSS G: 1.2955 | LOSS GAN: 0.8663 | LOSS MULTSCALE: 0.0212 | LOSS SSIM: 0.2997 | LOSS VGG: 0.1084 | LOSS MASK: 0.0056 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1590/1671 | LOSS D: 0.5804 | LOSS G: 1.2247 | LOSS GAN: 0.7804 | LOSS MULTSCALE: 0.0178 | LOSS SSIM: 0.2912 | LOSS VGG: 0.1354 | LOSS MASK: 0.0039 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1600/1671 | LOSS D: 0.4618 | LOSS G: 1.3407 | LOSS GAN: 0.9540 | LOSS MULTSCALE: 0.0141 | LOSS SSIM: 0.2451 | LOSS VGG: 0.1275 | LOSS MASK: 0.0040 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1610/1671 | LOSS D: 0.7095 | LOSS G: 1.1827 | LOSS GAN: 0.8123 | LOSS MULTSCALE: 0.0102 | LOSS SSIM: 0.2381 | LOSS VGG: 0.1220 | LOSS MASK: 0.0026 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1620/1671 | LOSS D: 0.6395 | LOSS G: 1.3590 | LOSS GAN: 0.8072 | LOSS MULTSCALE: 0.0236 | LOSS SSIM: 0.3150 | LOSS VGG: 0.2132 | LOSS MASK: 0.0056 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1630/1671 | LOSS D: 0.6063 | LOSS G: 1.1201 | LOSS GAN: 0.7207 | LOSS MULTSCALE: 0.0138 | LOSS SSIM: 0.2623 | LOSS VGG: 0.1234 | LOSS MASK: 0.0041 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1640/1671 | LOSS D: 0.7043 | LOSS G: 1.0539 | LOSS GAN: 0.7271 | LOSS MULTSCALE: 0.0119 | LOSS SSIM: 0.2193 | LOSS VGG: 0.0955 | LOSS MASK: 0.0034 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1650/1671 | LOSS D: 0.6776 | LOSS G: 1.2533 | LOSS GAN: 0.8340 | LOSS MULTSCALE: 0.0214 | LOSS SSIM: 0.2832 | LOSS VGG: 0.1147 | LOSS MASK: 0.0054 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1660/1671 | LOSS D: 0.6777 | LOSS G: 1.2911 | LOSS GAN: 0.8454 | LOSS MULTSCALE: 0.0107 | LOSS SSIM: 0.2559 | LOSS VGG: 0.1792 | LOSS MASK: 0.0034 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1670/1671 | LOSS D: 0.7052 | LOSS G: 1.0583 | LOSS GAN: 0.7599 | LOSS MULTSCALE: 0.0069 | LOSS SSIM: 0.1925 | LOSS VGG: 0.0990 | LOSS MASK: 0.0016 |
# [proposed] TRAIN: EPOCH 600/20 | BATCH 1671/1671 | LOSS D: 0.6842 | LOSS G: 1.0934 | LOSS GAN: 0.7397 | LOSS MULTSCALE: 0.0146 | LOSS SSIM: 0.2403 | LOSS VGG: 0.0988 | LOSS MASK: 0.0025 |
# [proposed: 1952.820s] TRAIN MEAN LOSS: EPOCH 600/20 | LOSS D: 0.6790 | LOSS G: 1.1772 | LOSS GAN: 0.7702 | LOSS MULTSCALE: 0.0159 | LOSS SSIM: 0.2563 | LOSS VGG: 0.1348 | LOSS MASK: 0.0041 |
# Training Finished!!: 2025-03-17 12:43:02.264997
